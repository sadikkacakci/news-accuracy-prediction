# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.25.1-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 7.9 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.8.2)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 46.8 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (21.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.23.0)
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 69.2 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (3.0.4)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.11.1 tokenizers-0.13.2 transformers-4.25.1

# %%
model_name="yiyanghkust/finbert-tone"

# %%
from transformers import AutoModelForSequenceClassification
new_model = AutoModelForSequenceClassification.from_pretrained("/content/drive/MyDrive/Colab Notebooks/yiyanghkust finbert-tone/model")

# %%
from transformers import AutoTokenizer
new_tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# Downloading:   0%|          | 0.00/533 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]

# %%
import nltk
from nltk.stem.porter import PorterStemmer
import re
from nltk.corpus import stopwords
nltk.download("stopwords")
def preprocessing(text):
    ps = PorterStemmer()
    sentence = re.sub('[^a-zA-Z]',' ',text) # noktalama işaretlerini silme.
    sentence = sentence.lower() # kelimelerin hepsini küçük harf 
    sentence = sentence.split() # keliemeleri listeye atma
    sentence = [ps.stem(kelime) for kelime in sentence if not kelime in set(stopwords.words("english"))] #anlamı olmayan(stopwords) kelimeleri listeden atma
    sentence = " ".join(sentence) # listede kalan kelimeleri birleştirip yeni cümleyi oluşturma.
    return sentence
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
sentence = preprocessing("He went to airport.")
print(sentence)
# Out:
# went airport

# %%
import torch
import numpy as np

def get_prediction(text):
    text = preprocessing(text)
    encoding = new_tokenizer(text, return_tensors="pt", padding="max_length", truncation=True, max_length=128)
    # encoding = {k: v.to(trainer.model.device) for k,v in encoding.items()}
    outputs = new_model(**encoding)

    logits = outputs.logits

    sigmoid = torch.nn.Sigmoid()
    probs = sigmoid(logits.squeeze().cpu())
    probs = probs.detach().numpy()
    label = np.argmax(probs, axis=-1) # değeri 0 veya 1'e yuvarlıyoruz.
    
    if label == 1:
        print(f"sentiment: True, probability: {probs[1]}")
        return 1
    else:
        print(f"sentiment: Fake, probability: {probs[1]}")
        return 0

# %%
get_prediction("He goes to airport.")
# Out:
# sentiment: True, probability: 0.9936510920524597
# 1

# %%
submission = pd.read_csv("/content/drive/MyDrive/submission.csv")
# y = submission["Truth"]
# x = submission["Haber"]

# %%
accuracy = 0
y_pred = []
for i in range(submission.shape[0]):
    row = submission.iloc[i]
    text = row[0]
    truth_value = row[1]
    print(f"{i}-)")
    result = get_prediction(text)
    y_pred.append(result)
    if(result == int(truth_value)):
        accuracy += 1 
accuracy
# Out:
# 0-)
# sentiment: True, probability: 0.9937022924423218
# 1-)
# sentiment: Fake, probability: 0.09930296987295151
# 2-)
# sentiment: Fake, probability: 0.08127196133136749
# 3-)
# sentiment: True, probability: 0.9935838580131531
# 4-)
# sentiment: Fake, probability: 0.08820915967226028
# 5-)
# sentiment: True, probability: 0.9936891794204712
# 6-)
# sentiment: True, probability: 0.9937020540237427
# 7-)
# sentiment: Fake, probability: 0.08128499984741211
# 8-)
# sentiment: True, probability: 0.9936916828155518
# 9-)
# sentiment: True, probability: 0.9936816692352295
# 10-)
# sentiment: True, probability: 0.9936502575874329
# 11-)
# sentiment: True, probability: 0.9936901330947876
# 12-)
# sentiment: True, probability: 0.9936849474906921
# 13-)
# sentiment: True, probability: 0.9936406016349792
# 14-)
# sentiment: True, probability: 0.9937107563018799
# 15-)
# sentiment: True, probability: 0.9936342239379883
# 16-)
# sentiment: Fake, probability: 0.08127650618553162
# 17-)
# sentiment: True, probability: 0.9936783909797668
# 18-)
# sentiment: Fake, probability: 0.08441484719514847
# 19-)
# sentiment: True, probability: 0.9936656355857849
# 20-)
# sentiment: Fake, probability: 0.08185294270515442
# 21-)
# sentiment: True, probability: 0.9937145113945007
# 22-)
# sentiment: Fake, probability: 0.08279383182525635
# 23-)
# sentiment: Fake, probability: 0.14147914946079254
# 24-)
# sentiment: True, probability: 0.9935827851295471
# 25-)
# sentiment: Fake, probability: 0.09760131686925888
# 26-)
# sentiment: Fake, probability: 0.08654140681028366
# 27-)
# sentiment: True, probability: 0.9937009811401367
# 28-)
# sentiment: True, probability: 0.9936815500259399
# 29-)
# sentiment: True, probability: 0.9936349391937256
# 30-)
# sentiment: Fake, probability: 0.08322422951459885
# 31-)
# sentiment: Fake, probability: 0.08135540783405304
# 32-)
# sentiment: True, probability: 0.9935922026634216
# 33-)
# sentiment: Fake, probability: 0.08144516497850418
# 34-)
# sentiment: True, probability: 0.993678629398346
# 35-)
# sentiment: True, probability: 0.9936025738716125
# 36-)
# sentiment: Fake, probability: 0.08171310275793076
# 37-)
# sentiment: True, probability: 0.9936766028404236
# 38-)
# sentiment: True, probability: 0.9936814308166504
# 39-)
# sentiment: True, probability: 0.9936466217041016
# 40-)
# sentiment: Fake, probability: 0.2859346270561218
# 41-)
# sentiment: Fake, probability: 0.08215407282114029
# 42-)
# sentiment: Fake, probability: 0.08134644478559494
# 43-)
# sentiment: True, probability: 0.9937044978141785
# 44-)
# sentiment: Fake, probability: 0.08160971850156784
# 45-)
# sentiment: Fake, probability: 0.08144652098417282
# 46-)
# sentiment: True, probability: 0.9936995506286621
# 47-)
# sentiment: True, probability: 0.9936997890472412
# 48-)
# sentiment: True, probability: 0.9936855435371399
# 49-)
# sentiment: True, probability: 0.9936829805374146
# 50-)
# sentiment: True, probability: 0.9936624765396118
# 51-)
# sentiment: True, probability: 0.9936639070510864
# 52-)
# sentiment: True, probability: 0.9936720132827759
# 53-)
# sentiment: True, probability: 0.9936800003051758
# 54-)
# sentiment: True, probability: 0.993266224861145
# 55-)
# sentiment: Fake, probability: 0.08128020912408829
# 56-)
# sentiment: Fake, probability: 0.08143439888954163
# 57-)
# sentiment: True, probability: 0.9934598207473755
# 58-)
# sentiment: True, probability: 0.9936289191246033
# 59-)
# sentiment: Fake, probability: 0.09350863099098206
# 60-)
# sentiment: Fake, probability: 0.08578772842884064
# 61-)
# sentiment: Fake, probability: 0.08131031692028046
# 62-)
# sentiment: Fake, probability: 0.0812930092215538
# 63-)
# sentiment: Fake, probability: 0.08163851499557495
# 64-)
# sentiment: True, probability: 0.9602639079093933
# 65-)
# sentiment: True, probability: 0.9936814308166504
# 66-)
# sentiment: True, probability: 0.993678867816925
# 67-)
# sentiment: Fake, probability: 0.08125471323728561
# 68-)
# sentiment: True, probability: 0.9936680197715759
# 69-)
# sentiment: Fake, probability: 0.08127310127019882
# 70-)
# sentiment: True, probability: 0.993583619594574
# 71-)
# sentiment: True, probability: 0.9923725128173828
# 72-)
# sentiment: True, probability: 0.9936845898628235
# 73-)
# sentiment: Fake, probability: 0.08128323405981064
# 74-)
# sentiment: Fake, probability: 0.08126263320446014
# 75-)
# sentiment: True, probability: 0.9936959147453308
# 76-)
# sentiment: Fake, probability: 0.10014844685792923
# 77-)
# sentiment: Fake, probability: 0.2831228971481323
# 78-)
# sentiment: Fake, probability: 0.08128079771995544
# 79-)
# sentiment: Fake, probability: 0.08128385990858078
# 80-)
# sentiment: True, probability: 0.9936803579330444
# 81-)
# sentiment: Fake, probability: 0.08144441992044449
# 82-)
# sentiment: Fake, probability: 0.0813855230808258
# 83-)
# sentiment: Fake, probability: 0.08150886744260788
# 84-)
# sentiment: Fake, probability: 0.08128966391086578
# 85-)
# sentiment: True, probability: 0.9936832189559937
# 86-)
# sentiment: Fake, probability: 0.081573486328125
# 87-)
# sentiment: Fake, probability: 0.08605896681547165
# 88-)
# sentiment: Fake, probability: 0.08197294920682907
# 89-)
# sentiment: Fake, probability: 0.08127846568822861
# 90-)
# sentiment: True, probability: 0.9936802387237549
# 91-)
# sentiment: Fake, probability: 0.11611723154783249
# 92-)
# sentiment: Fake, probability: 0.08140049874782562
# 93-)
# sentiment: True, probability: 0.9936994314193726
# 94-)
# sentiment: True, probability: 0.9937029480934143
# 95-)
# sentiment: Fake, probability: 0.08128917962312698
# 96-)
# sentiment: Fake, probability: 0.08145833760499954
# 97-)
# sentiment: True, probability: 0.9935546517372131
# 98-)
# sentiment: Fake, probability: 0.21414954960346222
# 99-)
# sentiment: Fake, probability: 0.08359753340482712
# 100-)
# sentiment: True, probability: 0.9937044978141785
# 101-)
# sentiment: True, probability: 0.9936878085136414
# 102-)
# sentiment: True, probability: 0.9936879277229309
# 103-)
# sentiment: True, probability: 0.9936020970344543
# 104-)
# sentiment: Fake, probability: 0.08353005349636078
# 105-)
# sentiment: True, probability: 0.9937031865119934
# 106-)
# sentiment: True, probability: 0.9936855435371399
# 107-)
# sentiment: Fake, probability: 0.08169415593147278
# 108-)
# sentiment: Fake, probability: 0.0813124030828476
# 109-)
# sentiment: True, probability: 0.9936892986297607
# 110-)
# sentiment: True, probability: 0.9936912059783936
# 111-)
# sentiment: Fake, probability: 0.08129934966564178
# 112-)
# sentiment: True, probability: 0.9936681389808655
# 113-)
# sentiment: True, probability: 0.9936873316764832
# 114-)
# sentiment: True, probability: 0.9936755299568176
# 115-)
# sentiment: Fake, probability: 0.08131915330886841
# 116-)
# sentiment: True, probability: 0.9934887886047363
# 117-)
# sentiment: Fake, probability: 0.08365172892808914
# 118-)
# sentiment: Fake, probability: 0.08370863646268845
# 119-)
# sentiment: True, probability: 0.9936422109603882
# 120-)
# sentiment: True, probability: 0.9937019348144531
# 121-)
# sentiment: Fake, probability: 0.08317790925502777
# 122-)
# sentiment: Fake, probability: 0.08127830177545547
# 123-)
# sentiment: True, probability: 0.9936621189117432
# 124-)
# sentiment: Fake, probability: 0.08151743561029434
# 125-)
# sentiment: True, probability: 0.9936522245407104
# 126-)
# sentiment: True, probability: 0.9937039017677307
# 127-)
# sentiment: True, probability: 0.9936367273330688
# 128-)
# sentiment: True, probability: 0.9936698079109192
# 129-)
# sentiment: True, probability: 0.9937037825584412
# 130-)
# sentiment: Fake, probability: 0.08151514828205109
# 131-)
# sentiment: True, probability: 0.9936538934707642
# 132-)
# sentiment: True, probability: 0.9936927556991577
# 133-)
# sentiment: Fake, probability: 0.4864579737186432
# 134-)
# sentiment: Fake, probability: 0.08141694217920303
# 135-)
# sentiment: True, probability: 0.9936800003051758
# 136-)
# sentiment: Fake, probability: 0.08149898052215576
# 137-)
# sentiment: Fake, probability: 0.08143598586320877
# 138-)
# sentiment: Fake, probability: 0.08129621297121048
# 139-)
# sentiment: Fake, probability: 0.08127066493034363
# 140-)
# sentiment: Fake, probability: 0.08127853274345398
# 141-)
# sentiment: Fake, probability: 0.09248258918523788
# 142-)
# sentiment: True, probability: 0.993402898311615
# 143-)
# sentiment: Fake, probability: 0.08467325568199158
# 144-)
# sentiment: Fake, probability: 0.08877081423997879
# 145-)
# sentiment: True, probability: 0.9937015771865845
# 146-)
# sentiment: True, probability: 0.9936971068382263
# 147-)
# sentiment: Fake, probability: 0.08649465441703796
# 148-)
# sentiment: True, probability: 0.9937129616737366
# 149-)
# sentiment: Fake, probability: 0.0901477113366127
# 150-)
# sentiment: True, probability: 0.993684709072113
# 151-)
# sentiment: True, probability: 0.9936975836753845
# 152-)
# sentiment: True, probability: 0.9936463832855225
# 153-)
# sentiment: True, probability: 0.9936987161636353
# 154-)
# sentiment: True, probability: 0.9936628341674805
# 155-)
# sentiment: True, probability: 0.9936484694480896
# 156-)
# sentiment: True, probability: 0.993697464466095
# 157-)
# sentiment: Fake, probability: 0.08130060881376266
# 158-)
# sentiment: True, probability: 0.99363774061203
# 159-)
# sentiment: True, probability: 0.9937012195587158
# 160-)
# sentiment: Fake, probability: 0.08125901222229004
# 161-)
# sentiment: Fake, probability: 0.08126271516084671
# 162-)
# sentiment: True, probability: 0.9936755299568176
# 163-)
# sentiment: Fake, probability: 0.08184560388326645
# 164-)
# sentiment: Fake, probability: 0.08418460935354233
# 165-)
# sentiment: True, probability: 0.993626594543457
# 166-)
# sentiment: True, probability: 0.9936752915382385
# 167-)
# sentiment: True, probability: 0.993381142616272
# 168-)
# sentiment: True, probability: 0.9936787486076355
# 169-)
# sentiment: Fake, probability: 0.08188049495220184
# 170-)
# sentiment: Fake, probability: 0.1084132194519043
# 171-)
# sentiment: True, probability: 0.9936886429786682
# 172-)
# sentiment: Fake, probability: 0.08506747335195541
# 173-)
# sentiment: True, probability: 0.993707537651062
# 174-)
# sentiment: Fake, probability: 0.08143100887537003
# 175-)
# sentiment: True, probability: 0.9937098026275635
# 176-)
# sentiment: Fake, probability: 0.08129247277975082
# 177-)
# sentiment: True, probability: 0.9937042593955994
# 178-)
# sentiment: True, probability: 0.9936664700508118
# 179-)
# sentiment: Fake, probability: 0.08204745501279831
# 180-)
# sentiment: True, probability: 0.9937007427215576
# 181-)
# sentiment: Fake, probability: 0.08226610720157623
# 182-)
# sentiment: True, probability: 0.9936676621437073
# 183-)
# sentiment: Fake, probability: 0.08948777616024017
# 184-)
# sentiment: True, probability: 0.9936297535896301
# 185-)
# sentiment: Fake, probability: 0.08221142739057541
# 186-)
# sentiment: True, probability: 0.9936956763267517
# 187-)
# sentiment: True, probability: 0.9936267137527466
# 188-)
# sentiment: True, probability: 0.9935617446899414
# 189-)
# sentiment: Fake, probability: 0.09155534952878952
# 190-)
# sentiment: True, probability: 0.9936985969543457
# 191-)
# sentiment: True, probability: 0.9936878085136414
# 192-)
# sentiment: Fake, probability: 0.08132904022932053
# 193-)
# sentiment: Fake, probability: 0.0840296596288681
# 194-)
# sentiment: True, probability: 0.9935755133628845
# 195-)
# sentiment: True, probability: 0.9936927556991577
# 196-)
# sentiment: Fake, probability: 0.09266552329063416
# 197-)
# sentiment: Fake, probability: 0.08196444809436798
# 198-)
# sentiment: Fake, probability: 0.08553428202867508
# 199-)
# sentiment: True, probability: 0.9936591982841492
# 200-)
# sentiment: Fake, probability: 0.0856463760137558
# 201-)
# sentiment: Fake, probability: 0.08450625091791153
# 202-)
# sentiment: True, probability: 0.9936542510986328
# 203-)
# sentiment: Fake, probability: 0.08994811773300171
# 204-)
# sentiment: Fake, probability: 0.08126683533191681
# 205-)
# sentiment: True, probability: 0.9937014579772949
# 206-)
# sentiment: Fake, probability: 0.08127956837415695
# 207-)
# sentiment: True, probability: 0.9935622215270996
# 208-)
# sentiment: True, probability: 0.9936609268188477
# 209-)
# sentiment: True, probability: 0.9933130145072937
# 210-)
# sentiment: True, probability: 0.9936392903327942
# 211-)
# sentiment: True, probability: 0.9937096834182739
# 212-)
# sentiment: True, probability: 0.9937151074409485
# 213-)
# sentiment: True, probability: 0.9935954213142395
# 214-)
# sentiment: Fake, probability: 0.09015771001577377
# 215-)
# sentiment: Fake, probability: 0.08203330636024475
# 216-)
# sentiment: Fake, probability: 0.08131026476621628
# 217-)
# sentiment: True, probability: 0.993704617023468
# 218-)
# sentiment: True, probability: 0.9936819076538086
# 219-)
# sentiment: True, probability: 0.993693470954895
# 220-)
# sentiment: True, probability: 0.9937011003494263
# 221-)
# sentiment: Fake, probability: 0.08157007396221161
# 222-)
# sentiment: True, probability: 0.99369215965271
# 223-)
# sentiment: True, probability: 0.9936813116073608
# 224-)
# sentiment: True, probability: 0.9936676621437073
# 225-)
# sentiment: Fake, probability: 0.08191139250993729
# 226-)
# sentiment: Fake, probability: 0.08143366128206253
# 227-)
# sentiment: Fake, probability: 0.08255019038915634
# 228-)
# sentiment: True, probability: 0.9936838150024414
# 229-)
# sentiment: Fake, probability: 0.08148422092199326
# 230-)
# sentiment: True, probability: 0.9937031865119934
# 231-)
# sentiment: True, probability: 0.9937067627906799
# 232-)
# sentiment: Fake, probability: 0.08147677779197693
# 233-)
# sentiment: True, probability: 0.9936829805374146
# 234-)
# sentiment: Fake, probability: 0.08227577805519104
# 235-)
# sentiment: True, probability: 0.9937001466751099
# 236-)
# sentiment: True, probability: 0.9936918020248413
# 237-)
# sentiment: Fake, probability: 0.08138754218816757
# 238-)
# sentiment: Fake, probability: 0.08560159802436829
# 239-)
# sentiment: True, probability: 0.9935125708580017
# 240-)
# sentiment: True, probability: 0.9936975836753845
# 241-)
# sentiment: True, probability: 0.9929183125495911
# 242-)
# sentiment: True, probability: 0.9934843182563782
# 243-)
# sentiment: Fake, probability: 0.08127669990062714
# 244-)
# sentiment: Fake, probability: 0.08283524215221405
# 245-)
# sentiment: Fake, probability: 0.08376559615135193
# 246-)
# sentiment: Fake, probability: 0.085431769490242
# 247-)
# sentiment: Fake, probability: 0.08129776269197464
# 248-)
# sentiment: True, probability: 0.9936876893043518
# 249-)
# sentiment: Fake, probability: 0.09345488995313644
# 250-)
# sentiment: True, probability: 0.9936527013778687
# 251-)
# sentiment: Fake, probability: 0.08324815332889557
# 252-)
# sentiment: Fake, probability: 0.08733432739973068
# 253-)
# sentiment: True, probability: 0.9937029480934143
# 254-)
# sentiment: Fake, probability: 0.08136454969644547
# 255-)
# sentiment: True, probability: 0.9936768412590027
# 256-)
# sentiment: Fake, probability: 0.11071685701608658
# 257-)
# sentiment: Fake, probability: 0.0823369026184082
# 258-)
# sentiment: True, probability: 0.9937035441398621
# 259-)
# sentiment: True, probability: 0.9936656355857849
# 260-)
# sentiment: True, probability: 0.9936820268630981
# 261-)
# sentiment: Fake, probability: 0.10136175155639648
# 262-)
# sentiment: Fake, probability: 0.08311000466346741
# 263-)
# sentiment: True, probability: 0.9937044978141785
# 264-)
# sentiment: True, probability: 0.9936811923980713
# 265-)
# sentiment: True, probability: 0.9936942458152771
# 266-)
# sentiment: Fake, probability: 0.08132889866828918
# 267-)
# sentiment: True, probability: 0.9936648607254028
# 268-)
# sentiment: True, probability: 0.993695080280304
# 269-)
# sentiment: True, probability: 0.9936036467552185
# 270-)
# sentiment: True, probability: 0.9930877089500427
# 271-)
# sentiment: Fake, probability: 0.08245670050382614
# 272-)
# sentiment: Fake, probability: 0.0934431329369545
# 273-)
# sentiment: Fake, probability: 0.08139342069625854
# 274-)
# sentiment: True, probability: 0.993683934211731
# 275-)
# sentiment: Fake, probability: 0.3394045829772949
# 276-)
# sentiment: True, probability: 0.9936553239822388
# 277-)
# sentiment: Fake, probability: 0.08126965165138245
# 278-)
# sentiment: True, probability: 0.993661642074585
# 279-)
# sentiment: Fake, probability: 0.08130764216184616
# 280-)
# sentiment: Fake, probability: 0.10469045490026474
# 281-)
# sentiment: Fake, probability: 0.0820121318101883
# 282-)
# sentiment: True, probability: 0.9936683773994446
# 283-)
# sentiment: True, probability: 0.9936214089393616
# 284-)
# sentiment: True, probability: 0.993634819984436
# 285-)
# sentiment: True, probability: 0.9935805797576904
# 286-)
# sentiment: Fake, probability: 0.08126438409090042
# 287-)
# sentiment: True, probability: 0.9937103986740112
# 288-)
# sentiment: Fake, probability: 0.588807225227356
# 289-)
# sentiment: True, probability: 0.9936901330947876
# 290-)
# sentiment: True, probability: 0.9936915636062622
# 291-)
# sentiment: Fake, probability: 0.0843917652964592
# 292-)
# sentiment: True, probability: 0.993687093257904
# 293-)
# sentiment: True, probability: 0.9935947060585022
# 294-)
# sentiment: Fake, probability: 0.5222466588020325
# 295-)
# sentiment: True, probability: 0.9936991930007935
# 296-)
# sentiment: True, probability: 0.9936529397964478
# 297-)
# sentiment: Fake, probability: 0.0928107351064682
# 298-)
# sentiment: Fake, probability: 0.0834943950176239
# 299-)
# sentiment: True, probability: 0.9936627149581909
# 300-)
# sentiment: Fake, probability: 0.0854431539773941
# 301-)
# sentiment: Fake, probability: 0.08881116658449173
# 302-)
# sentiment: Fake, probability: 0.08134753257036209
# 303-)
# sentiment: Fake, probability: 0.08132025599479675
# 304-)
# sentiment: Fake, probability: 0.08127782493829727
# 305-)
# sentiment: Fake, probability: 0.6049332618713379
# 306-)
# sentiment: True, probability: 0.9936739206314087
# 307-)
# sentiment: True, probability: 0.9937074780464172
# 308-)
# sentiment: True, probability: 0.9936655163764954
# 309-)
# sentiment: True, probability: 0.9937166571617126
# 310-)
# sentiment: True, probability: 0.9936030507087708
# 311-)
# sentiment: Fake, probability: 0.0835922360420227
# 312-)
# sentiment: True, probability: 0.9936715364456177
# 313-)
# sentiment: Fake, probability: 0.08139544725418091
# 314-)
# sentiment: True, probability: 0.9936234354972839
# 315-)
# sentiment: True, probability: 0.9936946034431458
# 316-)
# sentiment: True, probability: 0.9935005307197571
# 317-)
# sentiment: True, probability: 0.736994206905365
# 318-)
# sentiment: True, probability: 0.993661642074585
# 319-)
# sentiment: Fake, probability: 0.08202198147773743
# 320-)
# sentiment: True, probability: 0.9936797618865967
# 321-)
# sentiment: True, probability: 0.993629515171051
# 322-)
# sentiment: Fake, probability: 0.08239860087633133
# 323-)
# sentiment: True, probability: 0.9936984777450562
# 324-)
# sentiment: Fake, probability: 0.19179067015647888
# 325-)
# sentiment: True, probability: 0.9932565689086914
# 326-)
# sentiment: True, probability: 0.838619589805603
# 327-)
# sentiment: True, probability: 0.9937037825584412
# 328-)
# sentiment: True, probability: 0.993685781955719
# 329-)
# sentiment: Fake, probability: 0.08134566247463226
# 330-)
# sentiment: True, probability: 0.9936873316764832
# 331-)
# sentiment: True, probability: 0.9936979413032532
# 332-)
# sentiment: Fake, probability: 0.12150254845619202
# 333-)
# sentiment: Fake, probability: 0.08298563957214355
# 334-)
# sentiment: Fake, probability: 0.443775475025177
# 335-)
# sentiment: Fake, probability: 0.08192478865385056
# 336-)
# sentiment: True, probability: 0.9936431646347046
# 337-)
# sentiment: True, probability: 0.9936538934707642
# 338-)
# sentiment: Fake, probability: 0.08131074905395508
# 339-)
# sentiment: True, probability: 0.9936385750770569
# 340-)
# sentiment: Fake, probability: 0.10055030882358551
# 341-)
# sentiment: True, probability: 0.9937039017677307
# 342-)
# sentiment: Fake, probability: 0.10925698280334473
# 343-)
# sentiment: Fake, probability: 0.08131999522447586
# 344-)
# sentiment: True, probability: 0.9936822652816772
# 345-)
# sentiment: Fake, probability: 0.0820077657699585
# 346-)
# sentiment: Fake, probability: 0.08132093399763107
# 347-)
# sentiment: True, probability: 0.993607759475708
# 348-)
# sentiment: True, probability: 0.9936832189559937
# 349-)
# sentiment: True, probability: 0.993705689907074
# 350-)
# sentiment: Fake, probability: 0.08126594871282578
# 351-)
# sentiment: True, probability: 0.993687093257904
# 352-)
# sentiment: True, probability: 0.9722461700439453
# 353-)
# sentiment: Fake, probability: 0.08139170706272125
# 354-)
# sentiment: True, probability: 0.9935362935066223
# 355-)
# sentiment: True, probability: 0.9936078786849976
# 356-)
# sentiment: Fake, probability: 0.08504018187522888
# 357-)
# sentiment: True, probability: 0.9937014579772949
# 358-)
# sentiment: Fake, probability: 0.08161365240812302
# 359-)
# sentiment: True, probability: 0.9273251295089722
# 360-)
# sentiment: True, probability: 0.993556797504425
# 361-)
# sentiment: Fake, probability: 0.2506010830402374
# 362-)
# sentiment: True, probability: 0.9936415553092957
# 363-)
# sentiment: True, probability: 0.9936882853507996
# 364-)
# sentiment: Fake, probability: 0.12472105026245117
# 365-)
# sentiment: True, probability: 0.9936224818229675
# 366-)
# sentiment: Fake, probability: 0.0813860222697258
# 367-)
# sentiment: Fake, probability: 0.08128228783607483
# 368-)
# sentiment: True, probability: 0.9936741590499878
# 369-)
# sentiment: Fake, probability: 0.21986261010169983
# 370-)
# sentiment: True, probability: 0.9936664700508118
# 371-)
# sentiment: True, probability: 0.9932363629341125
# 372-)
# sentiment: True, probability: 0.9937029480934143
# 373-)
# sentiment: Fake, probability: 0.08133257925510406
# 374-)
# sentiment: Fake, probability: 0.08190389722585678
# 375-)
# sentiment: Fake, probability: 0.08164798468351364
# 376-)
# sentiment: Fake, probability: 0.08126316964626312
# 377-)
# sentiment: True, probability: 0.993696391582489
# 378-)
# sentiment: Fake, probability: 0.08143030852079391
# 379-)
# sentiment: Fake, probability: 0.08127831667661667
# 380-)
# sentiment: True, probability: 0.9936509728431702
# 381-)
# sentiment: True, probability: 0.9935157299041748
# 382-)
# sentiment: Fake, probability: 0.13369068503379822
# 383-)
# sentiment: True, probability: 0.9936869740486145
# 384-)
# sentiment: True, probability: 0.9936172962188721
# 385-)
# sentiment: True, probability: 0.993698239326477
# 386-)
# sentiment: True, probability: 0.8862313032150269
# 387-)
# sentiment: True, probability: 0.9935556054115295
# 388-)
# sentiment: Fake, probability: 0.08131381124258041
# 389-)
# sentiment: Fake, probability: 0.09362144768238068
# 390-)
# sentiment: True, probability: 0.9936907291412354
# 391-)
# sentiment: Fake, probability: 0.08127991110086441
# 392-)
# sentiment: True, probability: 0.9935339689254761
# 393-)
# sentiment: True, probability: 0.9937034249305725
# 394-)
# sentiment: True, probability: 0.7874213457107544
# 395-)
# sentiment: Fake, probability: 0.08127611875534058
# 396-)
# sentiment: Fake, probability: 0.08134999126195908
# 397-)
# sentiment: True, probability: 0.9752607941627502
# 398-)
# sentiment: Fake, probability: 0.08170302957296371
# 399-)
# sentiment: True, probability: 0.9935812950134277
# 400-)
# sentiment: Fake, probability: 0.09399176388978958
# 401-)
# sentiment: Fake, probability: 0.08131382614374161
# 402-)
# sentiment: Fake, probability: 0.08128907531499863
# 403-)
# sentiment: True, probability: 0.9936957955360413
# 404-)
# sentiment: Fake, probability: 0.08172670006752014
# 405-)
# sentiment: True, probability: 0.9936987161636353
# 406-)
# sentiment: True, probability: 0.9936933517456055
# 407-)
# sentiment: True, probability: 0.9935412406921387
# 408-)
# sentiment: True, probability: 0.9936099648475647
# 409-)
# sentiment: Fake, probability: 0.08376181125640869
# 410-)
# sentiment: True, probability: 0.9934725761413574
# 411-)
# sentiment: Fake, probability: 0.08139784634113312
# 412-)
# sentiment: Fake, probability: 0.09246287494897842
# 413-)
# sentiment: True, probability: 0.9936444759368896
# 414-)
# sentiment: True, probability: 0.9936922788619995
# 415-)
# sentiment: True, probability: 0.9936715364456177
# 416-)
# sentiment: Fake, probability: 0.08152889460325241
# 417-)
# sentiment: True, probability: 0.9936597943305969
# 418-)
# sentiment: Fake, probability: 0.08126369118690491
# 419-)
# sentiment: Fake, probability: 0.08172682672739029
# 420-)
# sentiment: True, probability: 0.993708610534668
# 421-)
# sentiment: Fake, probability: 0.09070504456758499
# 422-)
# sentiment: True, probability: 0.9936215281486511
# 423-)
# sentiment: True, probability: 0.9936994314193726
# 424-)
# sentiment: Fake, probability: 0.08134443312883377
# 425-)
# sentiment: True, probability: 0.9929457306861877
# 426-)
# sentiment: True, probability: 0.9936936497688293
# 427-)
# sentiment: True, probability: 0.9936979413032532
# 428-)
# sentiment: True, probability: 0.9937014579772949
# 429-)
# sentiment: True, probability: 0.9936803579330444
# 430-)
# sentiment: True, probability: 0.9936954379081726
# 431-)
# sentiment: True, probability: 0.993545413017273
# 432-)
# sentiment: True, probability: 0.99354088306427
# 433-)
# sentiment: True, probability: 0.9936805963516235
# 434-)
# sentiment: True, probability: 0.9936224818229675
# 435-)
# sentiment: Fake, probability: 0.10342136025428772
# 436-)
# sentiment: Fake, probability: 0.08180160820484161
# 437-)
# sentiment: Fake, probability: 0.08267956972122192
# 438-)
# sentiment: Fake, probability: 0.08150501549243927
# 439-)
# sentiment: True, probability: 0.9937006235122681
# 440-)
# sentiment: Fake, probability: 0.2660597264766693
# 441-)
# sentiment: Fake, probability: 0.08518356084823608
# 442-)
# sentiment: Fake, probability: 0.08131072670221329
# 443-)
# sentiment: Fake, probability: 0.08127164095640182
# 444-)
# sentiment: Fake, probability: 0.08243265748023987
# 445-)
# sentiment: Fake, probability: 0.08334961533546448
# 446-)
# sentiment: Fake, probability: 0.08127504587173462
# 447-)
# sentiment: True, probability: 0.9937066435813904
# 448-)
# sentiment: True, probability: 0.9937009811401367
# 449-)
# sentiment: Fake, probability: 0.08130679279565811
# 450-)
# sentiment: Fake, probability: 0.2578902840614319
# 451-)
# sentiment: True, probability: 0.9928183555603027
# 452-)
# sentiment: True, probability: 0.9937012195587158
# 453-)
# sentiment: Fake, probability: 0.0862816646695137
# 454-)
# sentiment: Fake, probability: 0.11892664432525635
# 455-)
# sentiment: Fake, probability: 0.08144265413284302
# 456-)
# sentiment: True, probability: 0.993579626083374
# 457-)
# sentiment: True, probability: 0.9937189817428589
# 458-)
# sentiment: True, probability: 0.9936836957931519
# 459-)
# sentiment: Fake, probability: 0.08495581895112991
# 460-)
# sentiment: Fake, probability: 0.08462619036436081
# 461-)
# sentiment: Fake, probability: 0.10668280720710754
# 462-)
# sentiment: Fake, probability: 0.0815013200044632
# 463-)
# sentiment: Fake, probability: 0.08156301826238632
# 464-)
# sentiment: Fake, probability: 0.12634766101837158
# 465-)
# sentiment: Fake, probability: 0.08142516016960144
# 466-)
# sentiment: Fake, probability: 0.08136752247810364
# 467-)
# sentiment: Fake, probability: 0.08132053911685944
# 468-)
# sentiment: True, probability: 0.9936615228652954
# 469-)
# sentiment: Fake, probability: 0.15199987590312958
# 470-)
# sentiment: Fake, probability: 0.08127301931381226
# 471-)
# sentiment: True, probability: 0.9936874508857727
# 472-)
# sentiment: True, probability: 0.9937072396278381
# 473-)
# sentiment: Fake, probability: 0.08130893111228943
# 474-)
# sentiment: True, probability: 0.9936844706535339
# 475-)
# sentiment: True, probability: 0.9936659932136536
# 476-)
# sentiment: Fake, probability: 0.08146211504936218
# 477-)
# sentiment: Fake, probability: 0.08276727050542831
# 478-)
# sentiment: True, probability: 0.9935775995254517
# 479-)
# sentiment: Fake, probability: 0.09707185626029968
# 480-)
# sentiment: True, probability: 0.9937071204185486
# 481-)
# sentiment: Fake, probability: 0.10308461636304855
# 482-)
# sentiment: True, probability: 0.9936841130256653
# 483-)
# sentiment: True, probability: 0.9937001466751099
# 484-)
# sentiment: Fake, probability: 0.11288892477750778
# 485-)
# sentiment: Fake, probability: 0.08130045235157013
# 486-)
# sentiment: True, probability: 0.9936664700508118
# 487-)
# sentiment: Fake, probability: 0.08129796385765076
# 488-)
# sentiment: Fake, probability: 0.08155597001314163
# 489-)
# sentiment: Fake, probability: 0.16586659848690033
# 490-)
# sentiment: Fake, probability: 0.08141572773456573
# 491-)
# sentiment: True, probability: 0.9936793446540833
# 492-)
# sentiment: Fake, probability: 0.08987404406070709
# 493-)
# sentiment: True, probability: 0.9937012195587158
# 494-)
# sentiment: True, probability: 0.9936374425888062
# 495-)
# sentiment: True, probability: 0.9937019348144531
# 496-)
# sentiment: Fake, probability: 0.0991172343492508
# 497-)
# sentiment: Fake, probability: 0.08142463862895966
# 498-)
# sentiment: True, probability: 0.9936769604682922
# 499-)
# sentiment: True, probability: 0.9936169385910034
# 500-)
# sentiment: True, probability: 0.993704617023468
# 501-)
# sentiment: Fake, probability: 0.10295315086841583
# 502-)
# sentiment: Fake, probability: 0.0812801718711853
# 503-)
# sentiment: Fake, probability: 0.08127319067716599
# 504-)
# sentiment: True, probability: 0.9935247898101807
# 505-)
# sentiment: Fake, probability: 0.08135606348514557
# 506-)
# sentiment: True, probability: 0.9936983585357666
# 507-)
# sentiment: True, probability: 0.9936988353729248
# 508-)
# sentiment: Fake, probability: 0.11575623601675034
# 509-)
# sentiment: Fake, probability: 0.08132531493902206
# 510-)
# sentiment: Fake, probability: 0.0822853222489357
# 511-)
# sentiment: True, probability: 0.9936803579330444
# 512-)
# sentiment: Fake, probability: 0.08343275636434555
# 513-)
# sentiment: Fake, probability: 0.0926414504647255
# 514-)
# sentiment: Fake, probability: 0.3713113069534302
# 515-)
# sentiment: True, probability: 0.9936017394065857
# 516-)
# sentiment: True, probability: 0.9936891794204712
# 517-)
# sentiment: True, probability: 0.9936985969543457
# 518-)
# sentiment: True, probability: 0.9937065243721008
# 519-)
# sentiment: True, probability: 0.9936848282814026
# 520-)
# sentiment: True, probability: 0.9937102794647217
# 521-)
# sentiment: True, probability: 0.9937137961387634
# 522-)
# sentiment: Fake, probability: 0.2506010830402374
# 523-)
# sentiment: True, probability: 0.9936792254447937
# 524-)
# sentiment: Fake, probability: 0.08138515055179596
# 525-)
# sentiment: Fake, probability: 0.08129893988370895
# 526-)
# sentiment: True, probability: 0.9936760067939758
# 527-)
# sentiment: Fake, probability: 0.09469735622406006
# 528-)
# sentiment: Fake, probability: 0.08176456391811371
# 529-)
# sentiment: True, probability: 0.993671178817749
# 530-)
# sentiment: True, probability: 0.9936457872390747
# 531-)
# sentiment: True, probability: 0.9936915636062622
# 532-)
# sentiment: True, probability: 0.9936755299568176
# 533-)
# sentiment: True, probability: 0.9936927556991577
# 534-)
# sentiment: Fake, probability: 0.09203091263771057
# 535-)
# sentiment: Fake, probability: 0.08156823366880417
# 536-)
# sentiment: True, probability: 0.9936131834983826
# 537-)
# sentiment: True, probability: 0.9936710596084595
# 538-)
# sentiment: Fake, probability: 0.08125756680965424
# 539-)
# sentiment: Fake, probability: 0.08128239959478378
# 540-)
# sentiment: True, probability: 0.9936861395835876
# 541-)
# sentiment: True, probability: 0.9936962723731995
# 542-)
# sentiment: True, probability: 0.9937021732330322
# 543-)
# sentiment: True, probability: 0.9937037825584412
# 544-)
# sentiment: True, probability: 0.9936439990997314
# 545-)
# sentiment: Fake, probability: 0.08128642290830612
# 546-)
# sentiment: Fake, probability: 0.49713853001594543
# 547-)
# sentiment: True, probability: 0.9937012195587158
# 548-)
# sentiment: Fake, probability: 0.08331147581338882
# 549-)
# sentiment: Fake, probability: 0.0821162760257721
# 550-)
# sentiment: Fake, probability: 0.08126279711723328
# 551-)
# sentiment: Fake, probability: 0.08597182482481003
# 552-)
# sentiment: True, probability: 0.9936863780021667
# 553-)
# sentiment: Fake, probability: 0.0827852115035057
# 554-)
# sentiment: Fake, probability: 0.08127258718013763
# 555-)
# sentiment: Fake, probability: 0.08137579262256622
# 556-)
# sentiment: True, probability: 0.9936832189559937
# 557-)
# sentiment: Fake, probability: 0.2842690944671631
# 558-)
# sentiment: Fake, probability: 0.0814557820558548
# 559-)
# sentiment: True, probability: 0.9936768412590027
# 560-)
# sentiment: Fake, probability: 0.08141177147626877
# 561-)
# sentiment: True, probability: 0.9936929941177368
# 562-)
# sentiment: True, probability: 0.9935542345046997
# 563-)
# sentiment: True, probability: 0.9935810565948486
# 564-)
# sentiment: True, probability: 0.9936699271202087
# 565-)
# sentiment: Fake, probability: 0.08133564889431
# 566-)
# sentiment: Fake, probability: 0.0856296643614769
# 567-)
# sentiment: True, probability: 0.993700385093689
# 568-)
# sentiment: Fake, probability: 0.08126980811357498
# 569-)
# sentiment: Fake, probability: 0.08140292763710022
# 570-)
# sentiment: True, probability: 0.9937042593955994
# 571-)
# sentiment: True, probability: 0.9936063289642334
# 572-)
# sentiment: Fake, probability: 0.1565033346414566
# 573-)
# sentiment: True, probability: 0.9936794638633728
# 574-)
# sentiment: True, probability: 0.9935672879219055
# 575-)
# sentiment: True, probability: 0.9936417937278748
# 576-)
# sentiment: True, probability: 0.9936810731887817
# 577-)
# sentiment: Fake, probability: 0.0812741369009018
# 578-)
# sentiment: Fake, probability: 0.08153273165225983
# 579-)
# sentiment: True, probability: 0.9936933517456055
# 580-)
# sentiment: True, probability: 0.9935637712478638
# 581-)
# sentiment: True, probability: 0.9935916066169739
# 582-)
# sentiment: Fake, probability: 0.0825827494263649
# 583-)
# sentiment: True, probability: 0.993685781955719
# 584-)
# sentiment: True, probability: 0.9937119483947754
# 585-)
# sentiment: True, probability: 0.9936935305595398
# 586-)
# sentiment: True, probability: 0.9936599135398865
# 587-)
# sentiment: True, probability: 0.9933037161827087
# 588-)
# sentiment: True, probability: 0.9935122132301331
# 589-)
# sentiment: True, probability: 0.9937007427215576
# 590-)
# sentiment: Fake, probability: 0.23418235778808594
# 591-)
# sentiment: True, probability: 0.993685781955719
# 592-)
# sentiment: True, probability: 0.9936599135398865
# 593-)
# sentiment: Fake, probability: 0.08266577124595642
# 594-)
# sentiment: True, probability: 0.9935146570205688
# 595-)
# sentiment: Fake, probability: 0.08132989704608917
# 596-)
# sentiment: True, probability: 0.9937115907669067
# 597-)
# sentiment: True, probability: 0.9931240677833557
# 598-)
# sentiment: Fake, probability: 0.08127189427614212
# 599-)
# sentiment: Fake, probability: 0.08126334846019745
# 600-)
# sentiment: Fake, probability: 0.08701568841934204
# 601-)
# sentiment: True, probability: 0.9933812618255615
# 602-)
# sentiment: True, probability: 0.9936915636062622
# 603-)
# sentiment: True, probability: 0.9936891794204712
# 604-)
# sentiment: Fake, probability: 0.08137479424476624
# 605-)
# sentiment: Fake, probability: 0.21361574530601501
# 606-)
# sentiment: True, probability: 0.9937090873718262
# 607-)
# sentiment: Fake, probability: 0.08130070567131042
# 608-)
# sentiment: True, probability: 0.9935815334320068
# 609-)
# sentiment: True, probability: 0.9936880469322205
# 610-)
# sentiment: Fake, probability: 0.08127792924642563
# 611-)
# sentiment: Fake, probability: 0.08141355216503143
# 612-)
# sentiment: True, probability: 0.9936366081237793
# 613-)
# sentiment: Fake, probability: 0.08743380755186081
# 614-)
# sentiment: Fake, probability: 0.08332185447216034
# 615-)
# sentiment: True, probability: 0.9936042428016663
# 616-)
# sentiment: True, probability: 0.9936792254447937
# 617-)
# sentiment: True, probability: 0.9937001466751099
# 618-)
# sentiment: True, probability: 0.9936980605125427
# 619-)
# sentiment: True, probability: 0.993658721446991
# 620-)
# sentiment: Fake, probability: 0.0813584178686142
# 621-)
# sentiment: Fake, probability: 0.08124992996454239
# 622-)
# sentiment: Fake, probability: 0.0814608633518219
# 623-)
# sentiment: Fake, probability: 0.08127467334270477
# 624-)
# sentiment: Fake, probability: 0.0812796950340271
# 625-)
# sentiment: Fake, probability: 0.08134081214666367
# 626-)
# sentiment: Fake, probability: 0.08129945397377014
# 627-)
# sentiment: Fake, probability: 0.17767848074436188
# 628-)
# sentiment: Fake, probability: 0.084813691675663
# 629-)
# sentiment: True, probability: 0.9937164187431335
# 630-)
# sentiment: True, probability: 0.9936532974243164
# 631-)
# sentiment: Fake, probability: 0.08159313350915909
# 632-)
# sentiment: Fake, probability: 0.08207037299871445
# 633-)
# sentiment: Fake, probability: 0.12387914210557938
# 634-)
# sentiment: True, probability: 0.9936866164207458
# 635-)
# sentiment: Fake, probability: 0.1142340824007988
# 636-)
# sentiment: True, probability: 0.9936703443527222
# 637-)
# sentiment: True, probability: 0.9936757683753967
# 638-)
# sentiment: Fake, probability: 0.08176083862781525
# 639-)
# sentiment: Fake, probability: 0.20948389172554016
# 640-)
# sentiment: True, probability: 0.9936798810958862
# 641-)
# sentiment: Fake, probability: 0.08176083862781525
# 642-)
# sentiment: Fake, probability: 0.08148748427629471
# 643-)
# sentiment: Fake, probability: 0.08163297176361084
# 644-)
# sentiment: Fake, probability: 0.08130408078432083
# 645-)
# sentiment: True, probability: 0.9936932325363159
# 646-)
# sentiment: Fake, probability: 0.08126883208751678
# 647-)
# sentiment: Fake, probability: 0.08492277562618256
# 648-)
# sentiment: Fake, probability: 0.08185084909200668
# 649-)
# sentiment: True, probability: 0.9936686158180237
# 650-)
# sentiment: Fake, probability: 0.0815565213561058
# 651-)
# sentiment: True, probability: 0.993672251701355
# 652-)
# sentiment: True, probability: 0.9937068819999695
# 653-)
# sentiment: Fake, probability: 0.08133673667907715
# 654-)
# sentiment: True, probability: 0.9932363629341125
# 655-)
# sentiment: True, probability: 0.9936873316764832
# 656-)
# sentiment: Fake, probability: 0.0814775675535202
# 657-)
# sentiment: True, probability: 0.9936821460723877
# 658-)
# sentiment: Fake, probability: 0.08128499984741211
# 659-)
# sentiment: True, probability: 0.9936761260032654
# 660-)
# sentiment: Fake, probability: 0.08143360912799835
# 661-)
# sentiment: Fake, probability: 0.08127447962760925
# 662-)
# sentiment: True, probability: 0.9936908483505249
# 663-)
# sentiment: True, probability: 0.9935402274131775
# 664-)
# sentiment: Fake, probability: 0.08132077753543854
# 665-)
# sentiment: True, probability: 0.9936988353729248
# 666-)
# sentiment: Fake, probability: 0.08152629435062408
# 667-)
# sentiment: True, probability: 0.9936869740486145
# 668-)
# sentiment: Fake, probability: 0.08134537935256958
# 669-)
# sentiment: Fake, probability: 0.08153396844863892
# 670-)
# sentiment: True, probability: 0.9936044812202454
# 671-)
# sentiment: Fake, probability: 0.08742465078830719
# 672-)
# sentiment: Fake, probability: 0.08140960335731506
# 673-)
# sentiment: Fake, probability: 0.08133426308631897
# 674-)
# sentiment: Fake, probability: 0.08146896958351135
# 675-)
# sentiment: Fake, probability: 0.08131420612335205
# 676-)
# sentiment: True, probability: 0.9936955571174622
# 677-)
# sentiment: True, probability: 0.9933916330337524
# 678-)
# sentiment: Fake, probability: 0.08508603274822235
# 679-)
# sentiment: Fake, probability: 0.08134181052446365
# 680-)
# sentiment: Fake, probability: 0.13622239232063293
# 681-)
# sentiment: True, probability: 0.9937073588371277
# 682-)
# sentiment: Fake, probability: 0.0812956839799881
# 683-)
# sentiment: Fake, probability: 0.09592046588659286
# 684-)
# sentiment: Fake, probability: 0.2668836712837219
# 685-)
# sentiment: Fake, probability: 0.0813193991780281
# 686-)
# sentiment: True, probability: 0.9053300619125366
# 687-)
# sentiment: Fake, probability: 0.09971550852060318
# 688-)
# sentiment: Fake, probability: 0.0813334584236145
# 689-)
# sentiment: Fake, probability: 0.10934579372406006
# 690-)
# sentiment: True, probability: 0.9936690926551819
# 691-)
# sentiment: True, probability: 0.9937102794647217
# 692-)
# sentiment: Fake, probability: 0.0831843838095665
# 693-)
# sentiment: True, probability: 0.9936009049415588
# 694-)
# sentiment: True, probability: 0.9937012195587158
# 695-)
# sentiment: Fake, probability: 0.08196331560611725
# 696-)
# sentiment: True, probability: 0.9936406016349792
# 697-)
# sentiment: True, probability: 0.9936942458152771
# 698-)
# sentiment: True, probability: 0.9935623407363892
# 699-)
# sentiment: True, probability: 0.9936468601226807
# 700-)
# sentiment: True, probability: 0.9936483502388
# 701-)
# sentiment: True, probability: 0.9933916330337524
# 702-)
# sentiment: True, probability: 0.9937034249305725
# 703-)
# sentiment: Fake, probability: 0.08158309757709503
# 704-)
# sentiment: Fake, probability: 0.08130420744419098
# 705-)
# sentiment: Fake, probability: 0.1522071808576584
# 706-)
# sentiment: True, probability: 0.9937065243721008
# 707-)
# sentiment: Fake, probability: 0.08208034187555313
# 708-)
# sentiment: Fake, probability: 0.08134114742279053
# 709-)
# sentiment: True, probability: 0.9937093257904053
# 710-)
# sentiment: Fake, probability: 0.08136922121047974
# 711-)
# sentiment: Fake, probability: 0.08172842860221863
# 712-)
# sentiment: True, probability: 0.9935810565948486
# 713-)
# sentiment: Fake, probability: 0.0813290923833847
# 714-)
# sentiment: Fake, probability: 0.09667972475290298
# 715-)
# sentiment: Fake, probability: 0.21090148389339447
# 716-)
# sentiment: Fake, probability: 0.08176171779632568
# 717-)
# sentiment: True, probability: 0.9936823844909668
# 718-)
# sentiment: Fake, probability: 0.08137019723653793
# 719-)
# sentiment: True, probability: 0.9936931133270264
# 720-)
# sentiment: Fake, probability: 0.13711391389369965
# 721-)
# sentiment: True, probability: 0.9936988353729248
# 722-)
# sentiment: True, probability: 0.9934014678001404
# 723-)
# sentiment: True, probability: 0.9933850169181824
# 724-)
# sentiment: True, probability: 0.9937022924423218
# 725-)
# sentiment: True, probability: 0.9936246871948242
# 726-)
# sentiment: Fake, probability: 0.0814172625541687
# 727-)
# sentiment: Fake, probability: 0.08130479604005814
# 728-)
# sentiment: Fake, probability: 0.10110402852296829
# 729-)
# sentiment: Fake, probability: 0.08560103178024292
# 730-)
# sentiment: True, probability: 0.9937159419059753
# 731-)
# sentiment: Fake, probability: 0.08293178677558899
# 732-)
# sentiment: Fake, probability: 0.08655533939599991
# 733-)
# sentiment: Fake, probability: 0.08144470304250717
# 734-)
# sentiment: True, probability: 0.9937073588371277
# 735-)
# sentiment: Fake, probability: 0.08212671428918839
# 736-)
# sentiment: Fake, probability: 0.31201228499412537
# 737-)
# sentiment: True, probability: 0.9937077760696411
# 738-)
# sentiment: Fake, probability: 0.08801468461751938
# 739-)
# sentiment: Fake, probability: 0.08209493011236191
# 740-)
# sentiment: True, probability: 0.9936932325363159
# 741-)
# sentiment: Fake, probability: 0.08135998249053955
# 742-)
# sentiment: True, probability: 0.9937113523483276
# 743-)
# sentiment: True, probability: 0.9935632944107056
# 744-)
# sentiment: Fake, probability: 0.09118915349245071
# 745-)
# sentiment: Fake, probability: 0.11698237806558609
# 746-)
# sentiment: True, probability: 0.9740244150161743
# 747-)
# sentiment: True, probability: 0.9936938881874084
# 748-)
# sentiment: True, probability: 0.9937092065811157
# 749-)
# sentiment: Fake, probability: 0.08225070685148239
# 750-)
# sentiment: Fake, probability: 0.0818895772099495
# 751-)
# sentiment: Fake, probability: 0.08470384776592255
# 752-)
# sentiment: True, probability: 0.9934731125831604
# 753-)
# sentiment: Fake, probability: 0.08194859325885773
# 754-)
# sentiment: True, probability: 0.993668258190155
# 755-)
# sentiment: True, probability: 0.9936811923980713
# 756-)
# sentiment: True, probability: 0.9935264587402344
# 757-)
# sentiment: True, probability: 0.9937018156051636
# 758-)
# sentiment: Fake, probability: 0.13661718368530273
# 759-)
# sentiment: Fake, probability: 0.08131858706474304
# 760-)
# sentiment: True, probability: 0.9936966300010681
# 761-)
# sentiment: Fake, probability: 0.08134619146585464
# 762-)
# sentiment: Fake, probability: 0.08154014497995377
# 763-)
# sentiment: True, probability: 0.9936826229095459
# 764-)
# sentiment: Fake, probability: 0.08257865160703659
# 765-)
# sentiment: Fake, probability: 0.08316592127084732
# 766-)
# sentiment: Fake, probability: 0.08131008595228195
# 767-)
# sentiment: True, probability: 0.9937022924423218
# 768-)
# sentiment: True, probability: 0.9931995272636414
# 769-)
# sentiment: Fake, probability: 0.08142895996570587
# 770-)
# sentiment: Fake, probability: 0.08137529343366623
# 771-)
# sentiment: Fake, probability: 0.08127452433109283
# 772-)
# sentiment: Fake, probability: 0.12962916493415833
# 773-)
# sentiment: Fake, probability: 0.08132040500640869
# 774-)
# sentiment: Fake, probability: 0.2642422914505005
# 775-)
# sentiment: Fake, probability: 0.08127260953187943
# 776-)
# sentiment: True, probability: 0.9937059283256531
# 777-)
# sentiment: Fake, probability: 0.08136671781539917
# 778-)
# sentiment: Fake, probability: 0.22994372248649597
# 779-)
# sentiment: True, probability: 0.9936793446540833
# 780-)
# sentiment: True, probability: 0.9937108755111694
# 781-)
# sentiment: True, probability: 0.9937011003494263
# 782-)
# sentiment: True, probability: 0.9936518669128418
# 783-)
# sentiment: True, probability: 0.99367755651474
# 784-)
# sentiment: True, probability: 0.9935217499732971
# 785-)
# sentiment: Fake, probability: 0.1787973940372467
# 786-)
# sentiment: True, probability: 0.993678629398346
# 787-)
# sentiment: Fake, probability: 0.0812762901186943
# 788-)
# sentiment: True, probability: 0.9936560392379761
# 789-)
# sentiment: True, probability: 0.9936792254447937
# 790-)
# sentiment: Fake, probability: 0.08153487741947174
# 791-)
# sentiment: Fake, probability: 0.09978689253330231
# 792-)
# sentiment: Fake, probability: 0.4512123465538025
# 793-)
# sentiment: True, probability: 0.9706472158432007
# 794-)
# sentiment: True, probability: 0.9936164617538452
# 795-)
# sentiment: True, probability: 0.9936781525611877
# 796-)
# sentiment: Fake, probability: 0.0813446044921875
# 797-)
# sentiment: True, probability: 0.9936822652816772
# 798-)
# sentiment: Fake, probability: 0.08161412924528122
# 799-)
# sentiment: Fake, probability: 0.08130932599306107
# 800-)
# sentiment: True, probability: 0.9936530590057373
# 801-)
# sentiment: Fake, probability: 0.08862859010696411
# 802-)
# sentiment: Fake, probability: 0.09585781395435333
# 803-)
# sentiment: True, probability: 0.9936851859092712
# 804-)
# sentiment: True, probability: 0.9936142563819885
# 805-)
# sentiment: Fake, probability: 0.5823984146118164
# 806-)
# sentiment: True, probability: 0.9934787750244141
# 807-)
# sentiment: True, probability: 0.9936493039131165
# 808-)
# sentiment: Fake, probability: 0.0814182385802269
# 809-)
# sentiment: Fake, probability: 0.08160920441150665
# 810-)
# sentiment: Fake, probability: 0.08301906287670135
# 811-)
# sentiment: True, probability: 0.9936965107917786
# 812-)
# sentiment: Fake, probability: 0.0812721773982048
# 813-)
# sentiment: True, probability: 0.993629515171051
# 814-)
# sentiment: Fake, probability: 0.08193039894104004
# 815-)
# sentiment: True, probability: 0.9936650991439819
# 816-)
# sentiment: True, probability: 0.9936933517456055
# 817-)
# sentiment: True, probability: 0.9936885237693787
# 818-)
# sentiment: Fake, probability: 0.081281378865242
# 819-)
# sentiment: True, probability: 0.993709921836853
# 820-)
# sentiment: True, probability: 0.9936885237693787
# 821-)
# sentiment: True, probability: 0.9936842322349548
# 822-)
# sentiment: True, probability: 0.9936808347702026
# 823-)
# sentiment: Fake, probability: 0.08899379521608353
# 824-)
# sentiment: True, probability: 0.9937006235122681
# 825-)
# sentiment: True, probability: 0.9937076568603516
# 826-)
# sentiment: True, probability: 0.9936188459396362
# 827-)
# sentiment: True, probability: 0.9936665892601013
# 828-)
# sentiment: True, probability: 0.993608832359314
# 829-)
# sentiment: True, probability: 0.9936329126358032
# 830-)
# sentiment: Fake, probability: 0.08293207734823227
# 831-)
# sentiment: True, probability: 0.9936925172805786
# 832-)
# sentiment: True, probability: 0.993482768535614
# 833-)
# sentiment: Fake, probability: 0.08503959327936172
# 834-)
# sentiment: Fake, probability: 0.14567627012729645
# 835-)
# sentiment: True, probability: 0.9922303557395935
# 836-)
# sentiment: Fake, probability: 0.08407659083604813
# 837-)
# sentiment: Fake, probability: 0.08479142934083939
# 838-)
# sentiment: True, probability: 0.9935376048088074
# 839-)
# sentiment: True, probability: 0.9936895370483398
# 840-)
# sentiment: True, probability: 0.9935558438301086
# 841-)
# sentiment: Fake, probability: 0.08126047998666763
# 842-)
# sentiment: True, probability: 0.9936955571174622
# 843-)
# sentiment: True, probability: 0.9937037825584412
# 844-)
# sentiment: Fake, probability: 0.08134770393371582
# 845-)
# sentiment: Fake, probability: 0.0814683586359024
# 846-)
# sentiment: Fake, probability: 0.0843995213508606
# 847-)
# sentiment: Fake, probability: 0.10337033867835999
# 848-)
# sentiment: Fake, probability: 0.08158029615879059
# 849-)
# sentiment: True, probability: 0.9936332702636719
# 850-)
# sentiment: True, probability: 0.9932469129562378
# 851-)
# sentiment: Fake, probability: 0.08212962746620178
# 852-)
# sentiment: Fake, probability: 0.08131375163793564
# 853-)
# sentiment: True, probability: 0.9937120676040649
# 854-)
# sentiment: Fake, probability: 0.08140351623296738
# 855-)
# sentiment: True, probability: 0.9936797618865967
# 856-)
# sentiment: True, probability: 0.9936915636062622
# 857-)
# sentiment: True, probability: 0.9932911396026611
# 858-)
# sentiment: True, probability: 0.9937123656272888
# 859-)
# sentiment: Fake, probability: 0.08272910863161087
# 860-)
# sentiment: True, probability: 0.9937074780464172
# 861-)
# sentiment: Fake, probability: 0.08215770870447159
# 862-)
# sentiment: Fake, probability: 0.08374354988336563
# 863-)
# sentiment: Fake, probability: 0.08177001029253006
# 864-)
# sentiment: Fake, probability: 0.08127646893262863
# 865-)
# sentiment: Fake, probability: 0.08170872181653976
# 866-)
# sentiment: Fake, probability: 0.08144135028123856
# 867-)
# sentiment: Fake, probability: 0.08317605406045914
# 868-)
# sentiment: True, probability: 0.9937073588371277
# 869-)
# sentiment: Fake, probability: 0.08128777146339417
# 870-)
# sentiment: True, probability: 0.9936823844909668
# 871-)
# sentiment: True, probability: 0.9936466217041016
# 872-)
# sentiment: True, probability: 0.993664026260376
# 873-)
# sentiment: True, probability: 0.9936836957931519
# 874-)
# sentiment: Fake, probability: 0.0813242495059967
# 875-)
# sentiment: Fake, probability: 0.08138707280158997
# 876-)
# sentiment: True, probability: 0.9936957955360413
# 877-)
# sentiment: Fake, probability: 0.08551489561796188
# 878-)
# sentiment: True, probability: 0.9936889410018921
# 879-)
# sentiment: True, probability: 0.9936622381210327
# 880-)
# sentiment: True, probability: 0.9936959147453308
# 881-)
# sentiment: Fake, probability: 0.13477514684200287
# 882-)
# sentiment: True, probability: 0.9937015771865845
# 883-)
# sentiment: True, probability: 0.9937022924423218
# 884-)
# sentiment: Fake, probability: 0.0814199447631836
# 885-)
# sentiment: True, probability: 0.9937094449996948
# 886-)
# sentiment: True, probability: 0.9936969876289368
# 887-)
# sentiment: True, probability: 0.99367755651474
# 888-)
# sentiment: True, probability: 0.9915643930435181
# 889-)
# sentiment: Fake, probability: 0.08130986988544464
# 890-)
# sentiment: Fake, probability: 0.08128664642572403
# 891-)
# sentiment: Fake, probability: 0.08135098963975906
# 892-)
# sentiment: True, probability: 0.9936975836753845
# 893-)
# sentiment: True, probability: 0.993691086769104
# 894-)
# sentiment: True, probability: 0.9936336278915405
# 895-)
# sentiment: Fake, probability: 0.10039615631103516
# 896-)
# sentiment: Fake, probability: 0.09724003821611404
# 897-)
# sentiment: Fake, probability: 0.08165906369686127
# 898-)
# sentiment: True, probability: 0.9935541152954102
# 899-)
# sentiment: True, probability: 0.9936810731887817
# 900-)
# sentiment: Fake, probability: 0.20052801072597504
# 901-)
# sentiment: Fake, probability: 0.11058598756790161
# 902-)
# sentiment: True, probability: 0.9931514263153076
# 903-)
# sentiment: True, probability: 0.9937005043029785
# 904-)
# sentiment: True, probability: 0.9936768412590027
# 905-)
# sentiment: True, probability: 0.993558943271637
# 906-)
# sentiment: Fake, probability: 0.1909855753183365
# 907-)
# sentiment: True, probability: 0.9936650991439819
# 908-)
# sentiment: True, probability: 0.9936380982398987
# 909-)
# sentiment: True, probability: 0.9936336278915405
# 910-)
# sentiment: Fake, probability: 0.08688829839229584
# 911-)
# sentiment: Fake, probability: 0.08165515959262848
# 912-)
# sentiment: True, probability: 0.99334716796875
# 913-)
# sentiment: True, probability: 0.987060546875
# 914-)
# sentiment: True, probability: 0.9936916828155518
# 915-)
# sentiment: True, probability: 0.993678867816925
# 916-)
# sentiment: Fake, probability: 0.08708636462688446
# 917-)
# sentiment: Fake, probability: 0.08128634840250015
# 918-)
# sentiment: Fake, probability: 0.08134499937295914
# 919-)
# sentiment: Fake, probability: 0.08164362609386444
# 920-)
# sentiment: Fake, probability: 0.08136292546987534
# 921-)
# sentiment: True, probability: 0.993705689907074
# 922-)
# sentiment: True, probability: 0.9936885237693787
# 923-)
# sentiment: Fake, probability: 0.2387557029724121
# 924-)
# sentiment: Fake, probability: 0.08133342117071152
# 925-)
# sentiment: Fake, probability: 0.08331777900457382
# 926-)
# sentiment: Fake, probability: 0.08500470221042633
# 927-)
# sentiment: Fake, probability: 0.08495631068944931
# 928-)
# sentiment: True, probability: 0.9936662316322327
# 929-)
# sentiment: True, probability: 0.9936826229095459
# 930-)
# sentiment: Fake, probability: 0.0833592489361763
# 931-)
# sentiment: True, probability: 0.9936885237693787
# 932-)
# sentiment: Fake, probability: 0.10967066138982773
# 933-)
# sentiment: True, probability: 0.9936509728431702
# 934-)
# sentiment: True, probability: 0.9936490654945374
# 935-)
# sentiment: Fake, probability: 0.08289050310850143
# 936-)
# sentiment: True, probability: 0.9937077760696411
# 937-)
# sentiment: Fake, probability: 0.08131888508796692
# 938-)
# sentiment: Fake, probability: 0.0813484936952591
# 939-)
# sentiment: True, probability: 0.9936801195144653
# 940-)
# sentiment: True, probability: 0.9936838150024414
# 941-)
# sentiment: True, probability: 0.9937030673027039
# 942-)
# sentiment: Fake, probability: 0.08128636330366135
# 943-)
# sentiment: Fake, probability: 0.08133746683597565
# 944-)
# sentiment: Fake, probability: 0.08125939965248108
# 945-)
# sentiment: True, probability: 0.9936153888702393
# 946-)
# sentiment: Fake, probability: 0.08224357664585114
# 947-)
# sentiment: True, probability: 0.9936597943305969
# 948-)
# sentiment: Fake, probability: 0.0813540369272232
# 949-)
# sentiment: Fake, probability: 0.08386857062578201
# 950-)
# sentiment: Fake, probability: 0.08127517253160477
# 951-)
# sentiment: True, probability: 0.9936984777450562
# 952-)
# sentiment: Fake, probability: 0.08193447440862656
# 953-)
# sentiment: True, probability: 0.9936919212341309
# 954-)
# sentiment: Fake, probability: 0.08126810193061829
# 955-)
# sentiment: Fake, probability: 0.18128053843975067
# 956-)
# sentiment: Fake, probability: 0.0818641260266304
# 957-)
# sentiment: Fake, probability: 0.08163779228925705
# 958-)
# sentiment: Fake, probability: 0.08444927632808685
# 959-)
# sentiment: Fake, probability: 0.086346834897995
# 960-)
# sentiment: True, probability: 0.9936894178390503
# 961-)
# sentiment: True, probability: 0.9936967492103577
# 962-)
# sentiment: Fake, probability: 0.08131658285856247
# 963-)
# sentiment: Fake, probability: 0.09017053991556168
# 964-)
# sentiment: Fake, probability: 0.0899428278207779
# 965-)
# sentiment: Fake, probability: 0.0813213586807251
# 966-)
# sentiment: Fake, probability: 0.1230248361825943
# 967-)
# sentiment: True, probability: 0.9935932755470276
# 968-)
# sentiment: Fake, probability: 0.090655617415905
# 969-)
# sentiment: True, probability: 0.9934978485107422
# 970-)
# sentiment: Fake, probability: 0.34905752539634705
# 971-)
# sentiment: True, probability: 0.9936571717262268
# 972-)
# sentiment: True, probability: 0.9936991930007935
# 973-)
# sentiment: Fake, probability: 0.0832420215010643
# 974-)
# sentiment: Fake, probability: 0.08129934966564178
# 975-)
# sentiment: True, probability: 0.9936562180519104
# 976-)
# sentiment: True, probability: 0.9935943484306335
# 977-)
# sentiment: True, probability: 0.9936814308166504
# 978-)
# sentiment: Fake, probability: 0.08140862733125687
# 979-)
# sentiment: Fake, probability: 0.08128068596124649
# 980-)
# sentiment: True, probability: 0.9936942458152771
# 981-)
# sentiment: True, probability: 0.9937041401863098
# 982-)
# sentiment: True, probability: 0.9937042593955994
# 983-)
# sentiment: Fake, probability: 0.08133725076913834
# 984-)
# sentiment: Fake, probability: 0.08128556609153748
# 985-)
# sentiment: Fake, probability: 0.08684181421995163
# 986-)
# sentiment: Fake, probability: 0.08353574573993683
# 987-)
# sentiment: Fake, probability: 0.6311647891998291
# 988-)
# sentiment: True, probability: 0.993707001209259
# 989-)
# sentiment: Fake, probability: 0.08127167820930481
# 990-)
# sentiment: True, probability: 0.9936925172805786
# 991-)
# sentiment: True, probability: 0.9936783909797668
# 992-)
# sentiment: True, probability: 0.9934735894203186
# 993-)
# sentiment: Fake, probability: 0.10101541876792908
# 994-)
# sentiment: Fake, probability: 0.08292099833488464
# 995-)
# sentiment: True, probability: 0.9930862188339233
# 996-)
# sentiment: Fake, probability: 0.2835504412651062
# 997-)
# sentiment: Fake, probability: 0.08258979767560959
# 998-)
# sentiment: Fake, probability: 0.0822376236319542
# 999-)
# sentiment: True, probability: 0.9936773180961609
# 978

# %%
from sklearn.metrics import confusion_matrix

# %%
y_true=submission["Truth"].tolist()

# %%
conf_matrix=confusion_matrix(y_true, y_pred)
conf_matrix
# Out:
# array([[480,  12],
#        [ 10, 498]])

# %%
TP = conf_matrix[1][1]
TN = conf_matrix[0][0]
FP = conf_matrix[0][1]
FN = conf_matrix[1][0]
print('True Positives:', TP)
print('True Negatives:', TN)
print('False Positives:', FP)
print('False Negatives:', FN)
# Out:
# True Positives: 498
# True Negatives: 480
# False Positives: 12
# False Negatives: 10

# %%
conf_accuracy = (float (TP+TN) / float(TP + TN + FP + FN))

conf_error_rate = 1- conf_accuracy
    
conf_sensitivity = (TP / float(TP + FN)) #recall

conf_specificity = (TN / float(TN + FP))
    
conf_precision = (TN / float(TN + FP))

conf_f1 = 2 * ((conf_precision * conf_sensitivity) / (conf_precision + conf_sensitivity))
print('-'*50)
print(f'Accuracy: {round(conf_accuracy,2)}') 
print(f'Error_rate: {round(conf_error_rate,2)}') 
print(f'Sensitivity: {round(conf_sensitivity,2)}') 
print(f'Specificity: {round(conf_specificity,2)}') 
print(f'Precision: {round(conf_precision,2)}')
print(f'f_1 Score: {round(conf_f1,2)}')
# Out:
# --------------------------------------------------
# Accuracy: 0.98
# Error_rate: 0.02
# Sensitivity: 0.98
# Specificity: 0.98
# Precision: 0.98
# f_1 Score: 0.98
