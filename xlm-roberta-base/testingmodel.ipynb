# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.25.1-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 15.0 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (21.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.8.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 62.7 MB/s
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 73.3 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.11.1 tokenizers-0.13.2 transformers-4.25.1

# %%
model_name="xlm-roberta-base"

# %%
from transformers import AutoModelForSequenceClassification
new_model = AutoModelForSequenceClassification.from_pretrained("/content/drive/MyDrive/Colab Notebooks/xlm-roberta-base/model")

# %%
from transformers import AutoTokenizer
new_tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# Downloading:   0%|          | 0.00/615 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.10M [00:00<?, ?B/s]

# %%
import nltk
from nltk.stem.porter import PorterStemmer
import re
from nltk.corpus import stopwords
nltk.download("stopwords")
def preprocessing(text):
    ps = PorterStemmer()
    sentence = re.sub('[^a-zA-Z]',' ',text) # noktalama işaretlerini silme.
    sentence = sentence.lower() # kelimelerin hepsini küçük harf 
    sentence = sentence.split() # keliemeleri listeye atma
    sentence = [ps.stem(kelime) for kelime in sentence if not kelime in set(stopwords.words("english"))] #anlamı olmayan(stopwords) kelimeleri listeden atma
    sentence = " ".join(sentence) # listede kalan kelimeleri birleştirip yeni cümleyi oluşturma.
    return sentence
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
sentence = preprocessing("He goes to airport.")
print(sentence)
# Out:
# goe airport

# %%
import torch
import numpy as np

def get_prediction(text):
    text = preprocessing(text)
    encoding = new_tokenizer(text, return_tensors="pt", padding="max_length", truncation=True, max_length=128)
    # encoding = {k: v.to(trainer.model.device) for k,v in encoding.items()}
    outputs = new_model(**encoding)

    logits = outputs.logits

    sigmoid = torch.nn.Sigmoid()
    probs = sigmoid(logits.squeeze().cpu())
    probs = probs.detach().numpy()
    label = np.argmax(probs, axis=-1) # değeri 0 veya 1'e yuvarlıyoruz.
    
    if label == 1:
        print(f"sentiment: True, probability: {probs[1]}")
        return 1
    else:
        print(f"sentiment: Fake, probability: {probs[1]}")
        return 0

# %%
get_prediction("He goes to airport.")
# Out:
# sentiment: True, probability: 0.9211758971214294
# 1

# %%
submission = pd.read_csv("/content/drive/MyDrive/submission.csv")
# y = submission["Truth"]
# x = submission["Haber"]

# %%
accuracy = 0
y_pred = []
for i in range(submission.shape[0]):
    row = submission.iloc[i]
    text = row[0]
    truth_value = row[1]
    print(f"{i}-)")
    result = get_prediction(text)
    y_pred.append(result)
    if(result == int(truth_value)):
        accuracy += 1 
accuracy
# Out:
# 0-)
# sentiment: True, probability: 0.9205685257911682
# 1-)
# sentiment: Fake, probability: 0.06162991747260094
# 2-)
# sentiment: Fake, probability: 0.05503503978252411
# 3-)
# sentiment: True, probability: 0.9207140207290649
# 4-)
# sentiment: Fake, probability: 0.055860940366983414
# 5-)
# sentiment: True, probability: 0.9201562404632568
# 6-)
# sentiment: True, probability: 0.9212066531181335
# 7-)
# sentiment: Fake, probability: 0.0564093180000782
# 8-)
# sentiment: True, probability: 0.9205716848373413
# 9-)
# sentiment: True, probability: 0.9210497736930847
# 10-)
# sentiment: True, probability: 0.9212003350257874
# 11-)
# sentiment: True, probability: 0.9202309250831604
# 12-)
# sentiment: True, probability: 0.9195054769515991
# 13-)
# sentiment: True, probability: 0.9197268486022949
# 14-)
# sentiment: True, probability: 0.9211759567260742
# 15-)
# sentiment: True, probability: 0.9196907877922058
# 16-)
# sentiment: Fake, probability: 0.05841889977455139
# 17-)
# sentiment: True, probability: 0.9151058793067932
# 18-)
# sentiment: Fake, probability: 0.05659941956400871
# 19-)
# sentiment: True, probability: 0.9203512668609619
# 20-)
# sentiment: Fake, probability: 0.05629408732056618
# 21-)
# sentiment: True, probability: 0.9212252497673035
# 22-)
# sentiment: Fake, probability: 0.06466379761695862
# 23-)
# sentiment: Fake, probability: 0.05573318898677826
# 24-)
# sentiment: True, probability: 0.9209751486778259
# 25-)
# sentiment: Fake, probability: 0.07618898898363113
# 26-)
# sentiment: Fake, probability: 0.10275120288133621
# 27-)
# sentiment: True, probability: 0.919710636138916
# 28-)
# sentiment: True, probability: 0.9202959537506104
# 29-)
# sentiment: True, probability: 0.9211545586585999
# 30-)
# sentiment: Fake, probability: 0.2615201771259308
# 31-)
# sentiment: Fake, probability: 0.055276840925216675
# 32-)
# sentiment: True, probability: 0.9209485054016113
# 33-)
# sentiment: Fake, probability: 0.055601559579372406
# 34-)
# sentiment: True, probability: 0.9209911823272705
# 35-)
# sentiment: True, probability: 0.9210755228996277
# 36-)
# sentiment: Fake, probability: 0.05542011931538582
# 37-)
# sentiment: True, probability: 0.9195879101753235
# 38-)
# sentiment: True, probability: 0.9126945734024048
# 39-)
# sentiment: True, probability: 0.9210603833198547
# 40-)
# sentiment: Fake, probability: 0.18651795387268066
# 41-)
# sentiment: Fake, probability: 0.055196043103933334
# 42-)
# sentiment: Fake, probability: 0.05565931648015976
# 43-)
# sentiment: True, probability: 0.9207301139831543
# 44-)
# sentiment: Fake, probability: 0.09970050305128098
# 45-)
# sentiment: Fake, probability: 0.056674420833587646
# 46-)
# sentiment: True, probability: 0.9152309894561768
# 47-)
# sentiment: True, probability: 0.9211922883987427
# 48-)
# sentiment: True, probability: 0.9212228059768677
# 49-)
# sentiment: True, probability: 0.921105682849884
# 50-)
# sentiment: True, probability: 0.920952558517456
# 51-)
# sentiment: True, probability: 0.9206582307815552
# 52-)
# sentiment: True, probability: 0.9212300181388855
# 53-)
# sentiment: True, probability: 0.9212145209312439
# 54-)
# sentiment: True, probability: 0.9168354272842407
# 55-)
# sentiment: Fake, probability: 0.055346786975860596
# 56-)
# sentiment: Fake, probability: 0.05933403596282005
# 57-)
# sentiment: True, probability: 0.9209718704223633
# 58-)
# sentiment: True, probability: 0.9212120175361633
# 59-)
# sentiment: Fake, probability: 0.056039415299892426
# 60-)
# sentiment: Fake, probability: 0.057260140776634216
# 61-)
# sentiment: Fake, probability: 0.055363498628139496
# 62-)
# sentiment: Fake, probability: 0.055423613637685776
# 63-)
# sentiment: Fake, probability: 0.060713425278663635
# 64-)
# sentiment: True, probability: 0.9211740493774414
# 65-)
# sentiment: True, probability: 0.9210728406906128
# 66-)
# sentiment: True, probability: 0.9210863709449768
# 67-)
# sentiment: Fake, probability: 0.05662496015429497
# 68-)
# sentiment: True, probability: 0.912995457649231
# 69-)
# sentiment: Fake, probability: 0.056815650314092636
# 70-)
# sentiment: True, probability: 0.9185503721237183
# 71-)
# sentiment: True, probability: 0.9211901426315308
# 72-)
# sentiment: True, probability: 0.9212056398391724
# 73-)
# sentiment: Fake, probability: 0.05523203685879707
# 74-)
# sentiment: Fake, probability: 0.060842327773571014
# 75-)
# sentiment: True, probability: 0.9204996228218079
# 76-)
# sentiment: Fake, probability: 0.055876247584819794
# 77-)
# sentiment: Fake, probability: 0.05639331787824631
# 78-)
# sentiment: Fake, probability: 0.05521957948803902
# 79-)
# sentiment: Fake, probability: 0.05560050904750824
# 80-)
# sentiment: True, probability: 0.9181653261184692
# 81-)
# sentiment: Fake, probability: 0.05568133667111397
# 82-)
# sentiment: Fake, probability: 0.061403658241033554
# 83-)
# sentiment: Fake, probability: 0.0560278445482254
# 84-)
# sentiment: Fake, probability: 0.05523357912898064
# 85-)
# sentiment: True, probability: 0.9212103486061096
# 86-)
# sentiment: Fake, probability: 0.05558198317885399
# 87-)
# sentiment: Fake, probability: 0.05538102984428406
# 88-)
# sentiment: Fake, probability: 0.05561307817697525
# 89-)
# sentiment: Fake, probability: 0.05564863979816437
# 90-)
# sentiment: True, probability: 0.9210628867149353
# 91-)
# sentiment: Fake, probability: 0.0647260919213295
# 92-)
# sentiment: Fake, probability: 0.05763958394527435
# 93-)
# sentiment: True, probability: 0.9212237000465393
# 94-)
# sentiment: True, probability: 0.9210994839668274
# 95-)
# sentiment: Fake, probability: 0.055599384009838104
# 96-)
# sentiment: Fake, probability: 0.0556771494448185
# 97-)
# sentiment: True, probability: 0.9201068878173828
# 98-)
# sentiment: Fake, probability: 0.09395155310630798
# 99-)
# sentiment: Fake, probability: 0.055951908230781555
# 100-)
# sentiment: True, probability: 0.9208664298057556
# 101-)
# sentiment: True, probability: 0.9210203289985657
# 102-)
# sentiment: True, probability: 0.9159126877784729
# 103-)
# sentiment: True, probability: 0.920965313911438
# 104-)
# sentiment: Fake, probability: 0.0549720823764801
# 105-)
# sentiment: True, probability: 0.9207955002784729
# 106-)
# sentiment: True, probability: 0.9211466312408447
# 107-)
# sentiment: Fake, probability: 0.05501444637775421
# 108-)
# sentiment: Fake, probability: 0.05521209537982941
# 109-)
# sentiment: True, probability: 0.920747697353363
# 110-)
# sentiment: True, probability: 0.9212185740470886
# 111-)
# sentiment: Fake, probability: 0.05526944622397423
# 112-)
# sentiment: True, probability: 0.9208580255508423
# 113-)
# sentiment: True, probability: 0.9211184978485107
# 114-)
# sentiment: Fake, probability: 0.06770742684602737
# 115-)
# sentiment: Fake, probability: 0.056171488016843796
# 116-)
# sentiment: True, probability: 0.9212162494659424
# 117-)
# sentiment: Fake, probability: 0.055959466844797134
# 118-)
# sentiment: Fake, probability: 0.06434249877929688
# 119-)
# sentiment: True, probability: 0.9212040901184082
# 120-)
# sentiment: True, probability: 0.9210659265518188
# 121-)
# sentiment: Fake, probability: 0.05619131401181221
# 122-)
# sentiment: Fake, probability: 0.05572211742401123
# 123-)
# sentiment: True, probability: 0.9201796650886536
# 124-)
# sentiment: Fake, probability: 0.05830349400639534
# 125-)
# sentiment: True, probability: 0.92123943567276
# 126-)
# sentiment: True, probability: 0.9207782745361328
# 127-)
# sentiment: True, probability: 0.9212036728858948
# 128-)
# sentiment: True, probability: 0.9208577275276184
# 129-)
# sentiment: True, probability: 0.9206947088241577
# 130-)
# sentiment: Fake, probability: 0.05546490475535393
# 131-)
# sentiment: True, probability: 0.9202633500099182
# 132-)
# sentiment: True, probability: 0.9209378361701965
# 133-)
# sentiment: True, probability: 0.9196594953536987
# 134-)
# sentiment: Fake, probability: 0.055214133113622665
# 135-)
# sentiment: True, probability: 0.9207854866981506
# 136-)
# sentiment: Fake, probability: 0.05698240548372269
# 137-)
# sentiment: Fake, probability: 0.05765786021947861
# 138-)
# sentiment: Fake, probability: 0.05791984498500824
# 139-)
# sentiment: Fake, probability: 0.06044858694076538
# 140-)
# sentiment: Fake, probability: 0.055488478392362595
# 141-)
# sentiment: Fake, probability: 0.05539390444755554
# 142-)
# sentiment: True, probability: 0.9182878136634827
# 143-)
# sentiment: Fake, probability: 0.05646128207445145
# 144-)
# sentiment: Fake, probability: 0.05730490759015083
# 145-)
# sentiment: True, probability: 0.9211428761482239
# 146-)
# sentiment: True, probability: 0.9211361408233643
# 147-)
# sentiment: Fake, probability: 0.058228008449077606
# 148-)
# sentiment: True, probability: 0.9210808873176575
# 149-)
# sentiment: Fake, probability: 0.0743916854262352
# 150-)
# sentiment: True, probability: 0.920803964138031
# 151-)
# sentiment: True, probability: 0.9138692617416382
# 152-)
# sentiment: True, probability: 0.9212414622306824
# 153-)
# sentiment: True, probability: 0.9212352633476257
# 154-)
# sentiment: True, probability: 0.9212246537208557
# 155-)
# sentiment: True, probability: 0.9212276935577393
# 156-)
# sentiment: True, probability: 0.9208750128746033
# 157-)
# sentiment: Fake, probability: 0.05662059411406517
# 158-)
# sentiment: True, probability: 0.920761227607727
# 159-)
# sentiment: True, probability: 0.9212217330932617
# 160-)
# sentiment: Fake, probability: 0.05583029240369797
# 161-)
# sentiment: Fake, probability: 0.11128062754869461
# 162-)
# sentiment: Fake, probability: 0.06770742684602737
# 163-)
# sentiment: Fake, probability: 0.05575942620635033
# 164-)
# sentiment: Fake, probability: 0.056389156728982925
# 165-)
# sentiment: True, probability: 0.9212327599525452
# 166-)
# sentiment: True, probability: 0.9182798862457275
# 167-)
# sentiment: True, probability: 0.925554096698761
# 168-)
# sentiment: True, probability: 0.9212268590927124
# 169-)
# sentiment: Fake, probability: 0.056008320301771164
# 170-)
# sentiment: Fake, probability: 0.05571743845939636
# 171-)
# sentiment: True, probability: 0.9205597639083862
# 172-)
# sentiment: Fake, probability: 0.05553528293967247
# 173-)
# sentiment: True, probability: 0.9212263822555542
# 174-)
# sentiment: Fake, probability: 0.057769522070884705
# 175-)
# sentiment: True, probability: 0.9212258458137512
# 176-)
# sentiment: Fake, probability: 0.05602773651480675
# 177-)
# sentiment: True, probability: 0.9208758473396301
# 178-)
# sentiment: True, probability: 0.9207754731178284
# 179-)
# sentiment: Fake, probability: 0.1286054402589798
# 180-)
# sentiment: True, probability: 0.9209301471710205
# 181-)
# sentiment: Fake, probability: 0.05730150640010834
# 182-)
# sentiment: True, probability: 0.9205115437507629
# 183-)
# sentiment: Fake, probability: 0.056026723235845566
# 184-)
# sentiment: True, probability: 0.9183286428451538
# 185-)
# sentiment: Fake, probability: 0.055717989802360535
# 186-)
# sentiment: True, probability: 0.9204877018928528
# 187-)
# sentiment: True, probability: 0.9111105799674988
# 188-)
# sentiment: True, probability: 0.9209159016609192
# 189-)
# sentiment: Fake, probability: 0.05947389826178551
# 190-)
# sentiment: True, probability: 0.9211241006851196
# 191-)
# sentiment: True, probability: 0.9204946160316467
# 192-)
# sentiment: Fake, probability: 0.05569694563746452
# 193-)
# sentiment: Fake, probability: 0.25972920656204224
# 194-)
# sentiment: True, probability: 0.9162967801094055
# 195-)
# sentiment: True, probability: 0.9212316274642944
# 196-)
# sentiment: Fake, probability: 0.05619345232844353
# 197-)
# sentiment: Fake, probability: 0.05564402788877487
# 198-)
# sentiment: Fake, probability: 0.05713117495179176
# 199-)
# sentiment: True, probability: 0.9208344221115112
# 200-)
# sentiment: Fake, probability: 0.05836183577775955
# 201-)
# sentiment: Fake, probability: 0.05566967651247978
# 202-)
# sentiment: True, probability: 0.9201492667198181
# 203-)
# sentiment: Fake, probability: 0.11095421016216278
# 204-)
# sentiment: Fake, probability: 0.055689048022031784
# 205-)
# sentiment: True, probability: 0.921163022518158
# 206-)
# sentiment: Fake, probability: 0.05540342256426811
# 207-)
# sentiment: True, probability: 0.9203283786773682
# 208-)
# sentiment: True, probability: 0.9210203289985657
# 209-)
# sentiment: True, probability: 0.914496898651123
# 210-)
# sentiment: True, probability: 0.9201594591140747
# 211-)
# sentiment: True, probability: 0.9211755990982056
# 212-)
# sentiment: True, probability: 0.9210657477378845
# 213-)
# sentiment: True, probability: 0.9095337390899658
# 214-)
# sentiment: Fake, probability: 0.05542425438761711
# 215-)
# sentiment: Fake, probability: 0.05573412403464317
# 216-)
# sentiment: Fake, probability: 0.05524315685033798
# 217-)
# sentiment: True, probability: 0.9206035733222961
# 218-)
# sentiment: True, probability: 0.9190477132797241
# 219-)
# sentiment: True, probability: 0.9211919903755188
# 220-)
# sentiment: True, probability: 0.9212071299552917
# 221-)
# sentiment: Fake, probability: 0.13302750885486603
# 222-)
# sentiment: True, probability: 0.9212284088134766
# 223-)
# sentiment: True, probability: 0.9184272885322571
# 224-)
# sentiment: True, probability: 0.9205115437507629
# 225-)
# sentiment: Fake, probability: 0.05532561615109444
# 226-)
# sentiment: Fake, probability: 0.055671218782663345
# 227-)
# sentiment: Fake, probability: 0.05791591480374336
# 228-)
# sentiment: True, probability: 0.9209124445915222
# 229-)
# sentiment: Fake, probability: 0.055317994207143784
# 230-)
# sentiment: True, probability: 0.9212321043014526
# 231-)
# sentiment: True, probability: 0.9211265444755554
# 232-)
# sentiment: Fake, probability: 0.055071987211704254
# 233-)
# sentiment: True, probability: 0.921059250831604
# 234-)
# sentiment: Fake, probability: 0.07582870125770569
# 235-)
# sentiment: True, probability: 0.9212320446968079
# 236-)
# sentiment: True, probability: 0.9207304120063782
# 237-)
# sentiment: Fake, probability: 0.055426351726055145
# 238-)
# sentiment: Fake, probability: 0.08242712914943695
# 239-)
# sentiment: True, probability: 0.919681966304779
# 240-)
# sentiment: True, probability: 0.9212313890457153
# 241-)
# sentiment: True, probability: 0.9203804731369019
# 242-)
# sentiment: True, probability: 0.9208149909973145
# 243-)
# sentiment: Fake, probability: 0.05618809163570404
# 244-)
# sentiment: Fake, probability: 0.059593796730041504
# 245-)
# sentiment: True, probability: 0.8467164039611816
# 246-)
# sentiment: Fake, probability: 0.05511793866753578
# 247-)
# sentiment: Fake, probability: 0.054941389709711075
# 248-)
# sentiment: True, probability: 0.9204599261283875
# 249-)
# sentiment: Fake, probability: 0.07700127363204956
# 250-)
# sentiment: True, probability: 0.9209496378898621
# 251-)
# sentiment: Fake, probability: 0.05535389482975006
# 252-)
# sentiment: Fake, probability: 0.056657128036022186
# 253-)
# sentiment: True, probability: 0.9212007522583008
# 254-)
# sentiment: Fake, probability: 0.05519022047519684
# 255-)
# sentiment: True, probability: 0.9210505485534668
# 256-)
# sentiment: Fake, probability: 0.055517252534627914
# 257-)
# sentiment: Fake, probability: 0.05944734439253807
# 258-)
# sentiment: True, probability: 0.9212056398391724
# 259-)
# sentiment: True, probability: 0.9203512668609619
# 260-)
# sentiment: True, probability: 0.9208225011825562
# 261-)
# sentiment: Fake, probability: 0.06160007789731026
# 262-)
# sentiment: Fake, probability: 0.05650721490383148
# 263-)
# sentiment: True, probability: 0.9212184548377991
# 264-)
# sentiment: True, probability: 0.9207190871238708
# 265-)
# sentiment: True, probability: 0.9212091565132141
# 266-)
# sentiment: Fake, probability: 0.05609004572033882
# 267-)
# sentiment: True, probability: 0.921173632144928
# 268-)
# sentiment: True, probability: 0.9211025238037109
# 269-)
# sentiment: True, probability: 0.921025812625885
# 270-)
# sentiment: Fake, probability: 0.32035255432128906
# 271-)
# sentiment: Fake, probability: 0.055767714977264404
# 272-)
# sentiment: Fake, probability: 0.06102842465043068
# 273-)
# sentiment: Fake, probability: 0.05551417917013168
# 274-)
# sentiment: True, probability: 0.9211269021034241
# 275-)
# sentiment: Fake, probability: 0.055962275713682175
# 276-)
# sentiment: True, probability: 0.9211215376853943
# 277-)
# sentiment: Fake, probability: 0.05647307261824608
# 278-)
# sentiment: True, probability: 0.920328676700592
# 279-)
# sentiment: Fake, probability: 0.0632379949092865
# 280-)
# sentiment: Fake, probability: 0.058058250695466995
# 281-)
# sentiment: Fake, probability: 0.06140311062335968
# 282-)
# sentiment: True, probability: 0.921200692653656
# 283-)
# sentiment: True, probability: 0.9212266802787781
# 284-)
# sentiment: Fake, probability: 0.056804705411195755
# 285-)
# sentiment: True, probability: 0.9197220206260681
# 286-)
# sentiment: Fake, probability: 0.055348411202430725
# 287-)
# sentiment: True, probability: 0.9211249947547913
# 288-)
# sentiment: Fake, probability: 0.05726443976163864
# 289-)
# sentiment: True, probability: 0.9203039407730103
# 290-)
# sentiment: True, probability: 0.9211935997009277
# 291-)
# sentiment: Fake, probability: 0.44835370779037476
# 292-)
# sentiment: True, probability: 0.9211891293525696
# 293-)
# sentiment: True, probability: 0.9205916523933411
# 294-)
# sentiment: Fake, probability: 0.0567096546292305
# 295-)
# sentiment: True, probability: 0.9212220907211304
# 296-)
# sentiment: True, probability: 0.9194920659065247
# 297-)
# sentiment: Fake, probability: 0.11926185339689255
# 298-)
# sentiment: Fake, probability: 0.056414179503917694
# 299-)
# sentiment: True, probability: 0.9207192063331604
# 300-)
# sentiment: Fake, probability: 0.05553680658340454
# 301-)
# sentiment: Fake, probability: 0.057769887149333954
# 302-)
# sentiment: Fake, probability: 0.05572991073131561
# 303-)
# sentiment: Fake, probability: 0.05571959912776947
# 304-)
# sentiment: Fake, probability: 0.05497651547193527
# 305-)
# sentiment: True, probability: 0.9179432392120361
# 306-)
# sentiment: True, probability: 0.9191054105758667
# 307-)
# sentiment: True, probability: 0.9211937785148621
# 308-)
# sentiment: True, probability: 0.9202109575271606
# 309-)
# sentiment: True, probability: 0.9211391806602478
# 310-)
# sentiment: True, probability: 0.9185576438903809
# 311-)
# sentiment: Fake, probability: 0.055284369736909866
# 312-)
# sentiment: True, probability: 0.9210216403007507
# 313-)
# sentiment: Fake, probability: 0.055242300033569336
# 314-)
# sentiment: True, probability: 0.9210612773895264
# 315-)
# sentiment: True, probability: 0.9209119081497192
# 316-)
# sentiment: True, probability: 0.920590341091156
# 317-)
# sentiment: Fake, probability: 0.05696012079715729
# 318-)
# sentiment: True, probability: 0.9077905416488647
# 319-)
# sentiment: True, probability: 0.9120118021965027
# 320-)
# sentiment: True, probability: 0.9210052490234375
# 321-)
# sentiment: True, probability: 0.917840838432312
# 322-)
# sentiment: Fake, probability: 0.05547144263982773
# 323-)
# sentiment: True, probability: 0.9209917187690735
# 324-)
# sentiment: Fake, probability: 0.24872715771198273
# 325-)
# sentiment: True, probability: 0.916549563407898
# 326-)
# sentiment: True, probability: 0.9164753556251526
# 327-)
# sentiment: True, probability: 0.9212347269058228
# 328-)
# sentiment: True, probability: 0.9210081696510315
# 329-)
# sentiment: Fake, probability: 0.05537457391619682
# 330-)
# sentiment: True, probability: 0.9211955070495605
# 331-)
# sentiment: True, probability: 0.9209374189376831
# 332-)
# sentiment: Fake, probability: 0.15585960447788239
# 333-)
# sentiment: Fake, probability: 0.05689670518040657
# 334-)
# sentiment: True, probability: 0.9120368957519531
# 335-)
# sentiment: Fake, probability: 0.05585643649101257
# 336-)
# sentiment: True, probability: 0.9210521578788757
# 337-)
# sentiment: True, probability: 0.920421838760376
# 338-)
# sentiment: Fake, probability: 0.055989447981119156
# 339-)
# sentiment: True, probability: 0.9207381010055542
# 340-)
# sentiment: Fake, probability: 0.05595935508608818
# 341-)
# sentiment: True, probability: 0.9207620024681091
# 342-)
# sentiment: Fake, probability: 0.08553300052881241
# 343-)
# sentiment: Fake, probability: 0.05508562549948692
# 344-)
# sentiment: True, probability: 0.9209613800048828
# 345-)
# sentiment: Fake, probability: 0.05826593190431595
# 346-)
# sentiment: Fake, probability: 0.05549238994717598
# 347-)
# sentiment: Fake, probability: 0.05657486617565155
# 348-)
# sentiment: True, probability: 0.9212117791175842
# 349-)
# sentiment: True, probability: 0.9212223887443542
# 350-)
# sentiment: Fake, probability: 0.055364206433296204
# 351-)
# sentiment: True, probability: 0.9212294816970825
# 352-)
# sentiment: True, probability: 0.90952467918396
# 353-)
# sentiment: Fake, probability: 0.05497384071350098
# 354-)
# sentiment: True, probability: 0.9165002107620239
# 355-)
# sentiment: True, probability: 0.917766809463501
# 356-)
# sentiment: Fake, probability: 0.05508314073085785
# 357-)
# sentiment: True, probability: 0.9207070469856262
# 358-)
# sentiment: Fake, probability: 0.057126376777887344
# 359-)
# sentiment: Fake, probability: 0.056257784366607666
# 360-)
# sentiment: True, probability: 0.918692409992218
# 361-)
# sentiment: True, probability: 0.915803074836731
# 362-)
# sentiment: Fake, probability: 0.061660315841436386
# 363-)
# sentiment: True, probability: 0.920478343963623
# 364-)
# sentiment: Fake, probability: 0.07190412282943726
# 365-)
# sentiment: True, probability: 0.9178455471992493
# 366-)
# sentiment: Fake, probability: 0.05531322956085205
# 367-)
# sentiment: Fake, probability: 0.055455077439546585
# 368-)
# sentiment: True, probability: 0.9211863875389099
# 369-)
# sentiment: Fake, probability: 0.06086772680282593
# 370-)
# sentiment: True, probability: 0.9202702045440674
# 371-)
# sentiment: True, probability: 0.9201523065567017
# 372-)
# sentiment: True, probability: 0.9212164282798767
# 373-)
# sentiment: Fake, probability: 0.056478776037693024
# 374-)
# sentiment: Fake, probability: 0.055478375405073166
# 375-)
# sentiment: Fake, probability: 0.05697878450155258
# 376-)
# sentiment: Fake, probability: 0.05497422814369202
# 377-)
# sentiment: True, probability: 0.9212287664413452
# 378-)
# sentiment: Fake, probability: 0.0559283010661602
# 379-)
# sentiment: Fake, probability: 0.05525887757539749
# 380-)
# sentiment: True, probability: 0.9206785559654236
# 381-)
# sentiment: True, probability: 0.9109750390052795
# 382-)
# sentiment: Fake, probability: 0.25583869218826294
# 383-)
# sentiment: True, probability: 0.9210670590400696
# 384-)
# sentiment: True, probability: 0.9169772863388062
# 385-)
# sentiment: True, probability: 0.9211001992225647
# 386-)
# sentiment: True, probability: 0.9206403493881226
# 387-)
# sentiment: True, probability: 0.9207957983016968
# 388-)
# sentiment: Fake, probability: 0.05571628361940384
# 389-)
# sentiment: Fake, probability: 0.2728075385093689
# 390-)
# sentiment: True, probability: 0.9210595488548279
# 391-)
# sentiment: Fake, probability: 0.05552120506763458
# 392-)
# sentiment: True, probability: 0.9172094464302063
# 393-)
# sentiment: True, probability: 0.9153285622596741
# 394-)
# sentiment: True, probability: 0.9210687875747681
# 395-)
# sentiment: Fake, probability: 0.055214185267686844
# 396-)
# sentiment: Fake, probability: 0.05514918640255928
# 397-)
# sentiment: True, probability: 0.912238359451294
# 398-)
# sentiment: Fake, probability: 0.06193678453564644
# 399-)
# sentiment: True, probability: 0.917243480682373
# 400-)
# sentiment: Fake, probability: 0.057893507182598114
# 401-)
# sentiment: Fake, probability: 0.05532423406839371
# 402-)
# sentiment: Fake, probability: 0.05517418310046196
# 403-)
# sentiment: True, probability: 0.919641375541687
# 404-)
# sentiment: Fake, probability: 0.05527808517217636
# 405-)
# sentiment: True, probability: 0.9212304353713989
# 406-)
# sentiment: True, probability: 0.9210644960403442
# 407-)
# sentiment: True, probability: 0.9212225079536438
# 408-)
# sentiment: True, probability: 0.920764148235321
# 409-)
# sentiment: Fake, probability: 0.057556409388780594
# 410-)
# sentiment: True, probability: 0.9172165989875793
# 411-)
# sentiment: Fake, probability: 0.05507659167051315
# 412-)
# sentiment: Fake, probability: 0.0555448979139328
# 413-)
# sentiment: True, probability: 0.9211341142654419
# 414-)
# sentiment: True, probability: 0.9209631085395813
# 415-)
# sentiment: True, probability: 0.9160687327384949
# 416-)
# sentiment: Fake, probability: 0.055002812296152115
# 417-)
# sentiment: True, probability: 0.9207533597946167
# 418-)
# sentiment: Fake, probability: 0.056359823793172836
# 419-)
# sentiment: Fake, probability: 0.059345874935388565
# 420-)
# sentiment: True, probability: 0.9204106330871582
# 421-)
# sentiment: Fake, probability: 0.05508347600698471
# 422-)
# sentiment: True, probability: 0.9187972545623779
# 423-)
# sentiment: True, probability: 0.921127200126648
# 424-)
# sentiment: Fake, probability: 0.058009371161460876
# 425-)
# sentiment: True, probability: 0.9209645390510559
# 426-)
# sentiment: True, probability: 0.9211472272872925
# 427-)
# sentiment: True, probability: 0.921189546585083
# 428-)
# sentiment: True, probability: 0.921209990978241
# 429-)
# sentiment: True, probability: 0.9212070107460022
# 430-)
# sentiment: True, probability: 0.9211406707763672
# 431-)
# sentiment: True, probability: 0.9211399555206299
# 432-)
# sentiment: True, probability: 0.920516312122345
# 433-)
# sentiment: True, probability: 0.9211923480033875
# 434-)
# sentiment: True, probability: 0.9178455471992493
# 435-)
# sentiment: Fake, probability: 0.058162983506917953
# 436-)
# sentiment: Fake, probability: 0.055715397000312805
# 437-)
# sentiment: Fake, probability: 0.05508185178041458
# 438-)
# sentiment: Fake, probability: 0.057561829686164856
# 439-)
# sentiment: True, probability: 0.9211755990982056
# 440-)
# sentiment: True, probability: 0.9121618270874023
# 441-)
# sentiment: Fake, probability: 0.057037536054849625
# 442-)
# sentiment: Fake, probability: 0.05581928417086601
# 443-)
# sentiment: Fake, probability: 0.05535832419991493
# 444-)
# sentiment: Fake, probability: 0.062491923570632935
# 445-)
# sentiment: Fake, probability: 0.06086975336074829
# 446-)
# sentiment: Fake, probability: 0.0551471970975399
# 447-)
# sentiment: True, probability: 0.9211785197257996
# 448-)
# sentiment: True, probability: 0.9212297201156616
# 449-)
# sentiment: Fake, probability: 0.05582251399755478
# 450-)
# sentiment: True, probability: 0.9107141494750977
# 451-)
# sentiment: True, probability: 0.9143750071525574
# 452-)
# sentiment: True, probability: 0.9208893179893494
# 453-)
# sentiment: Fake, probability: 0.0560305193066597
# 454-)
# sentiment: Fake, probability: 0.09926706552505493
# 455-)
# sentiment: Fake, probability: 0.0588720366358757
# 456-)
# sentiment: True, probability: 0.9194751381874084
# 457-)
# sentiment: True, probability: 0.9212198853492737
# 458-)
# sentiment: True, probability: 0.9212220311164856
# 459-)
# sentiment: Fake, probability: 0.055440254509449005
# 460-)
# sentiment: Fake, probability: 0.05786817893385887
# 461-)
# sentiment: Fake, probability: 0.12811517715454102
# 462-)
# sentiment: Fake, probability: 0.055078811943531036
# 463-)
# sentiment: Fake, probability: 0.054775137454271317
# 464-)
# sentiment: Fake, probability: 0.06090366095304489
# 465-)
# sentiment: Fake, probability: 0.05552639067173004
# 466-)
# sentiment: Fake, probability: 0.054915644228458405
# 467-)
# sentiment: Fake, probability: 0.062126342207193375
# 468-)
# sentiment: True, probability: 0.9209475517272949
# 469-)
# sentiment: Fake, probability: 0.05991561710834503
# 470-)
# sentiment: Fake, probability: 0.05627277493476868
# 471-)
# sentiment: True, probability: 0.9210120439529419
# 472-)
# sentiment: True, probability: 0.9205320477485657
# 473-)
# sentiment: Fake, probability: 0.05581280216574669
# 474-)
# sentiment: True, probability: 0.9206411838531494
# 475-)
# sentiment: True, probability: 0.920681357383728
# 476-)
# sentiment: Fake, probability: 0.05895816162228584
# 477-)
# sentiment: Fake, probability: 0.05828147754073143
# 478-)
# sentiment: True, probability: 0.9203848838806152
# 479-)
# sentiment: Fake, probability: 0.0554887093603611
# 480-)
# sentiment: True, probability: 0.9211387634277344
# 481-)
# sentiment: Fake, probability: 0.05665367469191551
# 482-)
# sentiment: True, probability: 0.9208282232284546
# 483-)
# sentiment: True, probability: 0.9212320446968079
# 484-)
# sentiment: Fake, probability: 0.05580082908272743
# 485-)
# sentiment: Fake, probability: 0.055537428706884384
# 486-)
# sentiment: True, probability: 0.9205403327941895
# 487-)
# sentiment: Fake, probability: 0.055839039385318756
# 488-)
# sentiment: Fake, probability: 0.081019327044487
# 489-)
# sentiment: Fake, probability: 0.06895825266838074
# 490-)
# sentiment: Fake, probability: 0.055738601833581924
# 491-)
# sentiment: True, probability: 0.9206108450889587
# 492-)
# sentiment: Fake, probability: 0.08074953407049179
# 493-)
# sentiment: True, probability: 0.9204068183898926
# 494-)
# sentiment: True, probability: 0.9210271835327148
# 495-)
# sentiment: True, probability: 0.9201629161834717
# 496-)
# sentiment: True, probability: 0.9085621237754822
# 497-)
# sentiment: Fake, probability: 0.05789300799369812
# 498-)
# sentiment: True, probability: 0.9155113697052002
# 499-)
# sentiment: True, probability: 0.9203369617462158
# 500-)
# sentiment: True, probability: 0.9211850762367249
# 501-)
# sentiment: Fake, probability: 0.05852799117565155
# 502-)
# sentiment: Fake, probability: 0.054914385080337524
# 503-)
# sentiment: Fake, probability: 0.05496560409665108
# 504-)
# sentiment: True, probability: 0.9186153411865234
# 505-)
# sentiment: Fake, probability: 0.05694330483675003
# 506-)
# sentiment: True, probability: 0.9212313890457153
# 507-)
# sentiment: True, probability: 0.9212117195129395
# 508-)
# sentiment: Fake, probability: 0.05779361352324486
# 509-)
# sentiment: Fake, probability: 0.05575614795088768
# 510-)
# sentiment: Fake, probability: 0.055241912603378296
# 511-)
# sentiment: True, probability: 0.9211901426315308
# 512-)
# sentiment: Fake, probability: 0.057604242116212845
# 513-)
# sentiment: Fake, probability: 0.05813497304916382
# 514-)
# sentiment: Fake, probability: 0.07584651559591293
# 515-)
# sentiment: True, probability: 0.920438826084137
# 516-)
# sentiment: True, probability: 0.9211944937705994
# 517-)
# sentiment: True, probability: 0.9211891293525696
# 518-)
# sentiment: True, probability: 0.9211371541023254
# 519-)
# sentiment: True, probability: 0.9211375713348389
# 520-)
# sentiment: True, probability: 0.9212366938591003
# 521-)
# sentiment: True, probability: 0.9211922883987427
# 522-)
# sentiment: True, probability: 0.915803074836731
# 523-)
# sentiment: True, probability: 0.9212121963500977
# 524-)
# sentiment: Fake, probability: 0.055502939969301224
# 525-)
# sentiment: Fake, probability: 0.057249680161476135
# 526-)
# sentiment: True, probability: 0.9176024794578552
# 527-)
# sentiment: Fake, probability: 0.05858644098043442
# 528-)
# sentiment: Fake, probability: 0.05587146431207657
# 529-)
# sentiment: True, probability: 0.9179569482803345
# 530-)
# sentiment: True, probability: 0.9208203554153442
# 531-)
# sentiment: True, probability: 0.9212256669998169
# 532-)
# sentiment: True, probability: 0.9212051033973694
# 533-)
# sentiment: True, probability: 0.9211786985397339
# 534-)
# sentiment: Fake, probability: 0.05567707121372223
# 535-)
# sentiment: Fake, probability: 0.05742718279361725
# 536-)
# sentiment: True, probability: 0.9210991263389587
# 537-)
# sentiment: True, probability: 0.9209686517715454
# 538-)
# sentiment: Fake, probability: 0.059017594903707504
# 539-)
# sentiment: Fake, probability: 0.055258750915527344
# 540-)
# sentiment: True, probability: 0.9211953282356262
# 541-)
# sentiment: True, probability: 0.9212272763252258
# 542-)
# sentiment: True, probability: 0.9204711318016052
# 543-)
# sentiment: True, probability: 0.9212354421615601
# 544-)
# sentiment: True, probability: 0.9212268590927124
# 545-)
# sentiment: Fake, probability: 0.05556750297546387
# 546-)
# sentiment: Fake, probability: 0.0552419014275074
# 547-)
# sentiment: True, probability: 0.9211946129798889
# 548-)
# sentiment: Fake, probability: 0.05564940348267555
# 549-)
# sentiment: Fake, probability: 0.05837143957614899
# 550-)
# sentiment: Fake, probability: 0.05680327117443085
# 551-)
# sentiment: Fake, probability: 0.0559186190366745
# 552-)
# sentiment: True, probability: 0.9212197065353394
# 553-)
# sentiment: Fake, probability: 0.10323317348957062
# 554-)
# sentiment: Fake, probability: 0.05549858883023262
# 555-)
# sentiment: Fake, probability: 0.056355152279138565
# 556-)
# sentiment: True, probability: 0.9211615324020386
# 557-)
# sentiment: Fake, probability: 0.05867992714047432
# 558-)
# sentiment: Fake, probability: 0.05520932376384735
# 559-)
# sentiment: True, probability: 0.9212130308151245
# 560-)
# sentiment: Fake, probability: 0.05559593811631203
# 561-)
# sentiment: True, probability: 0.9212262630462646
# 562-)
# sentiment: True, probability: 0.9210477471351624
# 563-)
# sentiment: True, probability: 0.9211745858192444
# 564-)
# sentiment: True, probability: 0.915909469127655
# 565-)
# sentiment: Fake, probability: 0.054858699440956116
# 566-)
# sentiment: Fake, probability: 0.05741823837161064
# 567-)
# sentiment: True, probability: 0.9212144017219543
# 568-)
# sentiment: Fake, probability: 0.055348895490169525
# 569-)
# sentiment: Fake, probability: 0.055274199694395065
# 570-)
# sentiment: True, probability: 0.9212096929550171
# 571-)
# sentiment: True, probability: 0.9185594320297241
# 572-)
# sentiment: Fake, probability: 0.05815858393907547
# 573-)
# sentiment: True, probability: 0.9205111265182495
# 574-)
# sentiment: True, probability: 0.9196048378944397
# 575-)
# sentiment: True, probability: 0.9168320298194885
# 576-)
# sentiment: True, probability: 0.920978844165802
# 577-)
# sentiment: Fake, probability: 0.05504800006747246
# 578-)
# sentiment: Fake, probability: 0.05542973428964615
# 579-)
# sentiment: True, probability: 0.9211068153381348
# 580-)
# sentiment: True, probability: 0.9212220907211304
# 581-)
# sentiment: True, probability: 0.9197919964790344
# 582-)
# sentiment: Fake, probability: 0.05590455234050751
# 583-)
# sentiment: True, probability: 0.9211772680282593
# 584-)
# sentiment: True, probability: 0.9212182760238647
# 585-)
# sentiment: True, probability: 0.9206972718238831
# 586-)
# sentiment: True, probability: 0.9212239384651184
# 587-)
# sentiment: True, probability: 0.9212258458137512
# 588-)
# sentiment: Fake, probability: 0.374847948551178
# 589-)
# sentiment: True, probability: 0.9209511876106262
# 590-)
# sentiment: Fake, probability: 0.1676664501428604
# 591-)
# sentiment: True, probability: 0.9210743308067322
# 592-)
# sentiment: True, probability: 0.9103161692619324
# 593-)
# sentiment: Fake, probability: 0.06027534231543541
# 594-)
# sentiment: True, probability: 0.9210956692695618
# 595-)
# sentiment: Fake, probability: 0.055560559034347534
# 596-)
# sentiment: True, probability: 0.9212247133255005
# 597-)
# sentiment: True, probability: 0.9155128598213196
# 598-)
# sentiment: Fake, probability: 0.057996395975351334
# 599-)
# sentiment: Fake, probability: 0.05852028727531433
# 600-)
# sentiment: Fake, probability: 0.056794267147779465
# 601-)
# sentiment: True, probability: 0.9211033582687378
# 602-)
# sentiment: True, probability: 0.9212192893028259
# 603-)
# sentiment: True, probability: 0.9212271571159363
# 604-)
# sentiment: Fake, probability: 0.055312372744083405
# 605-)
# sentiment: True, probability: 0.914768397808075
# 606-)
# sentiment: True, probability: 0.9211512804031372
# 607-)
# sentiment: Fake, probability: 0.05747567117214203
# 608-)
# sentiment: True, probability: 0.9154987335205078
# 609-)
# sentiment: True, probability: 0.9209518432617188
# 610-)
# sentiment: Fake, probability: 0.05553948134183884
# 611-)
# sentiment: Fake, probability: 0.05593407526612282
# 612-)
# sentiment: True, probability: 0.920936107635498
# 613-)
# sentiment: Fake, probability: 0.06825266778469086
# 614-)
# sentiment: Fake, probability: 0.05561116710305214
# 615-)
# sentiment: Fake, probability: 0.20214278995990753
# 616-)
# sentiment: True, probability: 0.9206377267837524
# 617-)
# sentiment: True, probability: 0.9211871027946472
# 618-)
# sentiment: True, probability: 0.920718789100647
# 619-)
# sentiment: True, probability: 0.9091383814811707
# 620-)
# sentiment: Fake, probability: 0.05611652135848999
# 621-)
# sentiment: Fake, probability: 0.055086057633161545
# 622-)
# sentiment: Fake, probability: 0.05499840900301933
# 623-)
# sentiment: Fake, probability: 0.05527639016509056
# 624-)
# sentiment: Fake, probability: 0.05559878051280975
# 625-)
# sentiment: Fake, probability: 0.05584585294127464
# 626-)
# sentiment: Fake, probability: 0.05572573095560074
# 627-)
# sentiment: Fake, probability: 0.08803799748420715
# 628-)
# sentiment: Fake, probability: 0.06067919358611107
# 629-)
# sentiment: True, probability: 0.9210953712463379
# 630-)
# sentiment: True, probability: 0.9209255576133728
# 631-)
# sentiment: Fake, probability: 0.05533256009221077
# 632-)
# sentiment: Fake, probability: 0.05593045428395271
# 633-)
# sentiment: True, probability: 0.4998537003993988
# 634-)
# sentiment: True, probability: 0.9212394952774048
# 635-)
# sentiment: True, probability: 0.8100003004074097
# 636-)
# sentiment: True, probability: 0.920759916305542
# 637-)
# sentiment: True, probability: 0.9211905598640442
# 638-)
# sentiment: Fake, probability: 0.05549453943967819
# 639-)
# sentiment: Fake, probability: 0.11334995925426483
# 640-)
# sentiment: True, probability: 0.920070469379425
# 641-)
# sentiment: Fake, probability: 0.05549453943967819
# 642-)
# sentiment: Fake, probability: 0.05554698407649994
# 643-)
# sentiment: Fake, probability: 0.0549725666642189
# 644-)
# sentiment: Fake, probability: 0.056283775717020035
# 645-)
# sentiment: True, probability: 0.9212175607681274
# 646-)
# sentiment: Fake, probability: 0.05846065282821655
# 647-)
# sentiment: Fake, probability: 0.11365004628896713
# 648-)
# sentiment: Fake, probability: 0.056180693209171295
# 649-)
# sentiment: True, probability: 0.9150466918945312
# 650-)
# sentiment: Fake, probability: 0.05510306358337402
# 651-)
# sentiment: True, probability: 0.9209940433502197
# 652-)
# sentiment: True, probability: 0.921163022518158
# 653-)
# sentiment: Fake, probability: 0.05502935126423836
# 654-)
# sentiment: True, probability: 0.9201523065567017
# 655-)
# sentiment: True, probability: 0.9212243556976318
# 656-)
# sentiment: Fake, probability: 0.05577997863292694
# 657-)
# sentiment: True, probability: 0.920857846736908
# 658-)
# sentiment: Fake, probability: 0.0564093180000782
# 659-)
# sentiment: True, probability: 0.9211569428443909
# 660-)
# sentiment: Fake, probability: 0.07424601912498474
# 661-)
# sentiment: Fake, probability: 0.05537954345345497
# 662-)
# sentiment: True, probability: 0.921223521232605
# 663-)
# sentiment: True, probability: 0.9133685827255249
# 664-)
# sentiment: Fake, probability: 0.055650219321250916
# 665-)
# sentiment: True, probability: 0.9206395745277405
# 666-)
# sentiment: Fake, probability: 0.056563276797533035
# 667-)
# sentiment: True, probability: 0.9207061529159546
# 668-)
# sentiment: Fake, probability: 0.0551658496260643
# 669-)
# sentiment: Fake, probability: 0.05633736774325371
# 670-)
# sentiment: True, probability: 0.915143609046936
# 671-)
# sentiment: Fake, probability: 0.055625349283218384
# 672-)
# sentiment: Fake, probability: 0.05597896873950958
# 673-)
# sentiment: Fake, probability: 0.05859815329313278
# 674-)
# sentiment: Fake, probability: 0.05502048507332802
# 675-)
# sentiment: Fake, probability: 0.0552772656083107
# 676-)
# sentiment: True, probability: 0.9210930466651917
# 677-)
# sentiment: True, probability: 0.9203749895095825
# 678-)
# sentiment: True, probability: 0.9179806113243103
# 679-)
# sentiment: Fake, probability: 0.05551854148507118
# 680-)
# sentiment: Fake, probability: 0.24228957295417786
# 681-)
# sentiment: True, probability: 0.9212237000465393
# 682-)
# sentiment: Fake, probability: 0.05524665489792824
# 683-)
# sentiment: Fake, probability: 0.055851712822914124
# 684-)
# sentiment: Fake, probability: 0.1313372552394867
# 685-)
# sentiment: Fake, probability: 0.05566663295030594
# 686-)
# sentiment: Fake, probability: 0.47031527757644653
# 687-)
# sentiment: Fake, probability: 0.0588860847055912
# 688-)
# sentiment: Fake, probability: 0.055403608828783035
# 689-)
# sentiment: Fake, probability: 0.05608915165066719
# 690-)
# sentiment: True, probability: 0.9211312532424927
# 691-)
# sentiment: True, probability: 0.9211987257003784
# 692-)
# sentiment: Fake, probability: 0.05562875419855118
# 693-)
# sentiment: True, probability: 0.9209553003311157
# 694-)
# sentiment: True, probability: 0.9211605787277222
# 695-)
# sentiment: Fake, probability: 0.05509178340435028
# 696-)
# sentiment: True, probability: 0.9210705757141113
# 697-)
# sentiment: True, probability: 0.921212911605835
# 698-)
# sentiment: True, probability: 0.9207640290260315
# 699-)
# sentiment: True, probability: 0.9087347984313965
# 700-)
# sentiment: True, probability: 0.9212307929992676
# 701-)
# sentiment: True, probability: 0.9203749895095825
# 702-)
# sentiment: True, probability: 0.9203311800956726
# 703-)
# sentiment: Fake, probability: 0.055597301572561264
# 704-)
# sentiment: Fake, probability: 0.057832393795251846
# 705-)
# sentiment: True, probability: 0.9108322262763977
# 706-)
# sentiment: True, probability: 0.9212210774421692
# 707-)
# sentiment: Fake, probability: 0.0551062747836113
# 708-)
# sentiment: Fake, probability: 0.05496711656451225
# 709-)
# sentiment: True, probability: 0.9211556315422058
# 710-)
# sentiment: Fake, probability: 0.05658768489956856
# 711-)
# sentiment: Fake, probability: 0.061392396688461304
# 712-)
# sentiment: True, probability: 0.918539822101593
# 713-)
# sentiment: Fake, probability: 0.060087189078330994
# 714-)
# sentiment: Fake, probability: 0.05510906130075455
# 715-)
# sentiment: Fake, probability: 0.056214649230241776
# 716-)
# sentiment: Fake, probability: 0.06746872514486313
# 717-)
# sentiment: True, probability: 0.9211809635162354
# 718-)
# sentiment: Fake, probability: 0.05550388619303703
# 719-)
# sentiment: True, probability: 0.9161409735679626
# 720-)
# sentiment: True, probability: 0.9113243222236633
# 721-)
# sentiment: True, probability: 0.9212198853492737
# 722-)
# sentiment: True, probability: 0.9181011915206909
# 723-)
# sentiment: True, probability: 0.920911431312561
# 724-)
# sentiment: True, probability: 0.9212310910224915
# 725-)
# sentiment: True, probability: 0.9202650785446167
# 726-)
# sentiment: Fake, probability: 0.05561782419681549
# 727-)
# sentiment: Fake, probability: 0.0553099699318409
# 728-)
# sentiment: Fake, probability: 0.05643710494041443
# 729-)
# sentiment: Fake, probability: 0.057317230850458145
# 730-)
# sentiment: True, probability: 0.921221911907196
# 731-)
# sentiment: Fake, probability: 0.1138942763209343
# 732-)
# sentiment: Fake, probability: 0.055656470358371735
# 733-)
# sentiment: Fake, probability: 0.05562310665845871
# 734-)
# sentiment: True, probability: 0.9212318062782288
# 735-)
# sentiment: Fake, probability: 0.05845635011792183
# 736-)
# sentiment: Fake, probability: 0.05723138153553009
# 737-)
# sentiment: True, probability: 0.9211386442184448
# 738-)
# sentiment: True, probability: 0.5615789294242859
# 739-)
# sentiment: Fake, probability: 0.05504387989640236
# 740-)
# sentiment: True, probability: 0.921237587928772
# 741-)
# sentiment: Fake, probability: 0.05565838888287544
# 742-)
# sentiment: True, probability: 0.920991837978363
# 743-)
# sentiment: True, probability: 0.9212207794189453
# 744-)
# sentiment: Fake, probability: 0.05545854941010475
# 745-)
# sentiment: True, probability: 0.9210488200187683
# 746-)
# sentiment: True, probability: 0.9203099608421326
# 747-)
# sentiment: True, probability: 0.9210554361343384
# 748-)
# sentiment: True, probability: 0.9210094213485718
# 749-)
# sentiment: Fake, probability: 0.055810414254665375
# 750-)
# sentiment: Fake, probability: 0.4868220090866089
# 751-)
# sentiment: Fake, probability: 0.06202322244644165
# 752-)
# sentiment: True, probability: 0.9178674221038818
# 753-)
# sentiment: Fake, probability: 0.05509181693196297
# 754-)
# sentiment: True, probability: 0.9210518002510071
# 755-)
# sentiment: True, probability: 0.9211947917938232
# 756-)
# sentiment: True, probability: 0.9145877361297607
# 757-)
# sentiment: True, probability: 0.9212262630462646
# 758-)
# sentiment: Fake, probability: 0.22557246685028076
# 759-)
# sentiment: Fake, probability: 0.0557829812169075
# 760-)
# sentiment: True, probability: 0.9211908578872681
# 761-)
# sentiment: Fake, probability: 0.055465202778577805
# 762-)
# sentiment: Fake, probability: 0.055498216301202774
# 763-)
# sentiment: True, probability: 0.9194567203521729
# 764-)
# sentiment: Fake, probability: 0.05535515770316124
# 765-)
# sentiment: Fake, probability: 0.058719929307699203
# 766-)
# sentiment: Fake, probability: 0.05630044639110565
# 767-)
# sentiment: True, probability: 0.9212241172790527
# 768-)
# sentiment: True, probability: 0.9167810678482056
# 769-)
# sentiment: Fake, probability: 0.05573570355772972
# 770-)
# sentiment: Fake, probability: 0.05523259565234184
# 771-)
# sentiment: Fake, probability: 0.055668726563453674
# 772-)
# sentiment: True, probability: 0.9124826192855835
# 773-)
# sentiment: Fake, probability: 0.055329978466033936
# 774-)
# sentiment: Fake, probability: 0.20470164716243744
# 775-)
# sentiment: Fake, probability: 0.056405209004879
# 776-)
# sentiment: True, probability: 0.9206995964050293
# 777-)
# sentiment: Fake, probability: 0.056253064423799515
# 778-)
# sentiment: Fake, probability: 0.0553780235350132
# 779-)
# sentiment: True, probability: 0.9212374687194824
# 780-)
# sentiment: True, probability: 0.9202675819396973
# 781-)
# sentiment: True, probability: 0.9210885763168335
# 782-)
# sentiment: True, probability: 0.9196915626525879
# 783-)
# sentiment: True, probability: 0.9212324023246765
# 784-)
# sentiment: True, probability: 0.9212268590927124
# 785-)
# sentiment: Fake, probability: 0.05637789145112038
# 786-)
# sentiment: True, probability: 0.9205913543701172
# 787-)
# sentiment: Fake, probability: 0.05581880360841751
# 788-)
# sentiment: True, probability: 0.9202159643173218
# 789-)
# sentiment: True, probability: 0.9211922883987427
# 790-)
# sentiment: Fake, probability: 0.05609329044818878
# 791-)
# sentiment: Fake, probability: 0.05559949576854706
# 792-)
# sentiment: True, probability: 0.9206604957580566
# 793-)
# sentiment: True, probability: 0.9186868667602539
# 794-)
# sentiment: True, probability: 0.9212272763252258
# 795-)
# sentiment: True, probability: 0.9212162494659424
# 796-)
# sentiment: Fake, probability: 0.055991657078266144
# 797-)
# sentiment: True, probability: 0.9211575984954834
# 798-)
# sentiment: Fake, probability: 0.08024337142705917
# 799-)
# sentiment: Fake, probability: 0.055252619087696075
# 800-)
# sentiment: True, probability: 0.9208405613899231
# 801-)
# sentiment: Fake, probability: 0.05565743148326874
# 802-)
# sentiment: Fake, probability: 0.05567214637994766
# 803-)
# sentiment: True, probability: 0.9205211400985718
# 804-)
# sentiment: True, probability: 0.9204750061035156
# 805-)
# sentiment: Fake, probability: 0.05672820657491684
# 806-)
# sentiment: True, probability: 0.9208021759986877
# 807-)
# sentiment: True, probability: 0.9153661131858826
# 808-)
# sentiment: Fake, probability: 0.05630010366439819
# 809-)
# sentiment: Fake, probability: 0.058507997542619705
# 810-)
# sentiment: Fake, probability: 0.057076070457696915
# 811-)
# sentiment: True, probability: 0.9211258888244629
# 812-)
# sentiment: Fake, probability: 0.0551222562789917
# 813-)
# sentiment: True, probability: 0.9206441044807434
# 814-)
# sentiment: Fake, probability: 0.05607140436768532
# 815-)
# sentiment: True, probability: 0.9139657616615295
# 816-)
# sentiment: True, probability: 0.9211764931678772
# 817-)
# sentiment: True, probability: 0.9212092757225037
# 818-)
# sentiment: Fake, probability: 0.05583823844790459
# 819-)
# sentiment: True, probability: 0.9212267398834229
# 820-)
# sentiment: True, probability: 0.9201974272727966
# 821-)
# sentiment: True, probability: 0.9208842515945435
# 822-)
# sentiment: True, probability: 0.9212336540222168
# 823-)
# sentiment: Fake, probability: 0.06359217315912247
# 824-)
# sentiment: True, probability: 0.9212287664413452
# 825-)
# sentiment: True, probability: 0.9212043285369873
# 826-)
# sentiment: True, probability: 0.9210662245750427
# 827-)
# sentiment: True, probability: 0.9210408329963684
# 828-)
# sentiment: True, probability: 0.9179896712303162
# 829-)
# sentiment: True, probability: 0.9106691479682922
# 830-)
# sentiment: Fake, probability: 0.05734487250447273
# 831-)
# sentiment: True, probability: 0.9211457371711731
# 832-)
# sentiment: True, probability: 0.9207567572593689
# 833-)
# sentiment: Fake, probability: 0.05579180642962456
# 834-)
# sentiment: True, probability: 0.9208094477653503
# 835-)
# sentiment: True, probability: 0.917529284954071
# 836-)
# sentiment: Fake, probability: 0.055811721831560135
# 837-)
# sentiment: Fake, probability: 0.06255275011062622
# 838-)
# sentiment: True, probability: 0.9202064871788025
# 839-)
# sentiment: True, probability: 0.9209544062614441
# 840-)
# sentiment: True, probability: 0.9212166666984558
# 841-)
# sentiment: Fake, probability: 0.059619102627038956
# 842-)
# sentiment: True, probability: 0.9202990531921387
# 843-)
# sentiment: True, probability: 0.9212290048599243
# 844-)
# sentiment: Fake, probability: 0.05576876923441887
# 845-)
# sentiment: Fake, probability: 0.05591094493865967
# 846-)
# sentiment: Fake, probability: 0.05489860475063324
# 847-)
# sentiment: True, probability: 0.9149901866912842
# 848-)
# sentiment: Fake, probability: 0.056607820093631744
# 849-)
# sentiment: True, probability: 0.9203727841377258
# 850-)
# sentiment: Fake, probability: 0.3897853493690491
# 851-)
# sentiment: Fake, probability: 0.06540481746196747
# 852-)
# sentiment: Fake, probability: 0.05546986311674118
# 853-)
# sentiment: True, probability: 0.921000599861145
# 854-)
# sentiment: Fake, probability: 0.05606056749820709
# 855-)
# sentiment: True, probability: 0.9186153411865234
# 856-)
# sentiment: True, probability: 0.9212256669998169
# 857-)
# sentiment: True, probability: 0.9145455956459045
# 858-)
# sentiment: True, probability: 0.9209619760513306
# 859-)
# sentiment: Fake, probability: 0.05663908272981644
# 860-)
# sentiment: True, probability: 0.9212030172348022
# 861-)
# sentiment: Fake, probability: 0.43696439266204834
# 862-)
# sentiment: Fake, probability: 0.05571405217051506
# 863-)
# sentiment: Fake, probability: 0.05662783980369568
# 864-)
# sentiment: Fake, probability: 0.0555984266102314
# 865-)
# sentiment: Fake, probability: 0.055565476417541504
# 866-)
# sentiment: Fake, probability: 0.058787886053323746
# 867-)
# sentiment: Fake, probability: 0.055300984531641006
# 868-)
# sentiment: True, probability: 0.9212249517440796
# 869-)
# sentiment: Fake, probability: 0.056045882403850555
# 870-)
# sentiment: True, probability: 0.921226441860199
# 871-)
# sentiment: True, probability: 0.9210603833198547
# 872-)
# sentiment: True, probability: 0.9209274053573608
# 873-)
# sentiment: True, probability: 0.9208852648735046
# 874-)
# sentiment: Fake, probability: 0.05493730306625366
# 875-)
# sentiment: Fake, probability: 0.056324634701013565
# 876-)
# sentiment: True, probability: 0.9204391241073608
# 877-)
# sentiment: Fake, probability: 0.055665455758571625
# 878-)
# sentiment: True, probability: 0.9201217889785767
# 879-)
# sentiment: True, probability: 0.9210968613624573
# 880-)
# sentiment: True, probability: 0.9211959838867188
# 881-)
# sentiment: Fake, probability: 0.0663350522518158
# 882-)
# sentiment: True, probability: 0.921209454536438
# 883-)
# sentiment: True, probability: 0.9210865497589111
# 884-)
# sentiment: Fake, probability: 0.05659946799278259
# 885-)
# sentiment: True, probability: 0.9208417534828186
# 886-)
# sentiment: True, probability: 0.9188644886016846
# 887-)
# sentiment: True, probability: 0.9205335974693298
# 888-)
# sentiment: Fake, probability: 0.21116873621940613
# 889-)
# sentiment: Fake, probability: 0.05609738826751709
# 890-)
# sentiment: Fake, probability: 0.06103820353746414
# 891-)
# sentiment: Fake, probability: 0.057067424058914185
# 892-)
# sentiment: True, probability: 0.921231210231781
# 893-)
# sentiment: True, probability: 0.9210376143455505
# 894-)
# sentiment: True, probability: 0.9203765392303467
# 895-)
# sentiment: Fake, probability: 0.06384018808603287
# 896-)
# sentiment: Fake, probability: 0.05646636709570885
# 897-)
# sentiment: Fake, probability: 0.05818881094455719
# 898-)
# sentiment: True, probability: 0.9205750226974487
# 899-)
# sentiment: True, probability: 0.9212294220924377
# 900-)
# sentiment: True, probability: 0.9127990007400513
# 901-)
# sentiment: Fake, probability: 0.0559358075261116
# 902-)
# sentiment: True, probability: 0.9155529141426086
# 903-)
# sentiment: True, probability: 0.9212015867233276
# 904-)
# sentiment: True, probability: 0.9209805727005005
# 905-)
# sentiment: True, probability: 0.9152626395225525
# 906-)
# sentiment: True, probability: 0.908393919467926
# 907-)
# sentiment: True, probability: 0.9139657616615295
# 908-)
# sentiment: True, probability: 0.9200366735458374
# 909-)
# sentiment: True, probability: 0.9203765392303467
# 910-)
# sentiment: Fake, probability: 0.05537106469273567
# 911-)
# sentiment: Fake, probability: 0.0553988553583622
# 912-)
# sentiment: True, probability: 0.9206404685974121
# 913-)
# sentiment: True, probability: 0.9178587794303894
# 914-)
# sentiment: True, probability: 0.9207433462142944
# 915-)
# sentiment: True, probability: 0.9206957221031189
# 916-)
# sentiment: Fake, probability: 0.08316612988710403
# 917-)
# sentiment: Fake, probability: 0.05495893210172653
# 918-)
# sentiment: Fake, probability: 0.05565226078033447
# 919-)
# sentiment: Fake, probability: 0.0554082915186882
# 920-)
# sentiment: Fake, probability: 0.05653269588947296
# 921-)
# sentiment: True, probability: 0.9212178587913513
# 922-)
# sentiment: True, probability: 0.640334963798523
# 923-)
# sentiment: Fake, probability: 0.0572487935423851
# 924-)
# sentiment: Fake, probability: 0.0560963936150074
# 925-)
# sentiment: Fake, probability: 0.056388676166534424
# 926-)
# sentiment: Fake, probability: 0.055179208517074585
# 927-)
# sentiment: Fake, probability: 0.05891229212284088
# 928-)
# sentiment: True, probability: 0.9211034774780273
# 929-)
# sentiment: True, probability: 0.9208155870437622
# 930-)
# sentiment: Fake, probability: 0.05597352609038353
# 931-)
# sentiment: True, probability: 0.9212284684181213
# 932-)
# sentiment: Fake, probability: 0.056116070598363876
# 933-)
# sentiment: True, probability: 0.9206785559654236
# 934-)
# sentiment: True, probability: 0.920717179775238
# 935-)
# sentiment: Fake, probability: 0.05843892693519592
# 936-)
# sentiment: True, probability: 0.921224057674408
# 937-)
# sentiment: Fake, probability: 0.05552365630865097
# 938-)
# sentiment: Fake, probability: 0.05607665330171585
# 939-)
# sentiment: True, probability: 0.9180186986923218
# 940-)
# sentiment: True, probability: 0.9211385250091553
# 941-)
# sentiment: True, probability: 0.921181857585907
# 942-)
# sentiment: Fake, probability: 0.055078499019145966
# 943-)
# sentiment: Fake, probability: 0.05610205978155136
# 944-)
# sentiment: Fake, probability: 0.058267779648303986
# 945-)
# sentiment: True, probability: 0.9109042882919312
# 946-)
# sentiment: Fake, probability: 0.05532841756939888
# 947-)
# sentiment: True, probability: 0.9212275743484497
# 948-)
# sentiment: Fake, probability: 0.05523485690355301
# 949-)
# sentiment: Fake, probability: 0.056039173156023026
# 950-)
# sentiment: Fake, probability: 0.05586450174450874
# 951-)
# sentiment: True, probability: 0.9209917187690735
# 952-)
# sentiment: Fake, probability: 0.05910518020391464
# 953-)
# sentiment: True, probability: 0.9212146997451782
# 954-)
# sentiment: Fake, probability: 0.060681361705064774
# 955-)
# sentiment: Fake, probability: 0.11656536906957626
# 956-)
# sentiment: Fake, probability: 0.05825173109769821
# 957-)
# sentiment: Fake, probability: 0.061064306646585464
# 958-)
# sentiment: Fake, probability: 0.05539597570896149
# 959-)
# sentiment: Fake, probability: 0.05917193368077278
# 960-)
# sentiment: True, probability: 0.9211304783821106
# 961-)
# sentiment: True, probability: 0.9211445450782776
# 962-)
# sentiment: Fake, probability: 0.05620058253407478
# 963-)
# sentiment: Fake, probability: 0.05575195699930191
# 964-)
# sentiment: Fake, probability: 0.19551879167556763
# 965-)
# sentiment: Fake, probability: 0.05648765712976456
# 966-)
# sentiment: Fake, probability: 0.06166527047753334
# 967-)
# sentiment: True, probability: 0.9119526147842407
# 968-)
# sentiment: Fake, probability: 0.06482518464326859
# 969-)
# sentiment: True, probability: 0.9211950898170471
# 970-)
# sentiment: Fake, probability: 0.09615427255630493
# 971-)
# sentiment: True, probability: 0.9212316274642944
# 972-)
# sentiment: True, probability: 0.9211917519569397
# 973-)
# sentiment: Fake, probability: 0.2562844157218933
# 974-)
# sentiment: Fake, probability: 0.05593113601207733
# 975-)
# sentiment: True, probability: 0.9207574725151062
# 976-)
# sentiment: Fake, probability: 0.4574231505393982
# 977-)
# sentiment: True, probability: 0.9212123155593872
# 978-)
# sentiment: Fake, probability: 0.05520714446902275
# 979-)
# sentiment: Fake, probability: 0.0564882792532444
# 980-)
# sentiment: True, probability: 0.9211910367012024
# 981-)
# sentiment: True, probability: 0.9211342334747314
# 982-)
# sentiment: True, probability: 0.9212096929550171
# 983-)
# sentiment: Fake, probability: 0.055113911628723145
# 984-)
# sentiment: Fake, probability: 0.05510552227497101
# 985-)
# sentiment: Fake, probability: 0.09606990963220596
# 986-)
# sentiment: Fake, probability: 0.05750122293829918
# 987-)
# sentiment: Fake, probability: 0.11553400754928589
# 988-)
# sentiment: True, probability: 0.9209763407707214
# 989-)
# sentiment: Fake, probability: 0.05544942989945412
# 990-)
# sentiment: True, probability: 0.9208951592445374
# 991-)
# sentiment: True, probability: 0.921204686164856
# 992-)
# sentiment: True, probability: 0.9203154444694519
# 993-)
# sentiment: Fake, probability: 0.055376190692186356
# 994-)
# sentiment: Fake, probability: 0.05525285005569458
# 995-)
# sentiment: True, probability: 0.9208077192306519
# 996-)
# sentiment: True, probability: 0.9078643918037415
# 997-)
# sentiment: Fake, probability: 0.05840151011943817
# 998-)
# sentiment: Fake, probability: 0.056179631501436234
# 999-)
# sentiment: True, probability: 0.9212319254875183
# 957

# %%
from sklearn.metrics import confusion_matrix

# %%
y_true=submission["Truth"].tolist()

# %%
conf_matrix=confusion_matrix(y_true, y_pred)
conf_matrix
# Out:
# array([[464,  28],
#        [ 15, 493]])

# %%
TP = conf_matrix[1][1]
TN = conf_matrix[0][0]
FP = conf_matrix[0][1]
FN = conf_matrix[1][0]
print('True Positives:', TP)
print('True Negatives:', TN)
print('False Positives:', FP)
print('False Negatives:', FN)
# Out:
# True Positives: 493
# True Negatives: 464
# False Positives: 28
# False Negatives: 15

# %%
conf_accuracy = (float (TP+TN) / float(TP + TN + FP + FN))

conf_error_rate = 1- conf_accuracy
    
conf_sensitivity = (TP / float(TP + FN)) #recall

conf_specificity = (TN / float(TN + FP))
    
conf_precision = (TN / float(TN + FP))

conf_f1 = 2 * ((conf_precision * conf_sensitivity) / (conf_precision + conf_sensitivity))
print('-'*50)
print(f'Accuracy: {round(conf_accuracy,2)}') 
print(f'Error_rate: {round(conf_error_rate,2)}') 
print(f'Sensitivity: {round(conf_sensitivity,2)}') 
print(f'Specificity: {round(conf_specificity,2)}') 
print(f'Precision: {round(conf_precision,2)}')
print(f'f_1 Score: {round(conf_f1,2)}')
# Out:
# --------------------------------------------------
# Accuracy: 0.96
# Error_rate: 0.04
# Sensitivity: 0.97
# Specificity: 0.94
# Precision: 0.94
# f_1 Score: 0.96
