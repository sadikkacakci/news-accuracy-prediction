# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.25.1-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 6.4 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 67.4 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 79.8 MB/s
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (21.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.8.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (3.0.4)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.11.1 tokenizers-0.13.2 transformers-4.25.1

# %%
model_name="roberta-base"

# %%
from transformers import AutoModelForSequenceClassification
new_model = AutoModelForSequenceClassification.from_pretrained("/content/drive/MyDrive/Colab Notebooks/roberta-base/model")

# %%
from transformers import AutoTokenizer
new_tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# Downloading:   0%|          | 0.00/481 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
import nltk
from nltk.stem.porter import PorterStemmer
import re
from nltk.corpus import stopwords
nltk.download("stopwords")
def preprocessing(text):
    ps = PorterStemmer()
    sentence = re.sub('[^a-zA-Z]',' ',text) # noktalama işaretlerini silme.
    sentence = sentence.lower() # kelimelerin hepsini küçük harf 
    sentence = sentence.split() # keliemeleri listeye atma
    sentence = [ps.stem(kelime) for kelime in sentence if not kelime in set(stopwords.words("english"))] #anlamı olmayan(stopwords) kelimeleri listeden atma
    sentence = " ".join(sentence) # listede kalan kelimeleri birleştirip yeni cümleyi oluşturma.
    return sentence
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
sentence = preprocessing("I wanted to go home.")
print(sentence)
# Out:
# want go home

# %%
import torch
import numpy as np

def get_prediction(text):
    text = preprocessing(text)
    encoding = new_tokenizer(text, return_tensors="pt", padding="max_length", truncation=True, max_length=128)
    # encoding = {k: v.to(trainer.model.device) for k,v in encoding.items()}
    outputs = new_model(**encoding)

    logits = outputs.logits

    sigmoid = torch.nn.Sigmoid()
    probs = sigmoid(logits.squeeze().cpu())
    probs = probs.detach().numpy()
    label = np.argmax(probs, axis=-1) # değeri 0 veya 1'e yuvarlıyoruz.
    
    if label == 1:
        print(f"sentiment: True, probability: {probs[1]}")
        return 1
    else:
        print(f"sentiment: Fake, probability: {probs[1]}")
        return 0

# %%
get_prediction("He goes to airport.")
# Out:
# sentiment: True, probability: 0.9391817450523376
# 1

# %%
submission = pd.read_csv("/content/drive/MyDrive/submission.csv")
# y = submission["Truth"]
# x = submission["Haber"]

# %%
accuracy = 0
y_pred = []
for i in range(submission.shape[0]):
    row = submission.iloc[i]
    text = row[0]
    truth_value = row[1]
    print(f"{i}-)")
    result = get_prediction(text)
    y_pred.append(result)
    if(result == int(truth_value)):
        accuracy += 1 
accuracy
# Out:
# 0-)
# sentiment: True, probability: 0.9394164085388184
# 1-)
# sentiment: Fake, probability: 0.04899635910987854
# 2-)
# sentiment: Fake, probability: 0.052601248025894165
# 3-)
# sentiment: True, probability: 0.939200758934021
# 4-)
# sentiment: Fake, probability: 0.05130833387374878
# 5-)
# sentiment: True, probability: 0.9394165277481079
# 6-)
# sentiment: True, probability: 0.9393579363822937
# 7-)
# sentiment: Fake, probability: 0.04509388282895088
# 8-)
# sentiment: True, probability: 0.9386608004570007
# 9-)
# sentiment: True, probability: 0.9393612742424011
# 10-)
# sentiment: True, probability: 0.9393813610076904
# 11-)
# sentiment: True, probability: 0.9393183588981628
# 12-)
# sentiment: True, probability: 0.9391000866889954
# 13-)
# sentiment: True, probability: 0.9388035535812378
# 14-)
# sentiment: True, probability: 0.9393751621246338
# 15-)
# sentiment: True, probability: 0.938866913318634
# 16-)
# sentiment: Fake, probability: 0.04777415469288826
# 17-)
# sentiment: True, probability: 0.9390647411346436
# 18-)
# sentiment: Fake, probability: 0.04569485783576965
# 19-)
# sentiment: True, probability: 0.9381591081619263
# 20-)
# sentiment: Fake, probability: 0.04500366374850273
# 21-)
# sentiment: True, probability: 0.9390271902084351
# 22-)
# sentiment: Fake, probability: 0.052066199481487274
# 23-)
# sentiment: Fake, probability: 0.04515869542956352
# 24-)
# sentiment: True, probability: 0.9390162825584412
# 25-)
# sentiment: Fake, probability: 0.0987681970000267
# 26-)
# sentiment: Fake, probability: 0.08325930684804916
# 27-)
# sentiment: True, probability: 0.9394969940185547
# 28-)
# sentiment: True, probability: 0.9388317465782166
# 29-)
# sentiment: True, probability: 0.9394290447235107
# 30-)
# sentiment: Fake, probability: 0.12121786922216415
# 31-)
# sentiment: Fake, probability: 0.052994344383478165
# 32-)
# sentiment: True, probability: 0.9394010305404663
# 33-)
# sentiment: Fake, probability: 0.05330333858728409
# 34-)
# sentiment: True, probability: 0.9393266439437866
# 35-)
# sentiment: True, probability: 0.9393272995948792
# 36-)
# sentiment: Fake, probability: 0.04959801211953163
# 37-)
# sentiment: True, probability: 0.9394981265068054
# 38-)
# sentiment: True, probability: 0.9392092823982239
# 39-)
# sentiment: True, probability: 0.9394609928131104
# 40-)
# sentiment: Fake, probability: 0.15438923239707947
# 41-)
# sentiment: Fake, probability: 0.04753294587135315
# 42-)
# sentiment: Fake, probability: 0.05006876960396767
# 43-)
# sentiment: True, probability: 0.9391873478889465
# 44-)
# sentiment: Fake, probability: 0.046947039663791656
# 45-)
# sentiment: Fake, probability: 0.05131518468260765
# 46-)
# sentiment: True, probability: 0.9393161535263062
# 47-)
# sentiment: True, probability: 0.939265251159668
# 48-)
# sentiment: True, probability: 0.9395383596420288
# 49-)
# sentiment: True, probability: 0.9393942952156067
# 50-)
# sentiment: True, probability: 0.9392848014831543
# 51-)
# sentiment: True, probability: 0.9391157031059265
# 52-)
# sentiment: True, probability: 0.9395008683204651
# 53-)
# sentiment: True, probability: 0.9389305114746094
# 54-)
# sentiment: True, probability: 0.9383115172386169
# 55-)
# sentiment: Fake, probability: 0.04635094478726387
# 56-)
# sentiment: Fake, probability: 0.04649420827627182
# 57-)
# sentiment: True, probability: 0.9391685128211975
# 58-)
# sentiment: True, probability: 0.9390673637390137
# 59-)
# sentiment: Fake, probability: 0.05505136027932167
# 60-)
# sentiment: Fake, probability: 0.05334009975194931
# 61-)
# sentiment: Fake, probability: 0.05145867168903351
# 62-)
# sentiment: Fake, probability: 0.045014116913080215
# 63-)
# sentiment: Fake, probability: 0.04615930840373039
# 64-)
# sentiment: True, probability: 0.9394909143447876
# 65-)
# sentiment: True, probability: 0.9394189119338989
# 66-)
# sentiment: True, probability: 0.9392579793930054
# 67-)
# sentiment: Fake, probability: 0.05044759064912796
# 68-)
# sentiment: True, probability: 0.9385170340538025
# 69-)
# sentiment: Fake, probability: 0.04658894240856171
# 70-)
# sentiment: True, probability: 0.9383493065834045
# 71-)
# sentiment: True, probability: 0.9390872120857239
# 72-)
# sentiment: True, probability: 0.9390351176261902
# 73-)
# sentiment: Fake, probability: 0.051060181111097336
# 74-)
# sentiment: Fake, probability: 0.045150645077228546
# 75-)
# sentiment: True, probability: 0.939362645149231
# 76-)
# sentiment: Fake, probability: 0.04495688155293465
# 77-)
# sentiment: Fake, probability: 0.04726138338446617
# 78-)
# sentiment: Fake, probability: 0.05195201188325882
# 79-)
# sentiment: Fake, probability: 0.052624113857746124
# 80-)
# sentiment: True, probability: 0.93829345703125
# 81-)
# sentiment: Fake, probability: 0.04630324989557266
# 82-)
# sentiment: Fake, probability: 0.051733843982219696
# 83-)
# sentiment: Fake, probability: 0.04537854716181755
# 84-)
# sentiment: Fake, probability: 0.052587512880563736
# 85-)
# sentiment: True, probability: 0.9394524097442627
# 86-)
# sentiment: Fake, probability: 0.04589758813381195
# 87-)
# sentiment: Fake, probability: 0.04544825106859207
# 88-)
# sentiment: Fake, probability: 0.04647029563784599
# 89-)
# sentiment: Fake, probability: 0.050841446965932846
# 90-)
# sentiment: True, probability: 0.9395412802696228
# 91-)
# sentiment: Fake, probability: 0.04495954141020775
# 92-)
# sentiment: Fake, probability: 0.04510654881596565
# 93-)
# sentiment: True, probability: 0.9388703107833862
# 94-)
# sentiment: True, probability: 0.9387499094009399
# 95-)
# sentiment: Fake, probability: 0.052331626415252686
# 96-)
# sentiment: Fake, probability: 0.04647525027394295
# 97-)
# sentiment: True, probability: 0.9378761053085327
# 98-)
# sentiment: Fake, probability: 0.0885162428021431
# 99-)
# sentiment: Fake, probability: 0.0527350977063179
# 100-)
# sentiment: True, probability: 0.9393869638442993
# 101-)
# sentiment: True, probability: 0.9393165707588196
# 102-)
# sentiment: True, probability: 0.9393154978752136
# 103-)
# sentiment: True, probability: 0.9393236041069031
# 104-)
# sentiment: Fake, probability: 0.04892842471599579
# 105-)
# sentiment: True, probability: 0.9384557008743286
# 106-)
# sentiment: True, probability: 0.9391407370567322
# 107-)
# sentiment: Fake, probability: 0.05529366433620453
# 108-)
# sentiment: Fake, probability: 0.049536753445863724
# 109-)
# sentiment: True, probability: 0.9386540055274963
# 110-)
# sentiment: True, probability: 0.9393593668937683
# 111-)
# sentiment: Fake, probability: 0.046632103621959686
# 112-)
# sentiment: True, probability: 0.9384187459945679
# 113-)
# sentiment: True, probability: 0.9391462206840515
# 114-)
# sentiment: True, probability: 0.725396990776062
# 115-)
# sentiment: Fake, probability: 0.05078616365790367
# 116-)
# sentiment: True, probability: 0.9390681982040405
# 117-)
# sentiment: Fake, probability: 0.045175567269325256
# 118-)
# sentiment: Fake, probability: 0.06293483078479767
# 119-)
# sentiment: True, probability: 0.9390008449554443
# 120-)
# sentiment: True, probability: 0.9391423463821411
# 121-)
# sentiment: Fake, probability: 0.04518222063779831
# 122-)
# sentiment: Fake, probability: 0.052218444645404816
# 123-)
# sentiment: True, probability: 0.9388096928596497
# 124-)
# sentiment: Fake, probability: 0.045135367661714554
# 125-)
# sentiment: True, probability: 0.9393151998519897
# 126-)
# sentiment: True, probability: 0.9389182329177856
# 127-)
# sentiment: True, probability: 0.9389767646789551
# 128-)
# sentiment: True, probability: 0.9393064975738525
# 129-)
# sentiment: True, probability: 0.9390875697135925
# 130-)
# sentiment: Fake, probability: 0.05600525811314583
# 131-)
# sentiment: True, probability: 0.8091497421264648
# 132-)
# sentiment: True, probability: 0.9394920468330383
# 133-)
# sentiment: True, probability: 0.9374576210975647
# 134-)
# sentiment: Fake, probability: 0.0528002604842186
# 135-)
# sentiment: True, probability: 0.9393835663795471
# 136-)
# sentiment: Fake, probability: 0.050406068563461304
# 137-)
# sentiment: Fake, probability: 0.05244665965437889
# 138-)
# sentiment: Fake, probability: 0.0460985042154789
# 139-)
# sentiment: Fake, probability: 0.05160833150148392
# 140-)
# sentiment: Fake, probability: 0.04497364163398743
# 141-)
# sentiment: Fake, probability: 0.045115403831005096
# 142-)
# sentiment: True, probability: 0.9389756917953491
# 143-)
# sentiment: Fake, probability: 0.0458061508834362
# 144-)
# sentiment: Fake, probability: 0.04960254207253456
# 145-)
# sentiment: True, probability: 0.9389551281929016
# 146-)
# sentiment: True, probability: 0.939298152923584
# 147-)
# sentiment: Fake, probability: 0.04499320313334465
# 148-)
# sentiment: True, probability: 0.9379833340644836
# 149-)
# sentiment: Fake, probability: 0.05146830528974533
# 150-)
# sentiment: True, probability: 0.9391682744026184
# 151-)
# sentiment: True, probability: 0.9393945336341858
# 152-)
# sentiment: True, probability: 0.9393553733825684
# 153-)
# sentiment: True, probability: 0.9392949342727661
# 154-)
# sentiment: True, probability: 0.9394556283950806
# 155-)
# sentiment: True, probability: 0.9391606450080872
# 156-)
# sentiment: True, probability: 0.9393001794815063
# 157-)
# sentiment: Fake, probability: 0.0533582977950573
# 158-)
# sentiment: True, probability: 0.9385462403297424
# 159-)
# sentiment: True, probability: 0.9387536644935608
# 160-)
# sentiment: Fake, probability: 0.053030408918857574
# 161-)
# sentiment: Fake, probability: 0.04860055819153786
# 162-)
# sentiment: True, probability: 0.725396990776062
# 163-)
# sentiment: Fake, probability: 0.05134151503443718
# 164-)
# sentiment: Fake, probability: 0.04837074875831604
# 165-)
# sentiment: True, probability: 0.9394256472587585
# 166-)
# sentiment: True, probability: 0.9389382600784302
# 167-)
# sentiment: True, probability: 0.6610150933265686
# 168-)
# sentiment: True, probability: 0.9392999410629272
# 169-)
# sentiment: Fake, probability: 0.0522286593914032
# 170-)
# sentiment: Fake, probability: 0.04517645388841629
# 171-)
# sentiment: True, probability: 0.9387573599815369
# 172-)
# sentiment: Fake, probability: 0.04495440050959587
# 173-)
# sentiment: True, probability: 0.9394354224205017
# 174-)
# sentiment: Fake, probability: 0.04624534398317337
# 175-)
# sentiment: True, probability: 0.9389594197273254
# 176-)
# sentiment: Fake, probability: 0.0487155057489872
# 177-)
# sentiment: True, probability: 0.9393255114555359
# 178-)
# sentiment: True, probability: 0.9392858743667603
# 179-)
# sentiment: Fake, probability: 0.04497358947992325
# 180-)
# sentiment: True, probability: 0.9394129514694214
# 181-)
# sentiment: Fake, probability: 0.04948689416050911
# 182-)
# sentiment: True, probability: 0.9393414258956909
# 183-)
# sentiment: Fake, probability: 0.0465971902012825
# 184-)
# sentiment: True, probability: 0.9377536773681641
# 185-)
# sentiment: Fake, probability: 0.046426355838775635
# 186-)
# sentiment: True, probability: 0.9394028186798096
# 187-)
# sentiment: True, probability: 0.9393690824508667
# 188-)
# sentiment: True, probability: 0.9379235506057739
# 189-)
# sentiment: Fake, probability: 0.045191872864961624
# 190-)
# sentiment: True, probability: 0.9392778873443604
# 191-)
# sentiment: True, probability: 0.9396371841430664
# 192-)
# sentiment: Fake, probability: 0.04496271535754204
# 193-)
# sentiment: Fake, probability: 0.0851462259888649
# 194-)
# sentiment: True, probability: 0.9393205642700195
# 195-)
# sentiment: True, probability: 0.9394192695617676
# 196-)
# sentiment: Fake, probability: 0.04647217318415642
# 197-)
# sentiment: Fake, probability: 0.045516133308410645
# 198-)
# sentiment: Fake, probability: 0.05358894169330597
# 199-)
# sentiment: True, probability: 0.9394949078559875
# 200-)
# sentiment: Fake, probability: 0.04500309005379677
# 201-)
# sentiment: Fake, probability: 0.04555902257561684
# 202-)
# sentiment: True, probability: 0.9392545223236084
# 203-)
# sentiment: Fake, probability: 0.04496912285685539
# 204-)
# sentiment: Fake, probability: 0.05337483063340187
# 205-)
# sentiment: True, probability: 0.9387953877449036
# 206-)
# sentiment: Fake, probability: 0.05054444819688797
# 207-)
# sentiment: True, probability: 0.937865674495697
# 208-)
# sentiment: True, probability: 0.9390377402305603
# 209-)
# sentiment: True, probability: 0.936870813369751
# 210-)
# sentiment: True, probability: 0.9380086660385132
# 211-)
# sentiment: True, probability: 0.939124345779419
# 212-)
# sentiment: True, probability: 0.9381060600280762
# 213-)
# sentiment: True, probability: 0.938708484172821
# 214-)
# sentiment: Fake, probability: 0.05333005264401436
# 215-)
# sentiment: Fake, probability: 0.04617266356945038
# 216-)
# sentiment: Fake, probability: 0.049144793301820755
# 217-)
# sentiment: True, probability: 0.9389419555664062
# 218-)
# sentiment: True, probability: 0.7911329865455627
# 219-)
# sentiment: True, probability: 0.9389591813087463
# 220-)
# sentiment: True, probability: 0.9394631385803223
# 221-)
# sentiment: Fake, probability: 0.04560675472021103
# 222-)
# sentiment: True, probability: 0.9387969374656677
# 223-)
# sentiment: True, probability: 0.9389515519142151
# 224-)
# sentiment: True, probability: 0.9393414258956909
# 225-)
# sentiment: Fake, probability: 0.04949161037802696
# 226-)
# sentiment: Fake, probability: 0.05270390212535858
# 227-)
# sentiment: Fake, probability: 0.0474870465695858
# 228-)
# sentiment: True, probability: 0.9395290017127991
# 229-)
# sentiment: Fake, probability: 0.04978003352880478
# 230-)
# sentiment: True, probability: 0.9395316243171692
# 231-)
# sentiment: True, probability: 0.9394167065620422
# 232-)
# sentiment: Fake, probability: 0.05450284481048584
# 233-)
# sentiment: True, probability: 0.9394192695617676
# 234-)
# sentiment: Fake, probability: 0.05694366246461868
# 235-)
# sentiment: True, probability: 0.9392741918563843
# 236-)
# sentiment: True, probability: 0.9394059777259827
# 237-)
# sentiment: Fake, probability: 0.054205942898988724
# 238-)
# sentiment: Fake, probability: 0.045326750725507736
# 239-)
# sentiment: True, probability: 0.9392033219337463
# 240-)
# sentiment: True, probability: 0.9395129680633545
# 241-)
# sentiment: True, probability: 0.937461793422699
# 242-)
# sentiment: True, probability: 0.9391241073608398
# 243-)
# sentiment: Fake, probability: 0.05224927142262459
# 244-)
# sentiment: Fake, probability: 0.04952137544751167
# 245-)
# sentiment: True, probability: 0.6555377244949341
# 246-)
# sentiment: Fake, probability: 0.0478813536465168
# 247-)
# sentiment: Fake, probability: 0.048508647829294205
# 248-)
# sentiment: True, probability: 0.9392895698547363
# 249-)
# sentiment: Fake, probability: 0.04550986737012863
# 250-)
# sentiment: True, probability: 0.9390520453453064
# 251-)
# sentiment: Fake, probability: 0.047183964401483536
# 252-)
# sentiment: Fake, probability: 0.045138128101825714
# 253-)
# sentiment: True, probability: 0.9393841028213501
# 254-)
# sentiment: Fake, probability: 0.05432915687561035
# 255-)
# sentiment: True, probability: 0.9394362568855286
# 256-)
# sentiment: Fake, probability: 0.04674939066171646
# 257-)
# sentiment: Fake, probability: 0.049342263489961624
# 258-)
# sentiment: True, probability: 0.9382604956626892
# 259-)
# sentiment: True, probability: 0.9381591081619263
# 260-)
# sentiment: True, probability: 0.9394587874412537
# 261-)
# sentiment: Fake, probability: 0.05303110554814339
# 262-)
# sentiment: Fake, probability: 0.04528973624110222
# 263-)
# sentiment: True, probability: 0.9394532442092896
# 264-)
# sentiment: True, probability: 0.9394858479499817
# 265-)
# sentiment: True, probability: 0.939464271068573
# 266-)
# sentiment: Fake, probability: 0.05382949858903885
# 267-)
# sentiment: True, probability: 0.9394107460975647
# 268-)
# sentiment: True, probability: 0.9391842484474182
# 269-)
# sentiment: True, probability: 0.9389199018478394
# 270-)
# sentiment: True, probability: 0.8293048739433289
# 271-)
# sentiment: Fake, probability: 0.04585705325007439
# 272-)
# sentiment: Fake, probability: 0.044977590441703796
# 273-)
# sentiment: Fake, probability: 0.05504973605275154
# 274-)
# sentiment: True, probability: 0.9384765028953552
# 275-)
# sentiment: Fake, probability: 0.0456075444817543
# 276-)
# sentiment: True, probability: 0.9391669034957886
# 277-)
# sentiment: Fake, probability: 0.049591731280088425
# 278-)
# sentiment: True, probability: 0.9391723871231079
# 279-)
# sentiment: Fake, probability: 0.04505391791462898
# 280-)
# sentiment: Fake, probability: 0.051913484930992126
# 281-)
# sentiment: Fake, probability: 0.04817778617143631
# 282-)
# sentiment: True, probability: 0.9394974112510681
# 283-)
# sentiment: True, probability: 0.939437210559845
# 284-)
# sentiment: Fake, probability: 0.05653770640492439
# 285-)
# sentiment: True, probability: 0.9378374218940735
# 286-)
# sentiment: Fake, probability: 0.045293428003787994
# 287-)
# sentiment: True, probability: 0.9392315149307251
# 288-)
# sentiment: Fake, probability: 0.04501749947667122
# 289-)
# sentiment: True, probability: 0.939171314239502
# 290-)
# sentiment: True, probability: 0.9393013119697571
# 291-)
# sentiment: True, probability: 0.9379956126213074
# 292-)
# sentiment: True, probability: 0.9393731355667114
# 293-)
# sentiment: True, probability: 0.9379377961158752
# 294-)
# sentiment: Fake, probability: 0.04724014922976494
# 295-)
# sentiment: True, probability: 0.9393561482429504
# 296-)
# sentiment: True, probability: 0.9385083317756653
# 297-)
# sentiment: True, probability: 0.9373875260353088
# 298-)
# sentiment: Fake, probability: 0.04637825861573219
# 299-)
# sentiment: True, probability: 0.9393987059593201
# 300-)
# sentiment: Fake, probability: 0.045252639800310135
# 301-)
# sentiment: True, probability: 0.712467610836029
# 302-)
# sentiment: Fake, probability: 0.055218737572431564
# 303-)
# sentiment: Fake, probability: 0.05492768436670303
# 304-)
# sentiment: Fake, probability: 0.05132848769426346
# 305-)
# sentiment: True, probability: 0.9391307830810547
# 306-)
# sentiment: True, probability: 0.9391924738883972
# 307-)
# sentiment: True, probability: 0.9395086765289307
# 308-)
# sentiment: True, probability: 0.9391547441482544
# 309-)
# sentiment: True, probability: 0.9390041828155518
# 310-)
# sentiment: True, probability: 0.9379867911338806
# 311-)
# sentiment: Fake, probability: 0.049292318522930145
# 312-)
# sentiment: True, probability: 0.9394785761833191
# 313-)
# sentiment: Fake, probability: 0.05226096510887146
# 314-)
# sentiment: True, probability: 0.9395310878753662
# 315-)
# sentiment: True, probability: 0.9389087557792664
# 316-)
# sentiment: True, probability: 0.9385491609573364
# 317-)
# sentiment: Fake, probability: 0.045917920768260956
# 318-)
# sentiment: True, probability: 0.939113199710846
# 319-)
# sentiment: Fake, probability: 0.06959500163793564
# 320-)
# sentiment: True, probability: 0.9394173622131348
# 321-)
# sentiment: True, probability: 0.938401460647583
# 322-)
# sentiment: Fake, probability: 0.049283403903245926
# 323-)
# sentiment: True, probability: 0.9393734931945801
# 324-)
# sentiment: True, probability: 0.9369392395019531
# 325-)
# sentiment: True, probability: 0.9389950633049011
# 326-)
# sentiment: True, probability: 0.9381713271141052
# 327-)
# sentiment: True, probability: 0.9394819736480713
# 328-)
# sentiment: True, probability: 0.9390029311180115
# 329-)
# sentiment: Fake, probability: 0.05348645895719528
# 330-)
# sentiment: True, probability: 0.939306378364563
# 331-)
# sentiment: True, probability: 0.9394662976264954
# 332-)
# sentiment: Fake, probability: 0.05511202663183212
# 333-)
# sentiment: Fake, probability: 0.04735718294978142
# 334-)
# sentiment: Fake, probability: 0.5516524910926819
# 335-)
# sentiment: Fake, probability: 0.045363325625658035
# 336-)
# sentiment: True, probability: 0.939041793346405
# 337-)
# sentiment: True, probability: 0.9394569993019104
# 338-)
# sentiment: Fake, probability: 0.051209017634391785
# 339-)
# sentiment: True, probability: 0.9392579793930054
# 340-)
# sentiment: Fake, probability: 0.046358637511730194
# 341-)
# sentiment: True, probability: 0.9392304420471191
# 342-)
# sentiment: Fake, probability: 0.12028686702251434
# 343-)
# sentiment: Fake, probability: 0.04826279729604721
# 344-)
# sentiment: True, probability: 0.9393190741539001
# 345-)
# sentiment: Fake, probability: 0.047463931143283844
# 346-)
# sentiment: Fake, probability: 0.05320260673761368
# 347-)
# sentiment: Fake, probability: 0.045501891523599625
# 348-)
# sentiment: True, probability: 0.9394895434379578
# 349-)
# sentiment: True, probability: 0.9394211173057556
# 350-)
# sentiment: Fake, probability: 0.04611112177371979
# 351-)
# sentiment: True, probability: 0.9386337995529175
# 352-)
# sentiment: True, probability: 0.9377481341362
# 353-)
# sentiment: Fake, probability: 0.05154227837920189
# 354-)
# sentiment: True, probability: 0.9383676648139954
# 355-)
# sentiment: True, probability: 0.9383944272994995
# 356-)
# sentiment: Fake, probability: 0.04737408086657524
# 357-)
# sentiment: True, probability: 0.9394495487213135
# 358-)
# sentiment: Fake, probability: 0.04516395926475525
# 359-)
# sentiment: Fake, probability: 0.04762246459722519
# 360-)
# sentiment: True, probability: 0.9393942952156067
# 361-)
# sentiment: True, probability: 0.9375507831573486
# 362-)
# sentiment: Fake, probability: 0.08517588675022125
# 363-)
# sentiment: True, probability: 0.939094066619873
# 364-)
# sentiment: Fake, probability: 0.5459709167480469
# 365-)
# sentiment: True, probability: 0.9389269351959229
# 366-)
# sentiment: Fake, probability: 0.05170746147632599
# 367-)
# sentiment: Fake, probability: 0.049567945301532745
# 368-)
# sentiment: True, probability: 0.9393831491470337
# 369-)
# sentiment: Fake, probability: 0.1919635832309723
# 370-)
# sentiment: True, probability: 0.9392260313034058
# 371-)
# sentiment: True, probability: 0.9386698603630066
# 372-)
# sentiment: True, probability: 0.9391704201698303
# 373-)
# sentiment: Fake, probability: 0.05404409021139145
# 374-)
# sentiment: Fake, probability: 0.050459813326597214
# 375-)
# sentiment: Fake, probability: 0.0493820495903492
# 376-)
# sentiment: Fake, probability: 0.04870325326919556
# 377-)
# sentiment: True, probability: 0.939586341381073
# 378-)
# sentiment: Fake, probability: 0.05071259289979935
# 379-)
# sentiment: Fake, probability: 0.045062240213155746
# 380-)
# sentiment: True, probability: 0.9390665292739868
# 381-)
# sentiment: True, probability: 0.9393578171730042
# 382-)
# sentiment: True, probability: 0.9375651478767395
# 383-)
# sentiment: True, probability: 0.9389371275901794
# 384-)
# sentiment: True, probability: 0.9393011927604675
# 385-)
# sentiment: True, probability: 0.9392324090003967
# 386-)
# sentiment: True, probability: 0.9394972324371338
# 387-)
# sentiment: True, probability: 0.9386621713638306
# 388-)
# sentiment: Fake, probability: 0.05370500683784485
# 389-)
# sentiment: Fake, probability: 0.18229472637176514
# 390-)
# sentiment: True, probability: 0.9394155740737915
# 391-)
# sentiment: Fake, probability: 0.04685743525624275
# 392-)
# sentiment: True, probability: 0.9380673170089722
# 393-)
# sentiment: True, probability: 0.9393019676208496
# 394-)
# sentiment: True, probability: 0.9390186071395874
# 395-)
# sentiment: Fake, probability: 0.049337077885866165
# 396-)
# sentiment: Fake, probability: 0.05258955433964729
# 397-)
# sentiment: True, probability: 0.9389716982841492
# 398-)
# sentiment: Fake, probability: 0.047768089920282364
# 399-)
# sentiment: True, probability: 0.9384332895278931
# 400-)
# sentiment: Fake, probability: 0.045237574726343155
# 401-)
# sentiment: Fake, probability: 0.044953275471925735
# 402-)
# sentiment: Fake, probability: 0.049748558551073074
# 403-)
# sentiment: True, probability: 0.9391628503799438
# 404-)
# sentiment: Fake, probability: 0.04513261094689369
# 405-)
# sentiment: True, probability: 0.9395703673362732
# 406-)
# sentiment: True, probability: 0.9393067955970764
# 407-)
# sentiment: True, probability: 0.9389680027961731
# 408-)
# sentiment: True, probability: 0.936488926410675
# 409-)
# sentiment: Fake, probability: 0.051064491271972656
# 410-)
# sentiment: True, probability: 0.9377889037132263
# 411-)
# sentiment: Fake, probability: 0.04740918055176735
# 412-)
# sentiment: Fake, probability: 0.04636436328291893
# 413-)
# sentiment: True, probability: 0.939132034778595
# 414-)
# sentiment: True, probability: 0.9391465187072754
# 415-)
# sentiment: True, probability: 0.9388166069984436
# 416-)
# sentiment: Fake, probability: 0.051807038486003876
# 417-)
# sentiment: True, probability: 0.9393296241760254
# 418-)
# sentiment: Fake, probability: 0.04984470456838608
# 419-)
# sentiment: Fake, probability: 0.04775271564722061
# 420-)
# sentiment: True, probability: 0.9383752346038818
# 421-)
# sentiment: Fake, probability: 0.04872806742787361
# 422-)
# sentiment: True, probability: 0.938488781452179
# 423-)
# sentiment: True, probability: 0.9393512606620789
# 424-)
# sentiment: Fake, probability: 0.04836415499448776
# 425-)
# sentiment: True, probability: 0.939483642578125
# 426-)
# sentiment: True, probability: 0.9393228888511658
# 427-)
# sentiment: True, probability: 0.9391632676124573
# 428-)
# sentiment: True, probability: 0.9390594959259033
# 429-)
# sentiment: True, probability: 0.939254641532898
# 430-)
# sentiment: True, probability: 0.9394052624702454
# 431-)
# sentiment: True, probability: 0.9393527507781982
# 432-)
# sentiment: True, probability: 0.9383395314216614
# 433-)
# sentiment: True, probability: 0.9393973350524902
# 434-)
# sentiment: True, probability: 0.9389269351959229
# 435-)
# sentiment: Fake, probability: 0.04565079137682915
# 436-)
# sentiment: Fake, probability: 0.05379454791545868
# 437-)
# sentiment: Fake, probability: 0.050916872918605804
# 438-)
# sentiment: Fake, probability: 0.045021407306194305
# 439-)
# sentiment: True, probability: 0.9387301206588745
# 440-)
# sentiment: Fake, probability: 0.2629644274711609
# 441-)
# sentiment: Fake, probability: 0.04752160981297493
# 442-)
# sentiment: Fake, probability: 0.04844248667359352
# 443-)
# sentiment: Fake, probability: 0.05050130560994148
# 444-)
# sentiment: Fake, probability: 0.044969432055950165
# 445-)
# sentiment: Fake, probability: 0.04713708162307739
# 446-)
# sentiment: Fake, probability: 0.050472334027290344
# 447-)
# sentiment: True, probability: 0.9394009113311768
# 448-)
# sentiment: True, probability: 0.9385842680931091
# 449-)
# sentiment: Fake, probability: 0.04545808956027031
# 450-)
# sentiment: Fake, probability: 0.15371079742908478
# 451-)
# sentiment: True, probability: 0.9385048747062683
# 452-)
# sentiment: True, probability: 0.9390746355056763
# 453-)
# sentiment: Fake, probability: 0.04496791586279869
# 454-)
# sentiment: Fake, probability: 0.08108783513307571
# 455-)
# sentiment: Fake, probability: 0.04508529603481293
# 456-)
# sentiment: True, probability: 0.9390961527824402
# 457-)
# sentiment: True, probability: 0.9391652345657349
# 458-)
# sentiment: True, probability: 0.9394612312316895
# 459-)
# sentiment: Fake, probability: 0.04594918712973595
# 460-)
# sentiment: Fake, probability: 0.044957660138607025
# 461-)
# sentiment: Fake, probability: 0.04597543179988861
# 462-)
# sentiment: Fake, probability: 0.05002943426370621
# 463-)
# sentiment: Fake, probability: 0.05257361754775047
# 464-)
# sentiment: Fake, probability: 0.04831387847661972
# 465-)
# sentiment: Fake, probability: 0.052228908985853195
# 466-)
# sentiment: Fake, probability: 0.04994291067123413
# 467-)
# sentiment: Fake, probability: 0.05385282635688782
# 468-)
# sentiment: True, probability: 0.9393332004547119
# 469-)
# sentiment: Fake, probability: 0.04909905418753624
# 470-)
# sentiment: Fake, probability: 0.049286823719739914
# 471-)
# sentiment: True, probability: 0.9391448497772217
# 472-)
# sentiment: True, probability: 0.9393838047981262
# 473-)
# sentiment: Fake, probability: 0.05191205069422722
# 474-)
# sentiment: True, probability: 0.9394828677177429
# 475-)
# sentiment: True, probability: 0.9386267066001892
# 476-)
# sentiment: Fake, probability: 0.046719204634428024
# 477-)
# sentiment: Fake, probability: 0.04496642202138901
# 478-)
# sentiment: True, probability: 0.938835084438324
# 479-)
# sentiment: Fake, probability: 0.045635074377059937
# 480-)
# sentiment: True, probability: 0.9382436871528625
# 481-)
# sentiment: Fake, probability: 0.04495422914624214
# 482-)
# sentiment: True, probability: 0.939464271068573
# 483-)
# sentiment: True, probability: 0.9392741918563843
# 484-)
# sentiment: Fake, probability: 0.045486051589250565
# 485-)
# sentiment: Fake, probability: 0.05302334576845169
# 486-)
# sentiment: True, probability: 0.9382147192955017
# 487-)
# sentiment: Fake, probability: 0.050977982580661774
# 488-)
# sentiment: Fake, probability: 0.052659980952739716
# 489-)
# sentiment: Fake, probability: 0.05743883177638054
# 490-)
# sentiment: Fake, probability: 0.053430091589689255
# 491-)
# sentiment: True, probability: 0.939204752445221
# 492-)
# sentiment: Fake, probability: 0.0451248437166214
# 493-)
# sentiment: True, probability: 0.9387933015823364
# 494-)
# sentiment: True, probability: 0.939254105091095
# 495-)
# sentiment: True, probability: 0.9394040703773499
# 496-)
# sentiment: Fake, probability: 0.5291458368301392
# 497-)
# sentiment: Fake, probability: 0.04495323449373245
# 498-)
# sentiment: True, probability: 0.9392221570014954
# 499-)
# sentiment: True, probability: 0.9394004344940186
# 500-)
# sentiment: True, probability: 0.9394506216049194
# 501-)
# sentiment: Fake, probability: 0.04603054001927376
# 502-)
# sentiment: Fake, probability: 0.051427945494651794
# 503-)
# sentiment: Fake, probability: 0.05130413547158241
# 504-)
# sentiment: True, probability: 0.9394758343696594
# 505-)
# sentiment: Fake, probability: 0.052501924335956573
# 506-)
# sentiment: True, probability: 0.9394361972808838
# 507-)
# sentiment: True, probability: 0.9395203590393066
# 508-)
# sentiment: Fake, probability: 0.04839498549699783
# 509-)
# sentiment: Fake, probability: 0.049400899559259415
# 510-)
# sentiment: Fake, probability: 0.04989822208881378
# 511-)
# sentiment: True, probability: 0.9378796815872192
# 512-)
# sentiment: Fake, probability: 0.048024702817201614
# 513-)
# sentiment: Fake, probability: 0.04534269496798515
# 514-)
# sentiment: Fake, probability: 0.14628025889396667
# 515-)
# sentiment: True, probability: 0.939175546169281
# 516-)
# sentiment: True, probability: 0.9393455982208252
# 517-)
# sentiment: True, probability: 0.9394207000732422
# 518-)
# sentiment: True, probability: 0.9391266703605652
# 519-)
# sentiment: True, probability: 0.938893735408783
# 520-)
# sentiment: True, probability: 0.9395265579223633
# 521-)
# sentiment: True, probability: 0.9392186403274536
# 522-)
# sentiment: True, probability: 0.9375507831573486
# 523-)
# sentiment: True, probability: 0.9390690326690674
# 524-)
# sentiment: Fake, probability: 0.05436531826853752
# 525-)
# sentiment: Fake, probability: 0.05366937443614006
# 526-)
# sentiment: True, probability: 0.9392601251602173
# 527-)
# sentiment: Fake, probability: 0.04512321203947067
# 528-)
# sentiment: Fake, probability: 0.04728974401950836
# 529-)
# sentiment: True, probability: 0.9393142461776733
# 530-)
# sentiment: True, probability: 0.9393823146820068
# 531-)
# sentiment: True, probability: 0.939238965511322
# 532-)
# sentiment: True, probability: 0.9392101168632507
# 533-)
# sentiment: True, probability: 0.9393954873085022
# 534-)
# sentiment: Fake, probability: 0.045091964304447174
# 535-)
# sentiment: Fake, probability: 0.051804862916469574
# 536-)
# sentiment: True, probability: 0.9394389986991882
# 537-)
# sentiment: True, probability: 0.9393740296363831
# 538-)
# sentiment: Fake, probability: 0.04668344557285309
# 539-)
# sentiment: Fake, probability: 0.05510980263352394
# 540-)
# sentiment: True, probability: 0.9372978806495667
# 541-)
# sentiment: True, probability: 0.939262330532074
# 542-)
# sentiment: True, probability: 0.9395185708999634
# 543-)
# sentiment: True, probability: 0.9391682147979736
# 544-)
# sentiment: True, probability: 0.9394756555557251
# 545-)
# sentiment: Fake, probability: 0.04857514426112175
# 546-)
# sentiment: Fake, probability: 0.04610572010278702
# 547-)
# sentiment: True, probability: 0.9386317133903503
# 548-)
# sentiment: Fake, probability: 0.04599510505795479
# 549-)
# sentiment: Fake, probability: 0.04887603968381882
# 550-)
# sentiment: Fake, probability: 0.04507063701748848
# 551-)
# sentiment: Fake, probability: 0.05054063722491264
# 552-)
# sentiment: True, probability: 0.9391696453094482
# 553-)
# sentiment: True, probability: 0.7666093111038208
# 554-)
# sentiment: Fake, probability: 0.046320222318172455
# 555-)
# sentiment: Fake, probability: 0.047770511358976364
# 556-)
# sentiment: True, probability: 0.9393373131752014
# 557-)
# sentiment: Fake, probability: 0.04599056765437126
# 558-)
# sentiment: Fake, probability: 0.04985428601503372
# 559-)
# sentiment: True, probability: 0.9393329620361328
# 560-)
# sentiment: Fake, probability: 0.0449833981692791
# 561-)
# sentiment: True, probability: 0.9385073781013489
# 562-)
# sentiment: True, probability: 0.9393939971923828
# 563-)
# sentiment: True, probability: 0.9394327998161316
# 564-)
# sentiment: True, probability: 0.9389021396636963
# 565-)
# sentiment: Fake, probability: 0.04794800281524658
# 566-)
# sentiment: Fake, probability: 0.04854871705174446
# 567-)
# sentiment: True, probability: 0.9391276836395264
# 568-)
# sentiment: Fake, probability: 0.05249446630477905
# 569-)
# sentiment: Fake, probability: 0.052589867264032364
# 570-)
# sentiment: True, probability: 0.9395489692687988
# 571-)
# sentiment: Fake, probability: 0.21898838877677917
# 572-)
# sentiment: Fake, probability: 0.05283692479133606
# 573-)
# sentiment: True, probability: 0.9381139278411865
# 574-)
# sentiment: True, probability: 0.9393506646156311
# 575-)
# sentiment: True, probability: 0.9379821419715881
# 576-)
# sentiment: True, probability: 0.9393861889839172
# 577-)
# sentiment: Fake, probability: 0.05153355002403259
# 578-)
# sentiment: Fake, probability: 0.05149921774864197
# 579-)
# sentiment: True, probability: 0.9390998482704163
# 580-)
# sentiment: True, probability: 0.9384750723838806
# 581-)
# sentiment: True, probability: 0.9393191933631897
# 582-)
# sentiment: Fake, probability: 0.05390980467200279
# 583-)
# sentiment: True, probability: 0.9391202330589294
# 584-)
# sentiment: True, probability: 0.9394338726997375
# 585-)
# sentiment: True, probability: 0.9394466876983643
# 586-)
# sentiment: True, probability: 0.9394558668136597
# 587-)
# sentiment: True, probability: 0.9384454488754272
# 588-)
# sentiment: True, probability: 0.9381832480430603
# 589-)
# sentiment: True, probability: 0.9386052489280701
# 590-)
# sentiment: Fake, probability: 0.060629792511463165
# 591-)
# sentiment: True, probability: 0.9395209550857544
# 592-)
# sentiment: True, probability: 0.9382767677307129
# 593-)
# sentiment: Fake, probability: 0.04600817337632179
# 594-)
# sentiment: True, probability: 0.9393373727798462
# 595-)
# sentiment: Fake, probability: 0.0522824190557003
# 596-)
# sentiment: True, probability: 0.9395090937614441
# 597-)
# sentiment: True, probability: 0.9374970197677612
# 598-)
# sentiment: Fake, probability: 0.050715122371912
# 599-)
# sentiment: Fake, probability: 0.04695253074169159
# 600-)
# sentiment: Fake, probability: 0.04624910280108452
# 601-)
# sentiment: True, probability: 0.9394371509552002
# 602-)
# sentiment: True, probability: 0.9393877983093262
# 603-)
# sentiment: True, probability: 0.9394257664680481
# 604-)
# sentiment: Fake, probability: 0.04894993454217911
# 605-)
# sentiment: True, probability: 0.9377408027648926
# 606-)
# sentiment: True, probability: 0.939415454864502
# 607-)
# sentiment: Fake, probability: 0.04759571701288223
# 608-)
# sentiment: True, probability: 0.9394304752349854
# 609-)
# sentiment: True, probability: 0.9395478367805481
# 610-)
# sentiment: Fake, probability: 0.053794387727975845
# 611-)
# sentiment: Fake, probability: 0.05102944001555443
# 612-)
# sentiment: True, probability: 0.9388713240623474
# 613-)
# sentiment: Fake, probability: 0.045829810202121735
# 614-)
# sentiment: Fake, probability: 0.044962793588638306
# 615-)
# sentiment: True, probability: 0.7955745458602905
# 616-)
# sentiment: True, probability: 0.9394040703773499
# 617-)
# sentiment: True, probability: 0.9383159279823303
# 618-)
# sentiment: True, probability: 0.9393233060836792
# 619-)
# sentiment: True, probability: 0.9388178586959839
# 620-)
# sentiment: Fake, probability: 0.05279333144426346
# 621-)
# sentiment: Fake, probability: 0.04881877452135086
# 622-)
# sentiment: Fake, probability: 0.04928074777126312
# 623-)
# sentiment: Fake, probability: 0.048842236399650574
# 624-)
# sentiment: Fake, probability: 0.049676135182380676
# 625-)
# sentiment: Fake, probability: 0.05227123200893402
# 626-)
# sentiment: Fake, probability: 0.05367997661232948
# 627-)
# sentiment: Fake, probability: 0.13468556106090546
# 628-)
# sentiment: Fake, probability: 0.044958069920539856
# 629-)
# sentiment: True, probability: 0.939093828201294
# 630-)
# sentiment: True, probability: 0.9387383460998535
# 631-)
# sentiment: Fake, probability: 0.05380505695939064
# 632-)
# sentiment: Fake, probability: 0.045429546386003494
# 633-)
# sentiment: Fake, probability: 0.07850894331932068
# 634-)
# sentiment: True, probability: 0.9386674165725708
# 635-)
# sentiment: Fake, probability: 0.222554549574852
# 636-)
# sentiment: True, probability: 0.9392242431640625
# 637-)
# sentiment: True, probability: 0.939351499080658
# 638-)
# sentiment: Fake, probability: 0.04644814506173134
# 639-)
# sentiment: Fake, probability: 0.17224685847759247
# 640-)
# sentiment: True, probability: 0.939241886138916
# 641-)
# sentiment: Fake, probability: 0.04644814506173134
# 642-)
# sentiment: Fake, probability: 0.04605083912611008
# 643-)
# sentiment: Fake, probability: 0.05203313007950783
# 644-)
# sentiment: Fake, probability: 0.044981230050325394
# 645-)
# sentiment: True, probability: 0.9393374919891357
# 646-)
# sentiment: Fake, probability: 0.0491885170340538
# 647-)
# sentiment: Fake, probability: 0.055058203637599945
# 648-)
# sentiment: Fake, probability: 0.0479317270219326
# 649-)
# sentiment: True, probability: 0.9395300149917603
# 650-)
# sentiment: Fake, probability: 0.047311775386333466
# 651-)
# sentiment: True, probability: 0.9383678436279297
# 652-)
# sentiment: True, probability: 0.939483642578125
# 653-)
# sentiment: Fake, probability: 0.04892812296748161
# 654-)
# sentiment: True, probability: 0.9386698603630066
# 655-)
# sentiment: True, probability: 0.9391070008277893
# 656-)
# sentiment: Fake, probability: 0.05311862379312515
# 657-)
# sentiment: True, probability: 0.9389297962188721
# 658-)
# sentiment: Fake, probability: 0.04509388282895088
# 659-)
# sentiment: True, probability: 0.9392852187156677
# 660-)
# sentiment: Fake, probability: 0.04653669521212578
# 661-)
# sentiment: Fake, probability: 0.049140121787786484
# 662-)
# sentiment: True, probability: 0.9394077658653259
# 663-)
# sentiment: True, probability: 0.9386301636695862
# 664-)
# sentiment: Fake, probability: 0.05150793120265007
# 665-)
# sentiment: True, probability: 0.9393391013145447
# 666-)
# sentiment: Fake, probability: 0.050862036645412445
# 667-)
# sentiment: True, probability: 0.9394524693489075
# 668-)
# sentiment: Fake, probability: 0.05038975179195404
# 669-)
# sentiment: Fake, probability: 0.04682736098766327
# 670-)
# sentiment: True, probability: 0.9396145343780518
# 671-)
# sentiment: Fake, probability: 0.04697175696492195
# 672-)
# sentiment: Fake, probability: 0.05439715087413788
# 673-)
# sentiment: Fake, probability: 0.04595349729061127
# 674-)
# sentiment: Fake, probability: 0.04525946080684662
# 675-)
# sentiment: Fake, probability: 0.04994847998023033
# 676-)
# sentiment: True, probability: 0.9388821721076965
# 677-)
# sentiment: True, probability: 0.9389872550964355
# 678-)
# sentiment: True, probability: 0.9371734857559204
# 679-)
# sentiment: Fake, probability: 0.0477517731487751
# 680-)
# sentiment: Fake, probability: 0.06834577769041061
# 681-)
# sentiment: True, probability: 0.9390503168106079
# 682-)
# sentiment: Fake, probability: 0.045995887368917465
# 683-)
# sentiment: Fake, probability: 0.04613003134727478
# 684-)
# sentiment: Fake, probability: 0.061121586710214615
# 685-)
# sentiment: Fake, probability: 0.04622102901339531
# 686-)
# sentiment: True, probability: 0.788426399230957
# 687-)
# sentiment: Fake, probability: 0.07293067127466202
# 688-)
# sentiment: Fake, probability: 0.055509213358163834
# 689-)
# sentiment: Fake, probability: 0.04535224661231041
# 690-)
# sentiment: True, probability: 0.9393779039382935
# 691-)
# sentiment: True, probability: 0.9390152096748352
# 692-)
# sentiment: Fake, probability: 0.048899244517087936
# 693-)
# sentiment: True, probability: 0.9386743903160095
# 694-)
# sentiment: True, probability: 0.9390807151794434
# 695-)
# sentiment: Fake, probability: 0.049314726144075394
# 696-)
# sentiment: True, probability: 0.9390483498573303
# 697-)
# sentiment: True, probability: 0.9393605589866638
# 698-)
# sentiment: True, probability: 0.9385514855384827
# 699-)
# sentiment: True, probability: 0.9380599856376648
# 700-)
# sentiment: True, probability: 0.9393166899681091
# 701-)
# sentiment: True, probability: 0.9389872550964355
# 702-)
# sentiment: True, probability: 0.9390026926994324
# 703-)
# sentiment: Fake, probability: 0.05143393576145172
# 704-)
# sentiment: Fake, probability: 0.05249496549367905
# 705-)
# sentiment: True, probability: 0.9376754760742188
# 706-)
# sentiment: True, probability: 0.9394283890724182
# 707-)
# sentiment: Fake, probability: 0.05213969945907593
# 708-)
# sentiment: Fake, probability: 0.05154382809996605
# 709-)
# sentiment: True, probability: 0.9394589066505432
# 710-)
# sentiment: Fake, probability: 0.044954463839530945
# 711-)
# sentiment: Fake, probability: 0.06044858694076538
# 712-)
# sentiment: True, probability: 0.9383348226547241
# 713-)
# sentiment: Fake, probability: 0.0536390095949173
# 714-)
# sentiment: Fake, probability: 0.04940053075551987
# 715-)
# sentiment: Fake, probability: 0.045501478016376495
# 716-)
# sentiment: Fake, probability: 0.12687969207763672
# 717-)
# sentiment: True, probability: 0.9392250776290894
# 718-)
# sentiment: Fake, probability: 0.04852196201682091
# 719-)
# sentiment: True, probability: 0.9386945366859436
# 720-)
# sentiment: True, probability: 0.8143638968467712
# 721-)
# sentiment: True, probability: 0.939399242401123
# 722-)
# sentiment: True, probability: 0.9387322664260864
# 723-)
# sentiment: True, probability: 0.9393494725227356
# 724-)
# sentiment: True, probability: 0.93922358751297
# 725-)
# sentiment: True, probability: 0.9391525983810425
# 726-)
# sentiment: Fake, probability: 0.05189908668398857
# 727-)
# sentiment: Fake, probability: 0.05446764454245567
# 728-)
# sentiment: Fake, probability: 0.045021865516901016
# 729-)
# sentiment: Fake, probability: 0.044953275471925735
# 730-)
# sentiment: True, probability: 0.939376950263977
# 731-)
# sentiment: True, probability: 0.8215129375457764
# 732-)
# sentiment: Fake, probability: 0.046199820935726166
# 733-)
# sentiment: Fake, probability: 0.047644179314374924
# 734-)
# sentiment: True, probability: 0.939261794090271
# 735-)
# sentiment: Fake, probability: 0.052719686180353165
# 736-)
# sentiment: Fake, probability: 0.0449557863175869
# 737-)
# sentiment: True, probability: 0.9391074180603027
# 738-)
# sentiment: Fake, probability: 0.12358461320400238
# 739-)
# sentiment: Fake, probability: 0.05150469392538071
# 740-)
# sentiment: True, probability: 0.9394173622131348
# 741-)
# sentiment: Fake, probability: 0.053973011672496796
# 742-)
# sentiment: True, probability: 0.9394769072532654
# 743-)
# sentiment: True, probability: 0.9392316937446594
# 744-)
# sentiment: Fake, probability: 0.04709957167506218
# 745-)
# sentiment: Fake, probability: 0.13252997398376465
# 746-)
# sentiment: True, probability: 0.7208575010299683
# 747-)
# sentiment: True, probability: 0.9391676783561707
# 748-)
# sentiment: True, probability: 0.9381105303764343
# 749-)
# sentiment: Fake, probability: 0.047681473195552826
# 750-)
# sentiment: Fake, probability: 0.054796863347291946
# 751-)
# sentiment: Fake, probability: 0.04678693041205406
# 752-)
# sentiment: True, probability: 0.9393289089202881
# 753-)
# sentiment: Fake, probability: 0.0476003959774971
# 754-)
# sentiment: True, probability: 0.9385504126548767
# 755-)
# sentiment: True, probability: 0.9394121766090393
# 756-)
# sentiment: True, probability: 0.9393630623817444
# 757-)
# sentiment: True, probability: 0.9395009875297546
# 758-)
# sentiment: Fake, probability: 0.12183663249015808
# 759-)
# sentiment: Fake, probability: 0.045526083558797836
# 760-)
# sentiment: True, probability: 0.9391863942146301
# 761-)
# sentiment: Fake, probability: 0.04797922447323799
# 762-)
# sentiment: Fake, probability: 0.05513230711221695
# 763-)
# sentiment: True, probability: 0.939301609992981
# 764-)
# sentiment: Fake, probability: 0.048243798315525055
# 765-)
# sentiment: Fake, probability: 0.04496854171156883
# 766-)
# sentiment: Fake, probability: 0.052141305059194565
# 767-)
# sentiment: True, probability: 0.9394645690917969
# 768-)
# sentiment: True, probability: 0.9379172325134277
# 769-)
# sentiment: Fake, probability: 0.04760710150003433
# 770-)
# sentiment: Fake, probability: 0.05069207772612572
# 771-)
# sentiment: Fake, probability: 0.0487016923725605
# 772-)
# sentiment: Fake, probability: 0.3660731911659241
# 773-)
# sentiment: Fake, probability: 0.05526883155107498
# 774-)
# sentiment: Fake, probability: 0.059453655034303665
# 775-)
# sentiment: Fake, probability: 0.0489339753985405
# 776-)
# sentiment: True, probability: 0.9395266771316528
# 777-)
# sentiment: Fake, probability: 0.05159455165266991
# 778-)
# sentiment: Fake, probability: 0.04657464474439621
# 779-)
# sentiment: True, probability: 0.9392019510269165
# 780-)
# sentiment: True, probability: 0.9390337467193604
# 781-)
# sentiment: True, probability: 0.9390704035758972
# 782-)
# sentiment: True, probability: 0.9389981031417847
# 783-)
# sentiment: True, probability: 0.9393132925033569
# 784-)
# sentiment: True, probability: 0.939365804195404
# 785-)
# sentiment: Fake, probability: 0.0470406599342823
# 786-)
# sentiment: True, probability: 0.9392587542533875
# 787-)
# sentiment: Fake, probability: 0.05062292888760567
# 788-)
# sentiment: True, probability: 0.9393831491470337
# 789-)
# sentiment: True, probability: 0.9385051727294922
# 790-)
# sentiment: Fake, probability: 0.054479166865348816
# 791-)
# sentiment: Fake, probability: 0.045023363083601
# 792-)
# sentiment: True, probability: 0.93841153383255
# 793-)
# sentiment: True, probability: 0.9383059144020081
# 794-)
# sentiment: True, probability: 0.9390214085578918
# 795-)
# sentiment: True, probability: 0.9391810297966003
# 796-)
# sentiment: Fake, probability: 0.04732293635606766
# 797-)
# sentiment: True, probability: 0.939426064491272
# 798-)
# sentiment: Fake, probability: 0.06015179678797722
# 799-)
# sentiment: Fake, probability: 0.05012933164834976
# 800-)
# sentiment: True, probability: 0.9393154978752136
# 801-)
# sentiment: Fake, probability: 0.04543159529566765
# 802-)
# sentiment: Fake, probability: 0.04759349301457405
# 803-)
# sentiment: True, probability: 0.9390546679496765
# 804-)
# sentiment: True, probability: 0.9392725229263306
# 805-)
# sentiment: Fake, probability: 0.06028309836983681
# 806-)
# sentiment: True, probability: 0.9392905831336975
# 807-)
# sentiment: True, probability: 0.9386824369430542
# 808-)
# sentiment: Fake, probability: 0.04921048879623413
# 809-)
# sentiment: Fake, probability: 0.055210765451192856
# 810-)
# sentiment: Fake, probability: 0.04590987786650658
# 811-)
# sentiment: True, probability: 0.9393905997276306
# 812-)
# sentiment: Fake, probability: 0.05304669216275215
# 813-)
# sentiment: True, probability: 0.9393005967140198
# 814-)
# sentiment: Fake, probability: 0.0465865358710289
# 815-)
# sentiment: True, probability: 0.9391220211982727
# 816-)
# sentiment: True, probability: 0.9388642907142639
# 817-)
# sentiment: True, probability: 0.9391201138496399
# 818-)
# sentiment: Fake, probability: 0.05014556646347046
# 819-)
# sentiment: True, probability: 0.9393869638442993
# 820-)
# sentiment: True, probability: 0.9390549659729004
# 821-)
# sentiment: True, probability: 0.9389113783836365
# 822-)
# sentiment: True, probability: 0.9391716718673706
# 823-)
# sentiment: Fake, probability: 0.10928759723901749
# 824-)
# sentiment: True, probability: 0.9391149878501892
# 825-)
# sentiment: True, probability: 0.939028263092041
# 826-)
# sentiment: True, probability: 0.9384165406227112
# 827-)
# sentiment: True, probability: 0.9384574294090271
# 828-)
# sentiment: True, probability: 0.939324676990509
# 829-)
# sentiment: True, probability: 0.9390602111816406
# 830-)
# sentiment: Fake, probability: 0.04598750174045563
# 831-)
# sentiment: True, probability: 0.9392915368080139
# 832-)
# sentiment: True, probability: 0.9382048845291138
# 833-)
# sentiment: Fake, probability: 0.045143596827983856
# 834-)
# sentiment: True, probability: 0.9388223886489868
# 835-)
# sentiment: True, probability: 0.9376319646835327
# 836-)
# sentiment: Fake, probability: 0.045077286660671234
# 837-)
# sentiment: Fake, probability: 0.04937544837594032
# 838-)
# sentiment: True, probability: 0.9394416213035583
# 839-)
# sentiment: True, probability: 0.9391620755195618
# 840-)
# sentiment: True, probability: 0.9393146634101868
# 841-)
# sentiment: Fake, probability: 0.04516725242137909
# 842-)
# sentiment: True, probability: 0.9390037655830383
# 843-)
# sentiment: True, probability: 0.939002275466919
# 844-)
# sentiment: Fake, probability: 0.054738759994506836
# 845-)
# sentiment: Fake, probability: 0.05502120032906532
# 846-)
# sentiment: Fake, probability: 0.04881642386317253
# 847-)
# sentiment: Fake, probability: 0.1363847702741623
# 848-)
# sentiment: Fake, probability: 0.05222320929169655
# 849-)
# sentiment: True, probability: 0.9391986727714539
# 850-)
# sentiment: True, probability: 0.743288516998291
# 851-)
# sentiment: Fake, probability: 0.08908096700906754
# 852-)
# sentiment: Fake, probability: 0.04827692732214928
# 853-)
# sentiment: True, probability: 0.9394305944442749
# 854-)
# sentiment: Fake, probability: 0.05009950324892998
# 855-)
# sentiment: True, probability: 0.9392967224121094
# 856-)
# sentiment: True, probability: 0.939238965511322
# 857-)
# sentiment: True, probability: 0.939242422580719
# 858-)
# sentiment: True, probability: 0.9392914175987244
# 859-)
# sentiment: Fake, probability: 0.04495656117796898
# 860-)
# sentiment: True, probability: 0.9394480586051941
# 861-)
# sentiment: Fake, probability: 0.07787096500396729
# 862-)
# sentiment: Fake, probability: 0.04850374907255173
# 863-)
# sentiment: Fake, probability: 0.049312569200992584
# 864-)
# sentiment: Fake, probability: 0.05133187770843506
# 865-)
# sentiment: Fake, probability: 0.04724936932325363
# 866-)
# sentiment: Fake, probability: 0.04767506569623947
# 867-)
# sentiment: Fake, probability: 0.0477728433907032
# 868-)
# sentiment: True, probability: 0.9395102262496948
# 869-)
# sentiment: Fake, probability: 0.0499422550201416
# 870-)
# sentiment: True, probability: 0.9392755627632141
# 871-)
# sentiment: True, probability: 0.9394609928131104
# 872-)
# sentiment: True, probability: 0.9395105838775635
# 873-)
# sentiment: True, probability: 0.9392436146736145
# 874-)
# sentiment: Fake, probability: 0.05037771537899971
# 875-)
# sentiment: Fake, probability: 0.05074754357337952
# 876-)
# sentiment: True, probability: 0.9393825531005859
# 877-)
# sentiment: Fake, probability: 0.0450754351913929
# 878-)
# sentiment: True, probability: 0.9388859272003174
# 879-)
# sentiment: True, probability: 0.939298152923584
# 880-)
# sentiment: True, probability: 0.939329206943512
# 881-)
# sentiment: Fake, probability: 0.1261938214302063
# 882-)
# sentiment: True, probability: 0.9393247961997986
# 883-)
# sentiment: True, probability: 0.9390614628791809
# 884-)
# sentiment: Fake, probability: 0.04929546266794205
# 885-)
# sentiment: True, probability: 0.9393268823623657
# 886-)
# sentiment: True, probability: 0.9385270476341248
# 887-)
# sentiment: True, probability: 0.939254105091095
# 888-)
# sentiment: True, probability: 0.9381113052368164
# 889-)
# sentiment: Fake, probability: 0.04495532438158989
# 890-)
# sentiment: Fake, probability: 0.04711218923330307
# 891-)
# sentiment: Fake, probability: 0.05360237509012222
# 892-)
# sentiment: True, probability: 0.9394253492355347
# 893-)
# sentiment: True, probability: 0.9394828081130981
# 894-)
# sentiment: True, probability: 0.9392198324203491
# 895-)
# sentiment: Fake, probability: 0.04571104049682617
# 896-)
# sentiment: Fake, probability: 0.045081790536642075
# 897-)
# sentiment: Fake, probability: 0.045904435217380524
# 898-)
# sentiment: True, probability: 0.938944399356842
# 899-)
# sentiment: True, probability: 0.9396165609359741
# 900-)
# sentiment: Fake, probability: 0.5200716257095337
# 901-)
# sentiment: Fake, probability: 0.04662720486521721
# 902-)
# sentiment: True, probability: 0.9374303817749023
# 903-)
# sentiment: True, probability: 0.9393779039382935
# 904-)
# sentiment: True, probability: 0.9392994046211243
# 905-)
# sentiment: True, probability: 0.9389087557792664
# 906-)
# sentiment: Fake, probability: 0.26042410731315613
# 907-)
# sentiment: True, probability: 0.9391220211982727
# 908-)
# sentiment: True, probability: 0.939384400844574
# 909-)
# sentiment: True, probability: 0.9392198324203491
# 910-)
# sentiment: Fake, probability: 0.05012877658009529
# 911-)
# sentiment: Fake, probability: 0.04915584623813629
# 912-)
# sentiment: True, probability: 0.9382131695747375
# 913-)
# sentiment: True, probability: 0.9373322129249573
# 914-)
# sentiment: True, probability: 0.9394264817237854
# 915-)
# sentiment: True, probability: 0.9394678473472595
# 916-)
# sentiment: Fake, probability: 0.07277587801218033
# 917-)
# sentiment: Fake, probability: 0.05168990418314934
# 918-)
# sentiment: Fake, probability: 0.04849064722657204
# 919-)
# sentiment: Fake, probability: 0.049182116985321045
# 920-)
# sentiment: Fake, probability: 0.051414474844932556
# 921-)
# sentiment: True, probability: 0.9394439458847046
# 922-)
# sentiment: True, probability: 0.9389507174491882
# 923-)
# sentiment: Fake, probability: 0.04753393679857254
# 924-)
# sentiment: Fake, probability: 0.05305647850036621
# 925-)
# sentiment: Fake, probability: 0.04775381088256836
# 926-)
# sentiment: Fake, probability: 0.04897244647145271
# 927-)
# sentiment: Fake, probability: 0.0451139472424984
# 928-)
# sentiment: True, probability: 0.9393103718757629
# 929-)
# sentiment: True, probability: 0.9385743737220764
# 930-)
# sentiment: Fake, probability: 0.045815758407115936
# 931-)
# sentiment: True, probability: 0.9391511678695679
# 932-)
# sentiment: Fake, probability: 0.04495346173644066
# 933-)
# sentiment: True, probability: 0.9390665292739868
# 934-)
# sentiment: True, probability: 0.9383336305618286
# 935-)
# sentiment: Fake, probability: 0.047996241599321365
# 936-)
# sentiment: True, probability: 0.939102292060852
# 937-)
# sentiment: Fake, probability: 0.05021682009100914
# 938-)
# sentiment: Fake, probability: 0.05348813161253929
# 939-)
# sentiment: True, probability: 0.9394361972808838
# 940-)
# sentiment: True, probability: 0.9394221901893616
# 941-)
# sentiment: True, probability: 0.9392204284667969
# 942-)
# sentiment: Fake, probability: 0.0514354482293129
# 943-)
# sentiment: Fake, probability: 0.05318509787321091
# 944-)
# sentiment: Fake, probability: 0.0502268485724926
# 945-)
# sentiment: True, probability: 0.9388868808746338
# 946-)
# sentiment: Fake, probability: 0.04666425287723541
# 947-)
# sentiment: True, probability: 0.9393302202224731
# 948-)
# sentiment: Fake, probability: 0.050634030252695084
# 949-)
# sentiment: Fake, probability: 0.05191139504313469
# 950-)
# sentiment: Fake, probability: 0.05223534256219864
# 951-)
# sentiment: True, probability: 0.9393734931945801
# 952-)
# sentiment: Fake, probability: 0.08505824953317642
# 953-)
# sentiment: True, probability: 0.9389538168907166
# 954-)
# sentiment: Fake, probability: 0.045881904661655426
# 955-)
# sentiment: Fake, probability: 0.04573950171470642
# 956-)
# sentiment: Fake, probability: 0.04513786360621452
# 957-)
# sentiment: Fake, probability: 0.05125871300697327
# 958-)
# sentiment: Fake, probability: 0.05079971253871918
# 959-)
# sentiment: Fake, probability: 0.04892481863498688
# 960-)
# sentiment: True, probability: 0.9392425417900085
# 961-)
# sentiment: True, probability: 0.9394289255142212
# 962-)
# sentiment: Fake, probability: 0.04526729881763458
# 963-)
# sentiment: Fake, probability: 0.045166149735450745
# 964-)
# sentiment: True, probability: 0.9388710260391235
# 965-)
# sentiment: Fake, probability: 0.05230797827243805
# 966-)
# sentiment: Fake, probability: 0.045443806797266006
# 967-)
# sentiment: True, probability: 0.9372227787971497
# 968-)
# sentiment: Fake, probability: 0.044984497129917145
# 969-)
# sentiment: True, probability: 0.9394121766090393
# 970-)
# sentiment: Fake, probability: 0.05722478777170181
# 971-)
# sentiment: True, probability: 0.9394616484642029
# 972-)
# sentiment: True, probability: 0.9394535422325134
# 973-)
# sentiment: True, probability: 0.9370846152305603
# 974-)
# sentiment: Fake, probability: 0.04974280670285225
# 975-)
# sentiment: True, probability: 0.9391440153121948
# 976-)
# sentiment: True, probability: 0.9387831091880798
# 977-)
# sentiment: True, probability: 0.9392271637916565
# 978-)
# sentiment: Fake, probability: 0.0558997318148613
# 979-)
# sentiment: Fake, probability: 0.0535987988114357
# 980-)
# sentiment: True, probability: 0.9394110441207886
# 981-)
# sentiment: True, probability: 0.9387590289115906
# 982-)
# sentiment: True, probability: 0.9395489692687988
# 983-)
# sentiment: Fake, probability: 0.04665076360106468
# 984-)
# sentiment: Fake, probability: 0.05364111438393593
# 985-)
# sentiment: Fake, probability: 0.12979847192764282
# 986-)
# sentiment: Fake, probability: 0.04809989035129547
# 987-)
# sentiment: True, probability: 0.7660748958587646
# 988-)
# sentiment: True, probability: 0.9395378232002258
# 989-)
# sentiment: Fake, probability: 0.049949586391448975
# 990-)
# sentiment: True, probability: 0.9394820332527161
# 991-)
# sentiment: True, probability: 0.939074695110321
# 992-)
# sentiment: True, probability: 0.9391890168190002
# 993-)
# sentiment: Fake, probability: 0.045500244945287704
# 994-)
# sentiment: Fake, probability: 0.04501887410879135
# 995-)
# sentiment: True, probability: 0.9385830163955688
# 996-)
# sentiment: True, probability: 0.9374222159385681
# 997-)
# sentiment: Fake, probability: 0.05219310149550438
# 998-)
# sentiment: Fake, probability: 0.045729972422122955
# 999-)
# sentiment: True, probability: 0.9395135045051575
# 966

# %%
from sklearn.metrics import confusion_matrix

# %%
y_true=submission["Truth"].tolist()

# %%
conf_matrix=confusion_matrix(y_true, y_pred)
conf_matrix
# Out:
# array([[466,  26],
#        [  8, 500]])

# %%
TP = conf_matrix[1][1]
TN = conf_matrix[0][0]
FP = conf_matrix[0][1]
FN = conf_matrix[1][0]
print('True Positives:', TP)
print('True Negatives:', TN)
print('False Positives:', FP)
print('False Negatives:', FN)
# Out:
# True Positives: 500
# True Negatives: 466
# False Positives: 26
# False Negatives: 8

# %%
conf_accuracy = (float (TP+TN) / float(TP + TN + FP + FN))

conf_error_rate = 1- conf_accuracy
    
conf_sensitivity = (TP / float(TP + FN)) #recall

conf_specificity = (TN / float(TN + FP))
    
conf_precision = (TN / float(TN + FP))

conf_f1 = 2 * ((conf_precision * conf_sensitivity) / (conf_precision + conf_sensitivity))
print('-'*50)
print(f'Accuracy: {round(conf_accuracy,2)}') 
print(f'Error_rate: {round(conf_error_rate,2)}') 
print(f'Sensitivity: {round(conf_sensitivity,2)}') 
print(f'Specificity: {round(conf_specificity,2)}') 
print(f'Precision: {round(conf_precision,2)}')
print(f'f_1 Score: {round(conf_f1,2)}')
# Out:
# --------------------------------------------------
# Accuracy: 0.97
# Error_rate: 0.03
# Sensitivity: 0.98
# Specificity: 0.95
# Precision: 0.95
# f_1 Score: 0.97
