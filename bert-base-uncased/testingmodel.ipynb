# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.25.1-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 12.4 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.21.6)
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 59.1 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 58.3 MB/s
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (21.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.8.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (3.0.4)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.11.1 tokenizers-0.13.2 transformers-4.25.1

# %%
model_name="bert-base-uncased"

# %%
from transformers import AutoModelForSequenceClassification
new_model = AutoModelForSequenceClassification.from_pretrained("/content/drive/MyDrive/Colab Notebooks/bert-base-uncased/model")

# %%
from transformers import AutoTokenizer
new_tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
import nltk
from nltk.stem.porter import PorterStemmer
import re
from nltk.corpus import stopwords
nltk.download("stopwords")
def preprocessing(text):
    ps = PorterStemmer()
    sentence = re.sub('[^a-zA-Z]',' ',text) # noktalama işaretlerini silme.
    sentence = sentence.lower() # kelimelerin hepsini küçük harf 
    sentence = sentence.split() # keliemeleri listeye atma
    sentence = [ps.stem(kelime) for kelime in sentence if not kelime in set(stopwords.words("english"))] #anlamı olmayan(stopwords) kelimeleri listeden atma
    sentence = " ".join(sentence) # listede kalan kelimeleri birleştirip yeni cümleyi oluşturma.
    return sentence
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
sentence = preprocessing("Do you want to go school?")
print(sentence)
# Out:
# want go school

# %%
import torch
import numpy as np

def get_prediction(text):
    text = preprocessing(text)
    encoding = new_tokenizer(text, return_tensors="pt", padding="max_length", truncation=True, max_length=128)
    # encoding = {k: v.to(trainer.model.device) for k,v in encoding.items()}
    outputs = new_model(**encoding)

    logits = outputs.logits

    sigmoid = torch.nn.Sigmoid()
    probs = sigmoid(logits.squeeze().cpu())
    probs = probs.detach().numpy()
    label = np.argmax(probs, axis=-1) # değeri 0 veya 1'e yuvarlıyoruz.
    
    if label == 1:
        print(f"sentiment: True, probability: {probs[1]}")
        return 1
    else:
        print(f"sentiment: Fake, probability: {probs[1]}")
        return 0

# %%
get_prediction("He goes to airport.")
# Out:
# sentiment: True, probability: 0.9462123513221741
# 1

# %%
submission = pd.read_csv("/content/drive/MyDrive/submission.csv")
# y = submission["Truth"]
# x = submission["Haber"]

# %%
accuracy = 0
y_pred = []
for i in range(submission.shape[0]):
    row = submission.iloc[i]
    text = row[0]
    truth_value = row[1]
    print(f"{i}-)")
    result = get_prediction(text)
    y_pred.append(result)
    if(result == int(truth_value)):
        accuracy += 1 
accuracy
# Out:
# 0-)
# sentiment: True, probability: 0.9462123513221741
# 1-)
# sentiment: Fake, probability: 0.04909549281001091
# 2-)
# sentiment: Fake, probability: 0.04909117519855499
# 3-)
# sentiment: True, probability: 0.9462127089500427
# 4-)
# sentiment: Fake, probability: 0.0490933358669281
# 5-)
# sentiment: True, probability: 0.9462121725082397
# 6-)
# sentiment: True, probability: 0.9462121725082397
# 7-)
# sentiment: Fake, probability: 0.04910113662481308
# 8-)
# sentiment: True, probability: 0.9462123513221741
# 9-)
# sentiment: True, probability: 0.9462122917175293
# 10-)
# sentiment: True, probability: 0.9462123513221741
# 11-)
# sentiment: True, probability: 0.9462122917175293
# 12-)
# sentiment: True, probability: 0.9462123513221741
# 13-)
# sentiment: True, probability: 0.9462130069732666
# 14-)
# sentiment: True, probability: 0.9462121725082397
# 15-)
# sentiment: True, probability: 0.9462121725082397
# 16-)
# sentiment: Fake, probability: 0.04910892993211746
# 17-)
# sentiment: True, probability: 0.9462123513221741
# 18-)
# sentiment: Fake, probability: 0.04909881204366684
# 19-)
# sentiment: True, probability: 0.9462124705314636
# 20-)
# sentiment: Fake, probability: 0.0491015687584877
# 21-)
# sentiment: True, probability: 0.9462122917175293
# 22-)
# sentiment: Fake, probability: 0.04911723732948303
# 23-)
# sentiment: Fake, probability: 0.049094777554273605
# 24-)
# sentiment: True, probability: 0.9462123513221741
# 25-)
# sentiment: Fake, probability: 0.0492577850818634
# 26-)
# sentiment: Fake, probability: 0.04913095384836197
# 27-)
# sentiment: True, probability: 0.9462122917175293
# 28-)
# sentiment: True, probability: 0.9462121725082397
# 29-)
# sentiment: True, probability: 0.9462122917175293
# 30-)
# sentiment: Fake, probability: 0.04926032945513725
# 31-)
# sentiment: Fake, probability: 0.049093108624219894
# 32-)
# sentiment: True, probability: 0.9462123513221741
# 33-)
# sentiment: Fake, probability: 0.04909300059080124
# 34-)
# sentiment: True, probability: 0.9462122917175293
# 35-)
# sentiment: True, probability: 0.9462125897407532
# 36-)
# sentiment: Fake, probability: 0.04909992218017578
# 37-)
# sentiment: True, probability: 0.9462124705314636
# 38-)
# sentiment: True, probability: 0.9462125897407532
# 39-)
# sentiment: True, probability: 0.9462123513221741
# 40-)
# sentiment: Fake, probability: 0.04932379350066185
# 41-)
# sentiment: Fake, probability: 0.049089618027210236
# 42-)
# sentiment: Fake, probability: 0.04909277707338333
# 43-)
# sentiment: True, probability: 0.9462124705314636
# 44-)
# sentiment: Fake, probability: 0.049138039350509644
# 45-)
# sentiment: Fake, probability: 0.04910394176840782
# 46-)
# sentiment: True, probability: 0.9462124705314636
# 47-)
# sentiment: True, probability: 0.9462122917175293
# 48-)
# sentiment: True, probability: 0.9462121725082397
# 49-)
# sentiment: True, probability: 0.9462121725082397
# 50-)
# sentiment: True, probability: 0.9462124705314636
# 51-)
# sentiment: True, probability: 0.9462125897407532
# 52-)
# sentiment: True, probability: 0.9462123513221741
# 53-)
# sentiment: True, probability: 0.9462122917175293
# 54-)
# sentiment: True, probability: 0.9462123513221741
# 55-)
# sentiment: Fake, probability: 0.04909064248204231
# 56-)
# sentiment: Fake, probability: 0.049102894961833954
# 57-)
# sentiment: True, probability: 0.9462123513221741
# 58-)
# sentiment: True, probability: 0.9462122917175293
# 59-)
# sentiment: Fake, probability: 0.04910193756222725
# 60-)
# sentiment: Fake, probability: 0.0491083487868309
# 61-)
# sentiment: Fake, probability: 0.04909205064177513
# 62-)
# sentiment: Fake, probability: 0.04909498989582062
# 63-)
# sentiment: Fake, probability: 0.049097951501607895
# 64-)
# sentiment: True, probability: 0.9462151527404785
# 65-)
# sentiment: True, probability: 0.9462123513221741
# 66-)
# sentiment: True, probability: 0.9462121725082397
# 67-)
# sentiment: Fake, probability: 0.049090996384620667
# 68-)
# sentiment: True, probability: 0.9462124705314636
# 69-)
# sentiment: Fake, probability: 0.04909473657608032
# 70-)
# sentiment: True, probability: 0.9462122917175293
# 71-)
# sentiment: True, probability: 0.9462127089500427
# 72-)
# sentiment: True, probability: 0.9462122917175293
# 73-)
# sentiment: Fake, probability: 0.04909152910113335
# 74-)
# sentiment: Fake, probability: 0.04909614846110344
# 75-)
# sentiment: True, probability: 0.9462123513221741
# 76-)
# sentiment: Fake, probability: 0.04909936711192131
# 77-)
# sentiment: Fake, probability: 0.049103349447250366
# 78-)
# sentiment: Fake, probability: 0.04908837005496025
# 79-)
# sentiment: Fake, probability: 0.04909504950046539
# 80-)
# sentiment: True, probability: 0.9462132453918457
# 81-)
# sentiment: Fake, probability: 0.04909558221697807
# 82-)
# sentiment: Fake, probability: 0.04909304529428482
# 83-)
# sentiment: Fake, probability: 0.0490913949906826
# 84-)
# sentiment: Fake, probability: 0.04909224063158035
# 85-)
# sentiment: True, probability: 0.9462121725082397
# 86-)
# sentiment: Fake, probability: 0.04909926652908325
# 87-)
# sentiment: Fake, probability: 0.04909456521272659
# 88-)
# sentiment: Fake, probability: 0.04909108579158783
# 89-)
# sentiment: Fake, probability: 0.049092020839452744
# 90-)
# sentiment: True, probability: 0.9462123513221741
# 91-)
# sentiment: Fake, probability: 0.04919332265853882
# 92-)
# sentiment: Fake, probability: 0.0491010807454586
# 93-)
# sentiment: True, probability: 0.9462121725082397
# 94-)
# sentiment: True, probability: 0.9462121725082397
# 95-)
# sentiment: Fake, probability: 0.04910052567720413
# 96-)
# sentiment: Fake, probability: 0.04910091310739517
# 97-)
# sentiment: True, probability: 0.9462124705314636
# 98-)
# sentiment: Fake, probability: 0.049133606255054474
# 99-)
# sentiment: Fake, probability: 0.049095269292593
# 100-)
# sentiment: True, probability: 0.9462123513221741
# 101-)
# sentiment: True, probability: 0.9462122917175293
# 102-)
# sentiment: True, probability: 0.9462124705314636
# 103-)
# sentiment: True, probability: 0.9462122917175293
# 104-)
# sentiment: Fake, probability: 0.0490916445851326
# 105-)
# sentiment: True, probability: 0.9462122917175293
# 106-)
# sentiment: True, probability: 0.9462122917175293
# 107-)
# sentiment: Fake, probability: 0.049090173095464706
# 108-)
# sentiment: Fake, probability: 0.049099452793598175
# 109-)
# sentiment: True, probability: 0.9462122917175293
# 110-)
# sentiment: True, probability: 0.9462121725082397
# 111-)
# sentiment: Fake, probability: 0.04909354820847511
# 112-)
# sentiment: True, probability: 0.9462122917175293
# 113-)
# sentiment: True, probability: 0.9462131261825562
# 114-)
# sentiment: True, probability: 0.9462189078330994
# 115-)
# sentiment: Fake, probability: 0.0491006039083004
# 116-)
# sentiment: True, probability: 0.9462123513221741
# 117-)
# sentiment: Fake, probability: 0.04911929368972778
# 118-)
# sentiment: Fake, probability: 0.04914579167962074
# 119-)
# sentiment: True, probability: 0.9462123513221741
# 120-)
# sentiment: True, probability: 0.9462122917175293
# 121-)
# sentiment: Fake, probability: 0.04910203814506531
# 122-)
# sentiment: Fake, probability: 0.04908948391675949
# 123-)
# sentiment: True, probability: 0.9462123513221741
# 124-)
# sentiment: Fake, probability: 0.04914623871445656
# 125-)
# sentiment: True, probability: 0.9462123513221741
# 126-)
# sentiment: True, probability: 0.9462123513221741
# 127-)
# sentiment: True, probability: 0.9462121725082397
# 128-)
# sentiment: True, probability: 0.9462121725082397
# 129-)
# sentiment: True, probability: 0.9462121725082397
# 130-)
# sentiment: Fake, probability: 0.04909081757068634
# 131-)
# sentiment: True, probability: 0.9462121725082397
# 132-)
# sentiment: True, probability: 0.9462125897407532
# 133-)
# sentiment: True, probability: 0.9462162256240845
# 134-)
# sentiment: Fake, probability: 0.049092795699834824
# 135-)
# sentiment: True, probability: 0.9462125897407532
# 136-)
# sentiment: Fake, probability: 0.049095068126916885
# 137-)
# sentiment: Fake, probability: 0.04909848794341087
# 138-)
# sentiment: Fake, probability: 0.04912905395030975
# 139-)
# sentiment: Fake, probability: 0.04910117760300636
# 140-)
# sentiment: Fake, probability: 0.049095604568719864
# 141-)
# sentiment: Fake, probability: 0.04909954592585564
# 142-)
# sentiment: True, probability: 0.9462124705314636
# 143-)
# sentiment: Fake, probability: 0.04910095036029816
# 144-)
# sentiment: Fake, probability: 0.04917321726679802
# 145-)
# sentiment: True, probability: 0.9462122917175293
# 146-)
# sentiment: True, probability: 0.9462121725082397
# 147-)
# sentiment: Fake, probability: 0.04912467300891876
# 148-)
# sentiment: True, probability: 0.9462121725082397
# 149-)
# sentiment: Fake, probability: 0.049317725002765656
# 150-)
# sentiment: True, probability: 0.9462123513221741
# 151-)
# sentiment: True, probability: 0.9462123513221741
# 152-)
# sentiment: True, probability: 0.9462125897407532
# 153-)
# sentiment: True, probability: 0.9462122917175293
# 154-)
# sentiment: True, probability: 0.9462122917175293
# 155-)
# sentiment: True, probability: 0.9462121725082397
# 156-)
# sentiment: True, probability: 0.9462124705314636
# 157-)
# sentiment: Fake, probability: 0.049091219902038574
# 158-)
# sentiment: True, probability: 0.9462125897407532
# 159-)
# sentiment: True, probability: 0.9462122917175293
# 160-)
# sentiment: Fake, probability: 0.049105431884527206
# 161-)
# sentiment: Fake, probability: 0.04910256341099739
# 162-)
# sentiment: True, probability: 0.9462189078330994
# 163-)
# sentiment: Fake, probability: 0.049103207886219025
# 164-)
# sentiment: Fake, probability: 0.04909907653927803
# 165-)
# sentiment: True, probability: 0.9462122917175293
# 166-)
# sentiment: True, probability: 0.9462122917175293
# 167-)
# sentiment: True, probability: 0.9462213516235352
# 168-)
# sentiment: True, probability: 0.9462122917175293
# 169-)
# sentiment: Fake, probability: 0.04910513386130333
# 170-)
# sentiment: Fake, probability: 0.049093179404735565
# 171-)
# sentiment: True, probability: 0.9462130069732666
# 172-)
# sentiment: Fake, probability: 0.04909678176045418
# 173-)
# sentiment: True, probability: 0.9462122917175293
# 174-)
# sentiment: Fake, probability: 0.04909960925579071
# 175-)
# sentiment: True, probability: 0.9462121725082397
# 176-)
# sentiment: Fake, probability: 0.04908895120024681
# 177-)
# sentiment: True, probability: 0.9462122917175293
# 178-)
# sentiment: True, probability: 0.9462122917175293
# 179-)
# sentiment: Fake, probability: 0.04909800738096237
# 180-)
# sentiment: True, probability: 0.9462123513221741
# 181-)
# sentiment: Fake, probability: 0.04910091310739517
# 182-)
# sentiment: True, probability: 0.9462123513221741
# 183-)
# sentiment: Fake, probability: 0.04909511283040047
# 184-)
# sentiment: True, probability: 0.94621342420578
# 185-)
# sentiment: Fake, probability: 0.04909531772136688
# 186-)
# sentiment: True, probability: 0.9462122917175293
# 187-)
# sentiment: True, probability: 0.9462123513221741
# 188-)
# sentiment: True, probability: 0.9462132453918457
# 189-)
# sentiment: Fake, probability: 0.04910799488425255
# 190-)
# sentiment: True, probability: 0.9462120532989502
# 191-)
# sentiment: True, probability: 0.9462121725082397
# 192-)
# sentiment: Fake, probability: 0.0490923747420311
# 193-)
# sentiment: Fake, probability: 0.049221064895391464
# 194-)
# sentiment: True, probability: 0.9462124705314636
# 195-)
# sentiment: True, probability: 0.9462122917175293
# 196-)
# sentiment: Fake, probability: 0.04909801855683327
# 197-)
# sentiment: Fake, probability: 0.04909765347838402
# 198-)
# sentiment: Fake, probability: 0.049095090478658676
# 199-)
# sentiment: True, probability: 0.9462123513221741
# 200-)
# sentiment: Fake, probability: 0.04909510537981987
# 201-)
# sentiment: Fake, probability: 0.049091886729002
# 202-)
# sentiment: True, probability: 0.9462123513221741
# 203-)
# sentiment: Fake, probability: 0.049264900386333466
# 204-)
# sentiment: Fake, probability: 0.04909241944551468
# 205-)
# sentiment: True, probability: 0.9462121725082397
# 206-)
# sentiment: Fake, probability: 0.049092844128608704
# 207-)
# sentiment: True, probability: 0.9462125897407532
# 208-)
# sentiment: True, probability: 0.9462122917175293
# 209-)
# sentiment: Fake, probability: 0.04922391101717949
# 210-)
# sentiment: True, probability: 0.9462123513221741
# 211-)
# sentiment: True, probability: 0.9462121725082397
# 212-)
# sentiment: True, probability: 0.9462121725082397
# 213-)
# sentiment: True, probability: 0.9462124705314636
# 214-)
# sentiment: Fake, probability: 0.04909379780292511
# 215-)
# sentiment: Fake, probability: 0.04909219965338707
# 216-)
# sentiment: Fake, probability: 0.04909271001815796
# 217-)
# sentiment: True, probability: 0.9462122917175293
# 218-)
# sentiment: True, probability: 0.9462127089500427
# 219-)
# sentiment: True, probability: 0.9462122917175293
# 220-)
# sentiment: True, probability: 0.9462124705314636
# 221-)
# sentiment: Fake, probability: 0.04910862818360329
# 222-)
# sentiment: True, probability: 0.9462123513221741
# 223-)
# sentiment: True, probability: 0.9462128281593323
# 224-)
# sentiment: True, probability: 0.9462123513221741
# 225-)
# sentiment: Fake, probability: 0.049093734472990036
# 226-)
# sentiment: Fake, probability: 0.049091409891843796
# 227-)
# sentiment: Fake, probability: 0.04912126809358597
# 228-)
# sentiment: True, probability: 0.9462121725082397
# 229-)
# sentiment: Fake, probability: 0.049092285335063934
# 230-)
# sentiment: True, probability: 0.9462121725082397
# 231-)
# sentiment: True, probability: 0.9462125897407532
# 232-)
# sentiment: Fake, probability: 0.049092646688222885
# 233-)
# sentiment: True, probability: 0.9462122917175293
# 234-)
# sentiment: Fake, probability: 0.04909723997116089
# 235-)
# sentiment: True, probability: 0.9462120532989502
# 236-)
# sentiment: True, probability: 0.9462121725082397
# 237-)
# sentiment: Fake, probability: 0.04908743500709534
# 238-)
# sentiment: Fake, probability: 0.04916275665163994
# 239-)
# sentiment: True, probability: 0.9462127089500427
# 240-)
# sentiment: True, probability: 0.9462122917175293
# 241-)
# sentiment: True, probability: 0.9462122917175293
# 242-)
# sentiment: True, probability: 0.9462125897407532
# 243-)
# sentiment: Fake, probability: 0.04909064993262291
# 244-)
# sentiment: Fake, probability: 0.04910210147500038
# 245-)
# sentiment: Fake, probability: 0.04914290830492973
# 246-)
# sentiment: Fake, probability: 0.049094315618276596
# 247-)
# sentiment: Fake, probability: 0.0490904301404953
# 248-)
# sentiment: True, probability: 0.9462121725082397
# 249-)
# sentiment: Fake, probability: 0.049103718250989914
# 250-)
# sentiment: True, probability: 0.9462122917175293
# 251-)
# sentiment: Fake, probability: 0.04909271001815796
# 252-)
# sentiment: Fake, probability: 0.04910879582166672
# 253-)
# sentiment: True, probability: 0.9462121725082397
# 254-)
# sentiment: Fake, probability: 0.04909050837159157
# 255-)
# sentiment: True, probability: 0.9462122917175293
# 256-)
# sentiment: Fake, probability: 0.04909460246562958
# 257-)
# sentiment: Fake, probability: 0.0491003543138504
# 258-)
# sentiment: True, probability: 0.9462123513221741
# 259-)
# sentiment: True, probability: 0.9462124705314636
# 260-)
# sentiment: True, probability: 0.9462122917175293
# 261-)
# sentiment: True, probability: 0.9462305307388306
# 262-)
# sentiment: Fake, probability: 0.0490909069776535
# 263-)
# sentiment: True, probability: 0.9462121725082397
# 264-)
# sentiment: True, probability: 0.9462122917175293
# 265-)
# sentiment: True, probability: 0.9462122917175293
# 266-)
# sentiment: Fake, probability: 0.04909698665142059
# 267-)
# sentiment: True, probability: 0.9462124705314636
# 268-)
# sentiment: True, probability: 0.9462122917175293
# 269-)
# sentiment: True, probability: 0.9462122917175293
# 270-)
# sentiment: True, probability: 0.9462130069732666
# 271-)
# sentiment: Fake, probability: 0.04909531772136688
# 272-)
# sentiment: Fake, probability: 0.04910409823060036
# 273-)
# sentiment: Fake, probability: 0.049089279025793076
# 274-)
# sentiment: True, probability: 0.9462123513221741
# 275-)
# sentiment: Fake, probability: 0.049109842628240585
# 276-)
# sentiment: True, probability: 0.9462121725082397
# 277-)
# sentiment: Fake, probability: 0.04909391328692436
# 278-)
# sentiment: True, probability: 0.9462124705314636
# 279-)
# sentiment: Fake, probability: 0.049099698662757874
# 280-)
# sentiment: Fake, probability: 0.04910050332546234
# 281-)
# sentiment: Fake, probability: 0.04909617081284523
# 282-)
# sentiment: True, probability: 0.9462123513221741
# 283-)
# sentiment: True, probability: 0.9462122917175293
# 284-)
# sentiment: Fake, probability: 0.04979884997010231
# 285-)
# sentiment: True, probability: 0.9462122917175293
# 286-)
# sentiment: Fake, probability: 0.04909170791506767
# 287-)
# sentiment: True, probability: 0.9462120532989502
# 288-)
# sentiment: Fake, probability: 0.0491131916642189
# 289-)
# sentiment: True, probability: 0.9462124705314636
# 290-)
# sentiment: True, probability: 0.9462122917175293
# 291-)
# sentiment: Fake, probability: 0.26181837916374207
# 292-)
# sentiment: True, probability: 0.9462122917175293
# 293-)
# sentiment: True, probability: 0.9462143182754517
# 294-)
# sentiment: Fake, probability: 0.04910524562001228
# 295-)
# sentiment: True, probability: 0.9462121725082397
# 296-)
# sentiment: True, probability: 0.9462130069732666
# 297-)
# sentiment: Fake, probability: 0.04966273158788681
# 298-)
# sentiment: Fake, probability: 0.04910043254494667
# 299-)
# sentiment: True, probability: 0.9462125897407532
# 300-)
# sentiment: Fake, probability: 0.049093492329120636
# 301-)
# sentiment: Fake, probability: 0.04911629855632782
# 302-)
# sentiment: Fake, probability: 0.04908814653754234
# 303-)
# sentiment: Fake, probability: 0.0490945503115654
# 304-)
# sentiment: Fake, probability: 0.04908900335431099
# 305-)
# sentiment: Fake, probability: 0.0499914288520813
# 306-)
# sentiment: True, probability: 0.9462148547172546
# 307-)
# sentiment: True, probability: 0.9462122917175293
# 308-)
# sentiment: True, probability: 0.9462122917175293
# 309-)
# sentiment: True, probability: 0.9462121725082397
# 310-)
# sentiment: True, probability: 0.9462128281593323
# 311-)
# sentiment: Fake, probability: 0.04909332096576691
# 312-)
# sentiment: True, probability: 0.9462121725082397
# 313-)
# sentiment: Fake, probability: 0.04908920079469681
# 314-)
# sentiment: True, probability: 0.9462130069732666
# 315-)
# sentiment: True, probability: 0.9462122917175293
# 316-)
# sentiment: True, probability: 0.9462121725082397
# 317-)
# sentiment: True, probability: 0.9462149143218994
# 318-)
# sentiment: True, probability: 0.946212887763977
# 319-)
# sentiment: Fake, probability: 0.049113571643829346
# 320-)
# sentiment: True, probability: 0.9462121725082397
# 321-)
# sentiment: True, probability: 0.9462124705314636
# 322-)
# sentiment: Fake, probability: 0.04909059405326843
# 323-)
# sentiment: True, probability: 0.9462121725082397
# 324-)
# sentiment: Fake, probability: 0.04914813116192818
# 325-)
# sentiment: True, probability: 0.9462127089500427
# 326-)
# sentiment: True, probability: 0.9462220668792725
# 327-)
# sentiment: True, probability: 0.9462122917175293
# 328-)
# sentiment: True, probability: 0.9462122917175293
# 329-)
# sentiment: Fake, probability: 0.04909328743815422
# 330-)
# sentiment: True, probability: 0.9462122917175293
# 331-)
# sentiment: True, probability: 0.9462121725082397
# 332-)
# sentiment: Fake, probability: 0.04917392507195473
# 333-)
# sentiment: Fake, probability: 0.049103520810604095
# 334-)
# sentiment: Fake, probability: 0.0500456839799881
# 335-)
# sentiment: Fake, probability: 0.04909723997116089
# 336-)
# sentiment: True, probability: 0.9462123513221741
# 337-)
# sentiment: True, probability: 0.9462123513221741
# 338-)
# sentiment: Fake, probability: 0.04909377917647362
# 339-)
# sentiment: True, probability: 0.9462122917175293
# 340-)
# sentiment: Fake, probability: 0.04909112676978111
# 341-)
# sentiment: True, probability: 0.9462121725082397
# 342-)
# sentiment: Fake, probability: 0.0499441884458065
# 343-)
# sentiment: Fake, probability: 0.0490877702832222
# 344-)
# sentiment: True, probability: 0.9462122917175293
# 345-)
# sentiment: Fake, probability: 0.04912355914711952
# 346-)
# sentiment: Fake, probability: 0.04910200834274292
# 347-)
# sentiment: True, probability: 0.946229875087738
# 348-)
# sentiment: True, probability: 0.9462122917175293
# 349-)
# sentiment: True, probability: 0.9462120532989502
# 350-)
# sentiment: Fake, probability: 0.049094557762145996
# 351-)
# sentiment: True, probability: 0.9462122917175293
# 352-)
# sentiment: True, probability: 0.9462130069732666
# 353-)
# sentiment: Fake, probability: 0.04908856004476547
# 354-)
# sentiment: True, probability: 0.9462124705314636
# 355-)
# sentiment: True, probability: 0.9462156891822815
# 356-)
# sentiment: Fake, probability: 0.04909719526767731
# 357-)
# sentiment: True, probability: 0.9462122917175293
# 358-)
# sentiment: Fake, probability: 0.04909396916627884
# 359-)
# sentiment: Fake, probability: 0.049107447266578674
# 360-)
# sentiment: True, probability: 0.9462127089500427
# 361-)
# sentiment: True, probability: 0.9462137818336487
# 362-)
# sentiment: Fake, probability: 0.05053921788930893
# 363-)
# sentiment: True, probability: 0.9462121725082397
# 364-)
# sentiment: Fake, probability: 0.04921448230743408
# 365-)
# sentiment: True, probability: 0.9462139010429382
# 366-)
# sentiment: Fake, probability: 0.049091752618551254
# 367-)
# sentiment: Fake, probability: 0.04909104108810425
# 368-)
# sentiment: True, probability: 0.9462122917175293
# 369-)
# sentiment: Fake, probability: 0.04980945587158203
# 370-)
# sentiment: True, probability: 0.9462123513221741
# 371-)
# sentiment: True, probability: 0.9462123513221741
# 372-)
# sentiment: True, probability: 0.9462122917175293
# 373-)
# sentiment: Fake, probability: 0.04909411072731018
# 374-)
# sentiment: Fake, probability: 0.049090564250946045
# 375-)
# sentiment: Fake, probability: 0.04916688799858093
# 376-)
# sentiment: Fake, probability: 0.04908907040953636
# 377-)
# sentiment: True, probability: 0.9462122917175293
# 378-)
# sentiment: Fake, probability: 0.04909580200910568
# 379-)
# sentiment: Fake, probability: 0.04909033700823784
# 380-)
# sentiment: True, probability: 0.9462122917175293
# 381-)
# sentiment: True, probability: 0.9462159276008606
# 382-)
# sentiment: Fake, probability: 0.04948104918003082
# 383-)
# sentiment: True, probability: 0.9462121725082397
# 384-)
# sentiment: True, probability: 0.9462124705314636
# 385-)
# sentiment: True, probability: 0.9462121725082397
# 386-)
# sentiment: True, probability: 0.9462124705314636
# 387-)
# sentiment: True, probability: 0.9462124705314636
# 388-)
# sentiment: Fake, probability: 0.049095191061496735
# 389-)
# sentiment: Fake, probability: 0.04966426268219948
# 390-)
# sentiment: True, probability: 0.9462122917175293
# 391-)
# sentiment: Fake, probability: 0.049090415239334106
# 392-)
# sentiment: True, probability: 0.9462124705314636
# 393-)
# sentiment: True, probability: 0.9462121725082397
# 394-)
# sentiment: True, probability: 0.9462139010429382
# 395-)
# sentiment: Fake, probability: 0.04909281060099602
# 396-)
# sentiment: Fake, probability: 0.04909582808613777
# 397-)
# sentiment: True, probability: 0.9462130069732666
# 398-)
# sentiment: Fake, probability: 0.04911275953054428
# 399-)
# sentiment: True, probability: 0.9462130069732666
# 400-)
# sentiment: Fake, probability: 0.0490962490439415
# 401-)
# sentiment: Fake, probability: 0.049096450209617615
# 402-)
# sentiment: Fake, probability: 0.049091920256614685
# 403-)
# sentiment: True, probability: 0.9462122917175293
# 404-)
# sentiment: Fake, probability: 0.04909731447696686
# 405-)
# sentiment: True, probability: 0.9462122917175293
# 406-)
# sentiment: True, probability: 0.9462123513221741
# 407-)
# sentiment: True, probability: 0.9462122917175293
# 408-)
# sentiment: True, probability: 0.946212887763977
# 409-)
# sentiment: Fake, probability: 0.04910420998930931
# 410-)
# sentiment: True, probability: 0.946212887763977
# 411-)
# sentiment: Fake, probability: 0.04909343272447586
# 412-)
# sentiment: Fake, probability: 0.049101293087005615
# 413-)
# sentiment: True, probability: 0.9462121725082397
# 414-)
# sentiment: True, probability: 0.9462121725082397
# 415-)
# sentiment: True, probability: 0.9462122917175293
# 416-)
# sentiment: Fake, probability: 0.04909076169133186
# 417-)
# sentiment: True, probability: 0.9462123513221741
# 418-)
# sentiment: Fake, probability: 0.049089670181274414
# 419-)
# sentiment: Fake, probability: 0.04909757524728775
# 420-)
# sentiment: True, probability: 0.9462122917175293
# 421-)
# sentiment: Fake, probability: 0.04909631982445717
# 422-)
# sentiment: True, probability: 0.9462125897407532
# 423-)
# sentiment: True, probability: 0.9462122917175293
# 424-)
# sentiment: Fake, probability: 0.049110252410173416
# 425-)
# sentiment: True, probability: 0.9462130069732666
# 426-)
# sentiment: True, probability: 0.9462121725082397
# 427-)
# sentiment: True, probability: 0.9462122917175293
# 428-)
# sentiment: True, probability: 0.9462122917175293
# 429-)
# sentiment: True, probability: 0.9462123513221741
# 430-)
# sentiment: True, probability: 0.9462121725082397
# 431-)
# sentiment: True, probability: 0.9462122917175293
# 432-)
# sentiment: True, probability: 0.9462124705314636
# 433-)
# sentiment: True, probability: 0.9462123513221741
# 434-)
# sentiment: True, probability: 0.9462139010429382
# 435-)
# sentiment: Fake, probability: 0.04911207780241966
# 436-)
# sentiment: Fake, probability: 0.04909524694085121
# 437-)
# sentiment: Fake, probability: 0.04909158870577812
# 438-)
# sentiment: Fake, probability: 0.04910657927393913
# 439-)
# sentiment: True, probability: 0.9462121725082397
# 440-)
# sentiment: Fake, probability: 0.049164094030857086
# 441-)
# sentiment: Fake, probability: 0.04910779371857643
# 442-)
# sentiment: Fake, probability: 0.049095913767814636
# 443-)
# sentiment: Fake, probability: 0.04909104108810425
# 444-)
# sentiment: Fake, probability: 0.04909504950046539
# 445-)
# sentiment: Fake, probability: 0.049142986536026
# 446-)
# sentiment: Fake, probability: 0.049087971448898315
# 447-)
# sentiment: True, probability: 0.9462122917175293
# 448-)
# sentiment: True, probability: 0.9462121725082397
# 449-)
# sentiment: Fake, probability: 0.04910394176840782
# 450-)
# sentiment: Fake, probability: 0.04913067817687988
# 451-)
# sentiment: True, probability: 0.9462122917175293
# 452-)
# sentiment: True, probability: 0.9462121725082397
# 453-)
# sentiment: Fake, probability: 0.04909722879528999
# 454-)
# sentiment: Fake, probability: 0.04958236962556839
# 455-)
# sentiment: Fake, probability: 0.049093589186668396
# 456-)
# sentiment: True, probability: 0.9462127089500427
# 457-)
# sentiment: True, probability: 0.9462121725082397
# 458-)
# sentiment: True, probability: 0.9462124705314636
# 459-)
# sentiment: Fake, probability: 0.04909469187259674
# 460-)
# sentiment: Fake, probability: 0.04909680783748627
# 461-)
# sentiment: Fake, probability: 0.04909464344382286
# 462-)
# sentiment: Fake, probability: 0.04908812418580055
# 463-)
# sentiment: Fake, probability: 0.049089327454566956
# 464-)
# sentiment: Fake, probability: 0.04910121485590935
# 465-)
# sentiment: Fake, probability: 0.04909377917647362
# 466-)
# sentiment: Fake, probability: 0.04909320920705795
# 467-)
# sentiment: Fake, probability: 0.04909660294651985
# 468-)
# sentiment: True, probability: 0.9462127089500427
# 469-)
# sentiment: Fake, probability: 0.049101781100034714
# 470-)
# sentiment: Fake, probability: 0.04909475892782211
# 471-)
# sentiment: True, probability: 0.9462122917175293
# 472-)
# sentiment: True, probability: 0.9462123513221741
# 473-)
# sentiment: Fake, probability: 0.04909992218017578
# 474-)
# sentiment: True, probability: 0.9462127089500427
# 475-)
# sentiment: True, probability: 0.9462125897407532
# 476-)
# sentiment: Fake, probability: 0.04910684749484062
# 477-)
# sentiment: Fake, probability: 0.049096617847681046
# 478-)
# sentiment: True, probability: 0.9462127089500427
# 479-)
# sentiment: Fake, probability: 0.04909858480095863
# 480-)
# sentiment: True, probability: 0.9462121725082397
# 481-)
# sentiment: Fake, probability: 0.049106668680906296
# 482-)
# sentiment: True, probability: 0.9462125897407532
# 483-)
# sentiment: True, probability: 0.9462120532989502
# 484-)
# sentiment: Fake, probability: 0.049098365008831024
# 485-)
# sentiment: Fake, probability: 0.04910469800233841
# 486-)
# sentiment: True, probability: 0.9462125897407532
# 487-)
# sentiment: Fake, probability: 0.049097541719675064
# 488-)
# sentiment: Fake, probability: 0.04915914312005043
# 489-)
# sentiment: Fake, probability: 0.050321582704782486
# 490-)
# sentiment: Fake, probability: 0.04909273236989975
# 491-)
# sentiment: True, probability: 0.9462122917175293
# 492-)
# sentiment: Fake, probability: 0.04910257086157799
# 493-)
# sentiment: True, probability: 0.9462122917175293
# 494-)
# sentiment: True, probability: 0.9462123513221741
# 495-)
# sentiment: True, probability: 0.9462122917175293
# 496-)
# sentiment: Fake, probability: 0.0493096299469471
# 497-)
# sentiment: Fake, probability: 0.04914401099085808
# 498-)
# sentiment: True, probability: 0.9462128281593323
# 499-)
# sentiment: True, probability: 0.9462123513221741
# 500-)
# sentiment: True, probability: 0.9462122917175293
# 501-)
# sentiment: Fake, probability: 0.049138009548187256
# 502-)
# sentiment: Fake, probability: 0.04908980429172516
# 503-)
# sentiment: Fake, probability: 0.049088794738054276
# 504-)
# sentiment: True, probability: 0.9462127089500427
# 505-)
# sentiment: Fake, probability: 0.04909389093518257
# 506-)
# sentiment: True, probability: 0.9462121725082397
# 507-)
# sentiment: True, probability: 0.9462121725082397
# 508-)
# sentiment: Fake, probability: 0.049101147800683975
# 509-)
# sentiment: Fake, probability: 0.04909751936793327
# 510-)
# sentiment: Fake, probability: 0.04909303039312363
# 511-)
# sentiment: True, probability: 0.9462121725082397
# 512-)
# sentiment: Fake, probability: 0.04909832030534744
# 513-)
# sentiment: Fake, probability: 0.04910736158490181
# 514-)
# sentiment: Fake, probability: 0.04933897778391838
# 515-)
# sentiment: True, probability: 0.9462131261825562
# 516-)
# sentiment: True, probability: 0.9462122917175293
# 517-)
# sentiment: True, probability: 0.9462122917175293
# 518-)
# sentiment: True, probability: 0.9462122917175293
# 519-)
# sentiment: True, probability: 0.9462121725082397
# 520-)
# sentiment: True, probability: 0.9462122917175293
# 521-)
# sentiment: True, probability: 0.9462121725082397
# 522-)
# sentiment: True, probability: 0.9462137818336487
# 523-)
# sentiment: True, probability: 0.9462122917175293
# 524-)
# sentiment: Fake, probability: 0.0490906648337841
# 525-)
# sentiment: Fake, probability: 0.0491022951900959
# 526-)
# sentiment: True, probability: 0.9462122917175293
# 527-)
# sentiment: Fake, probability: 0.04909587278962135
# 528-)
# sentiment: Fake, probability: 0.049093008041381836
# 529-)
# sentiment: True, probability: 0.9462121725082397
# 530-)
# sentiment: True, probability: 0.9462121725082397
# 531-)
# sentiment: True, probability: 0.9462124705314636
# 532-)
# sentiment: True, probability: 0.9462123513221741
# 533-)
# sentiment: True, probability: 0.9462122917175293
# 534-)
# sentiment: Fake, probability: 0.04909616336226463
# 535-)
# sentiment: Fake, probability: 0.04910746216773987
# 536-)
# sentiment: True, probability: 0.9462122917175293
# 537-)
# sentiment: True, probability: 0.9462122917175293
# 538-)
# sentiment: Fake, probability: 0.0490976981818676
# 539-)
# sentiment: Fake, probability: 0.04909011721611023
# 540-)
# sentiment: True, probability: 0.9462127089500427
# 541-)
# sentiment: True, probability: 0.9462121725082397
# 542-)
# sentiment: True, probability: 0.9462122917175293
# 543-)
# sentiment: True, probability: 0.9462121725082397
# 544-)
# sentiment: True, probability: 0.9462122917175293
# 545-)
# sentiment: Fake, probability: 0.04909130930900574
# 546-)
# sentiment: Fake, probability: 0.04909616336226463
# 547-)
# sentiment: True, probability: 0.9462122917175293
# 548-)
# sentiment: Fake, probability: 0.049096427857875824
# 549-)
# sentiment: Fake, probability: 0.04913109168410301
# 550-)
# sentiment: Fake, probability: 0.049109939485788345
# 551-)
# sentiment: Fake, probability: 0.049089569598436356
# 552-)
# sentiment: True, probability: 0.9462122917175293
# 553-)
# sentiment: Fake, probability: 0.04910754784941673
# 554-)
# sentiment: Fake, probability: 0.04909273236989975
# 555-)
# sentiment: Fake, probability: 0.0490916445851326
# 556-)
# sentiment: True, probability: 0.9462121725082397
# 557-)
# sentiment: Fake, probability: 0.04912017285823822
# 558-)
# sentiment: Fake, probability: 0.049089305102825165
# 559-)
# sentiment: True, probability: 0.9462123513221741
# 560-)
# sentiment: Fake, probability: 0.049094267189502716
# 561-)
# sentiment: True, probability: 0.9462125897407532
# 562-)
# sentiment: True, probability: 0.9462122917175293
# 563-)
# sentiment: True, probability: 0.9462122917175293
# 564-)
# sentiment: True, probability: 0.9462124705314636
# 565-)
# sentiment: Fake, probability: 0.049091510474681854
# 566-)
# sentiment: Fake, probability: 0.049097660928964615
# 567-)
# sentiment: True, probability: 0.9462121725082397
# 568-)
# sentiment: Fake, probability: 0.049092356115579605
# 569-)
# sentiment: Fake, probability: 0.049100011587142944
# 570-)
# sentiment: True, probability: 0.9462121725082397
# 571-)
# sentiment: Fake, probability: 0.04979259893298149
# 572-)
# sentiment: Fake, probability: 0.04912560060620308
# 573-)
# sentiment: True, probability: 0.9462123513221741
# 574-)
# sentiment: True, probability: 0.9462122917175293
# 575-)
# sentiment: True, probability: 0.9462125897407532
# 576-)
# sentiment: True, probability: 0.9462122917175293
# 577-)
# sentiment: Fake, probability: 0.04909748584032059
# 578-)
# sentiment: Fake, probability: 0.04909130930900574
# 579-)
# sentiment: True, probability: 0.9462125897407532
# 580-)
# sentiment: True, probability: 0.9462127089500427
# 581-)
# sentiment: True, probability: 0.946212887763977
# 582-)
# sentiment: Fake, probability: 0.04909462854266167
# 583-)
# sentiment: True, probability: 0.9462123513221741
# 584-)
# sentiment: True, probability: 0.9462121725082397
# 585-)
# sentiment: True, probability: 0.9462125897407532
# 586-)
# sentiment: True, probability: 0.9462121725082397
# 587-)
# sentiment: True, probability: 0.9462124705314636
# 588-)
# sentiment: True, probability: 0.946212887763977
# 589-)
# sentiment: True, probability: 0.9462127089500427
# 590-)
# sentiment: Fake, probability: 0.04913569986820221
# 591-)
# sentiment: True, probability: 0.9462121725082397
# 592-)
# sentiment: True, probability: 0.9462124705314636
# 593-)
# sentiment: Fake, probability: 0.04926886409521103
# 594-)
# sentiment: True, probability: 0.9462130069732666
# 595-)
# sentiment: Fake, probability: 0.04908992722630501
# 596-)
# sentiment: True, probability: 0.9462122917175293
# 597-)
# sentiment: True, probability: 0.9462130069732666
# 598-)
# sentiment: Fake, probability: 0.0490921214222908
# 599-)
# sentiment: Fake, probability: 0.04909183084964752
# 600-)
# sentiment: Fake, probability: 0.04917418956756592
# 601-)
# sentiment: True, probability: 0.9462122917175293
# 602-)
# sentiment: True, probability: 0.9462124705314636
# 603-)
# sentiment: True, probability: 0.9462122917175293
# 604-)
# sentiment: Fake, probability: 0.04909208416938782
# 605-)
# sentiment: True, probability: 0.9462156891822815
# 606-)
# sentiment: True, probability: 0.9462122917175293
# 607-)
# sentiment: Fake, probability: 0.04909508302807808
# 608-)
# sentiment: True, probability: 0.9462122917175293
# 609-)
# sentiment: True, probability: 0.9462121725082397
# 610-)
# sentiment: Fake, probability: 0.0490933358669281
# 611-)
# sentiment: Fake, probability: 0.04909662529826164
# 612-)
# sentiment: True, probability: 0.9462127089500427
# 613-)
# sentiment: Fake, probability: 0.04913888871669769
# 614-)
# sentiment: Fake, probability: 0.04910408332943916
# 615-)
# sentiment: True, probability: 0.9462140798568726
# 616-)
# sentiment: True, probability: 0.9462124705314636
# 617-)
# sentiment: True, probability: 0.9462121725082397
# 618-)
# sentiment: True, probability: 0.9462127089500427
# 619-)
# sentiment: True, probability: 0.9462121725082397
# 620-)
# sentiment: Fake, probability: 0.04909263178706169
# 621-)
# sentiment: Fake, probability: 0.04908807948231697
# 622-)
# sentiment: Fake, probability: 0.049089059233665466
# 623-)
# sentiment: Fake, probability: 0.0490913949906826
# 624-)
# sentiment: Fake, probability: 0.04909095540642738
# 625-)
# sentiment: Fake, probability: 0.04910712689161301
# 626-)
# sentiment: Fake, probability: 0.04910188168287277
# 627-)
# sentiment: Fake, probability: 0.049115363508462906
# 628-)
# sentiment: Fake, probability: 0.04910333827137947
# 629-)
# sentiment: True, probability: 0.9462121725082397
# 630-)
# sentiment: True, probability: 0.9462130069732666
# 631-)
# sentiment: Fake, probability: 0.04909614101052284
# 632-)
# sentiment: Fake, probability: 0.04909341409802437
# 633-)
# sentiment: Fake, probability: 0.049279093742370605
# 634-)
# sentiment: True, probability: 0.9462122917175293
# 635-)
# sentiment: Fake, probability: 0.04913828521966934
# 636-)
# sentiment: True, probability: 0.9462125897407532
# 637-)
# sentiment: True, probability: 0.9462122917175293
# 638-)
# sentiment: Fake, probability: 0.049094777554273605
# 639-)
# sentiment: Fake, probability: 0.04944910109043121
# 640-)
# sentiment: True, probability: 0.9462123513221741
# 641-)
# sentiment: Fake, probability: 0.049094777554273605
# 642-)
# sentiment: Fake, probability: 0.04909331351518631
# 643-)
# sentiment: Fake, probability: 0.04909030720591545
# 644-)
# sentiment: Fake, probability: 0.04909805208444595
# 645-)
# sentiment: True, probability: 0.9462123513221741
# 646-)
# sentiment: Fake, probability: 0.049099188297986984
# 647-)
# sentiment: Fake, probability: 0.04912497475743294
# 648-)
# sentiment: Fake, probability: 0.04910154640674591
# 649-)
# sentiment: True, probability: 0.9462121725082397
# 650-)
# sentiment: Fake, probability: 0.049092553555965424
# 651-)
# sentiment: True, probability: 0.9462123513221741
# 652-)
# sentiment: True, probability: 0.9462125897407532
# 653-)
# sentiment: Fake, probability: 0.04909127578139305
# 654-)
# sentiment: True, probability: 0.9462123513221741
# 655-)
# sentiment: True, probability: 0.9462124705314636
# 656-)
# sentiment: Fake, probability: 0.0490913949906826
# 657-)
# sentiment: True, probability: 0.9462128281593323
# 658-)
# sentiment: Fake, probability: 0.04910113662481308
# 659-)
# sentiment: True, probability: 0.9462122917175293
# 660-)
# sentiment: Fake, probability: 0.04909370094537735
# 661-)
# sentiment: Fake, probability: 0.049089960753917694
# 662-)
# sentiment: True, probability: 0.9462121725082397
# 663-)
# sentiment: True, probability: 0.9462143182754517
# 664-)
# sentiment: Fake, probability: 0.04909155145287514
# 665-)
# sentiment: True, probability: 0.9462123513221741
# 666-)
# sentiment: Fake, probability: 0.049093712121248245
# 667-)
# sentiment: True, probability: 0.9462122917175293
# 668-)
# sentiment: Fake, probability: 0.049090877175331116
# 669-)
# sentiment: Fake, probability: 0.04910039156675339
# 670-)
# sentiment: True, probability: 0.9462124705314636
# 671-)
# sentiment: Fake, probability: 0.04911182075738907
# 672-)
# sentiment: Fake, probability: 0.049090828746557236
# 673-)
# sentiment: Fake, probability: 0.049097273498773575
# 674-)
# sentiment: Fake, probability: 0.049092911183834076
# 675-)
# sentiment: Fake, probability: 0.0490923635661602
# 676-)
# sentiment: True, probability: 0.9462121725082397
# 677-)
# sentiment: True, probability: 0.9462128281593323
# 678-)
# sentiment: True, probability: 0.946212887763977
# 679-)
# sentiment: Fake, probability: 0.04909108579158783
# 680-)
# sentiment: Fake, probability: 0.04911397397518158
# 681-)
# sentiment: True, probability: 0.9462121725082397
# 682-)
# sentiment: Fake, probability: 0.04909219965338707
# 683-)
# sentiment: Fake, probability: 0.04910163953900337
# 684-)
# sentiment: True, probability: 0.9462183713912964
# 685-)
# sentiment: Fake, probability: 0.04910101369023323
# 686-)
# sentiment: Fake, probability: 0.04921480640769005
# 687-)
# sentiment: Fake, probability: 0.04910368472337723
# 688-)
# sentiment: Fake, probability: 0.049093641340732574
# 689-)
# sentiment: Fake, probability: 0.04909442365169525
# 690-)
# sentiment: True, probability: 0.9462122917175293
# 691-)
# sentiment: True, probability: 0.9462122917175293
# 692-)
# sentiment: Fake, probability: 0.04909540340304375
# 693-)
# sentiment: True, probability: 0.9462125897407532
# 694-)
# sentiment: True, probability: 0.9462121725082397
# 695-)
# sentiment: Fake, probability: 0.04908810555934906
# 696-)
# sentiment: True, probability: 0.9462124705314636
# 697-)
# sentiment: True, probability: 0.9462121725082397
# 698-)
# sentiment: True, probability: 0.9462127089500427
# 699-)
# sentiment: True, probability: 0.9462125897407532
# 700-)
# sentiment: True, probability: 0.9462122917175293
# 701-)
# sentiment: True, probability: 0.9462128281593323
# 702-)
# sentiment: True, probability: 0.9462125897407532
# 703-)
# sentiment: Fake, probability: 0.04908953979611397
# 704-)
# sentiment: Fake, probability: 0.04909641668200493
# 705-)
# sentiment: True, probability: 0.9462143182754517
# 706-)
# sentiment: True, probability: 0.9462123513221741
# 707-)
# sentiment: Fake, probability: 0.04909069463610649
# 708-)
# sentiment: Fake, probability: 0.0490870326757431
# 709-)
# sentiment: True, probability: 0.9462123513221741
# 710-)
# sentiment: Fake, probability: 0.04909719526767731
# 711-)
# sentiment: Fake, probability: 0.049098968505859375
# 712-)
# sentiment: True, probability: 0.9462140798568726
# 713-)
# sentiment: Fake, probability: 0.04909542575478554
# 714-)
# sentiment: Fake, probability: 0.04909539595246315
# 715-)
# sentiment: Fake, probability: 0.04910638928413391
# 716-)
# sentiment: Fake, probability: 0.04909740760922432
# 717-)
# sentiment: True, probability: 0.9462122917175293
# 718-)
# sentiment: Fake, probability: 0.04909408837556839
# 719-)
# sentiment: True, probability: 0.9462124705314636
# 720-)
# sentiment: True, probability: 0.9462364912033081
# 721-)
# sentiment: True, probability: 0.9462121725082397
# 722-)
# sentiment: True, probability: 0.9462127089500427
# 723-)
# sentiment: True, probability: 0.9462139010429382
# 724-)
# sentiment: True, probability: 0.9462121725082397
# 725-)
# sentiment: True, probability: 0.9462123513221741
# 726-)
# sentiment: Fake, probability: 0.049093086272478104
# 727-)
# sentiment: Fake, probability: 0.04909418150782585
# 728-)
# sentiment: Fake, probability: 0.04910529777407646
# 729-)
# sentiment: Fake, probability: 0.049104053527116776
# 730-)
# sentiment: True, probability: 0.9462121725082397
# 731-)
# sentiment: Fake, probability: 0.049191854894161224
# 732-)
# sentiment: Fake, probability: 0.0490964837372303
# 733-)
# sentiment: Fake, probability: 0.049096494913101196
# 734-)
# sentiment: True, probability: 0.9462122917175293
# 735-)
# sentiment: Fake, probability: 0.049094222486019135
# 736-)
# sentiment: Fake, probability: 0.04910256341099739
# 737-)
# sentiment: True, probability: 0.9462123513221741
# 738-)
# sentiment: Fake, probability: 0.04960929974913597
# 739-)
# sentiment: Fake, probability: 0.049093469977378845
# 740-)
# sentiment: True, probability: 0.9462122917175293
# 741-)
# sentiment: Fake, probability: 0.04909117519855499
# 742-)
# sentiment: True, probability: 0.9462122917175293
# 743-)
# sentiment: True, probability: 0.9462121725082397
# 744-)
# sentiment: Fake, probability: 0.04909345507621765
# 745-)
# sentiment: Fake, probability: 0.04913730174303055
# 746-)
# sentiment: True, probability: 0.94621342420578
# 747-)
# sentiment: True, probability: 0.9462125897407532
# 748-)
# sentiment: True, probability: 0.9462121725082397
# 749-)
# sentiment: Fake, probability: 0.04909401014447212
# 750-)
# sentiment: Fake, probability: 0.04923170804977417
# 751-)
# sentiment: Fake, probability: 0.049104444682598114
# 752-)
# sentiment: True, probability: 0.9462125897407532
# 753-)
# sentiment: Fake, probability: 0.04908882454037666
# 754-)
# sentiment: True, probability: 0.9462122917175293
# 755-)
# sentiment: True, probability: 0.9462121725082397
# 756-)
# sentiment: True, probability: 0.9462127089500427
# 757-)
# sentiment: True, probability: 0.9462123513221741
# 758-)
# sentiment: True, probability: 0.9462201595306396
# 759-)
# sentiment: Fake, probability: 0.04909176379442215
# 760-)
# sentiment: True, probability: 0.9462122917175293
# 761-)
# sentiment: Fake, probability: 0.04909305274486542
# 762-)
# sentiment: Fake, probability: 0.04909079894423485
# 763-)
# sentiment: True, probability: 0.9462125897407532
# 764-)
# sentiment: Fake, probability: 0.049094680696725845
# 765-)
# sentiment: Fake, probability: 0.049099087715148926
# 766-)
# sentiment: Fake, probability: 0.049104176461696625
# 767-)
# sentiment: True, probability: 0.9462122917175293
# 768-)
# sentiment: True, probability: 0.9462127089500427
# 769-)
# sentiment: Fake, probability: 0.04909127578139305
# 770-)
# sentiment: Fake, probability: 0.049094777554273605
# 771-)
# sentiment: Fake, probability: 0.04909273236989975
# 772-)
# sentiment: True, probability: 0.9462159276008606
# 773-)
# sentiment: Fake, probability: 0.04909162223339081
# 774-)
# sentiment: Fake, probability: 0.04915831610560417
# 775-)
# sentiment: Fake, probability: 0.049121957272291183
# 776-)
# sentiment: True, probability: 0.9462121725082397
# 777-)
# sentiment: Fake, probability: 0.04909355565905571
# 778-)
# sentiment: Fake, probability: 0.049098145216703415
# 779-)
# sentiment: True, probability: 0.9462123513221741
# 780-)
# sentiment: True, probability: 0.9462124705314636
# 781-)
# sentiment: True, probability: 0.9462123513221741
# 782-)
# sentiment: True, probability: 0.9462127089500427
# 783-)
# sentiment: True, probability: 0.9462121725082397
# 784-)
# sentiment: True, probability: 0.9462124705314636
# 785-)
# sentiment: Fake, probability: 0.04910282790660858
# 786-)
# sentiment: True, probability: 0.9462122917175293
# 787-)
# sentiment: Fake, probability: 0.0490911528468132
# 788-)
# sentiment: True, probability: 0.9462122917175293
# 789-)
# sentiment: True, probability: 0.9462121725082397
# 790-)
# sentiment: Fake, probability: 0.04909960925579071
# 791-)
# sentiment: Fake, probability: 0.049102138727903366
# 792-)
# sentiment: True, probability: 0.9462123513221741
# 793-)
# sentiment: True, probability: 0.9462125897407532
# 794-)
# sentiment: True, probability: 0.9462123513221741
# 795-)
# sentiment: True, probability: 0.9462122917175293
# 796-)
# sentiment: Fake, probability: 0.04909030720591545
# 797-)
# sentiment: True, probability: 0.9462121725082397
# 798-)
# sentiment: Fake, probability: 0.04909598454833031
# 799-)
# sentiment: Fake, probability: 0.04909025877714157
# 800-)
# sentiment: True, probability: 0.9462123513221741
# 801-)
# sentiment: Fake, probability: 0.04909660294651985
# 802-)
# sentiment: Fake, probability: 0.04910968616604805
# 803-)
# sentiment: True, probability: 0.9462122917175293
# 804-)
# sentiment: True, probability: 0.9462122917175293
# 805-)
# sentiment: Fake, probability: 0.04918297380208969
# 806-)
# sentiment: True, probability: 0.9462123513221741
# 807-)
# sentiment: True, probability: 0.9462123513221741
# 808-)
# sentiment: Fake, probability: 0.04909944534301758
# 809-)
# sentiment: Fake, probability: 0.049093689769506454
# 810-)
# sentiment: Fake, probability: 0.049100447446107864
# 811-)
# sentiment: True, probability: 0.9462121725082397
# 812-)
# sentiment: Fake, probability: 0.04908999428153038
# 813-)
# sentiment: True, probability: 0.9462123513221741
# 814-)
# sentiment: Fake, probability: 0.04909297823905945
# 815-)
# sentiment: True, probability: 0.9462122917175293
# 816-)
# sentiment: True, probability: 0.9462122917175293
# 817-)
# sentiment: True, probability: 0.9462120532989502
# 818-)
# sentiment: Fake, probability: 0.04909300059080124
# 819-)
# sentiment: True, probability: 0.9462120532989502
# 820-)
# sentiment: True, probability: 0.9462124705314636
# 821-)
# sentiment: True, probability: 0.9462124705314636
# 822-)
# sentiment: True, probability: 0.9462124705314636
# 823-)
# sentiment: Fake, probability: 0.049130890518426895
# 824-)
# sentiment: True, probability: 0.9462121725082397
# 825-)
# sentiment: True, probability: 0.9462121725082397
# 826-)
# sentiment: True, probability: 0.9461355209350586
# 827-)
# sentiment: True, probability: 0.9462125897407532
# 828-)
# sentiment: True, probability: 0.9462140798568726
# 829-)
# sentiment: True, probability: 0.9462122917175293
# 830-)
# sentiment: Fake, probability: 0.04913124442100525
# 831-)
# sentiment: True, probability: 0.9462121725082397
# 832-)
# sentiment: True, probability: 0.9462143182754517
# 833-)
# sentiment: Fake, probability: 0.049093812704086304
# 834-)
# sentiment: True, probability: 0.9462125897407532
# 835-)
# sentiment: True, probability: 0.9462130069732666
# 836-)
# sentiment: Fake, probability: 0.04909335821866989
# 837-)
# sentiment: Fake, probability: 0.04911088943481445
# 838-)
# sentiment: True, probability: 0.9462125897407532
# 839-)
# sentiment: True, probability: 0.9462122917175293
# 840-)
# sentiment: True, probability: 0.9462123513221741
# 841-)
# sentiment: Fake, probability: 0.049099478870630264
# 842-)
# sentiment: True, probability: 0.9462122917175293
# 843-)
# sentiment: True, probability: 0.9462121725082397
# 844-)
# sentiment: Fake, probability: 0.04909154400229454
# 845-)
# sentiment: Fake, probability: 0.04910972714424133
# 846-)
# sentiment: Fake, probability: 0.049092184752225876
# 847-)
# sentiment: Fake, probability: 0.04917461425065994
# 848-)
# sentiment: Fake, probability: 0.04909580200910568
# 849-)
# sentiment: True, probability: 0.9462127089500427
# 850-)
# sentiment: Fake, probability: 0.12272968143224716
# 851-)
# sentiment: Fake, probability: 0.0491177923977375
# 852-)
# sentiment: Fake, probability: 0.04909146577119827
# 853-)
# sentiment: True, probability: 0.9462121725082397
# 854-)
# sentiment: Fake, probability: 0.04909629747271538
# 855-)
# sentiment: True, probability: 0.9462124705314636
# 856-)
# sentiment: True, probability: 0.9462124705314636
# 857-)
# sentiment: True, probability: 0.9462125897407532
# 858-)
# sentiment: True, probability: 0.9462122917175293
# 859-)
# sentiment: Fake, probability: 0.049098700284957886
# 860-)
# sentiment: True, probability: 0.9462121725082397
# 861-)
# sentiment: True, probability: 0.946221113204956
# 862-)
# sentiment: Fake, probability: 0.049091607332229614
# 863-)
# sentiment: Fake, probability: 0.04909669607877731
# 864-)
# sentiment: Fake, probability: 0.049122657626867294
# 865-)
# sentiment: Fake, probability: 0.049099989235401154
# 866-)
# sentiment: Fake, probability: 0.04909759759902954
# 867-)
# sentiment: Fake, probability: 0.04909504950046539
# 868-)
# sentiment: True, probability: 0.9462122917175293
# 869-)
# sentiment: Fake, probability: 0.04909433797001839
# 870-)
# sentiment: True, probability: 0.9462122917175293
# 871-)
# sentiment: True, probability: 0.9462123513221741
# 872-)
# sentiment: True, probability: 0.9462122917175293
# 873-)
# sentiment: True, probability: 0.9462122917175293
# 874-)
# sentiment: Fake, probability: 0.04908952862024307
# 875-)
# sentiment: Fake, probability: 0.049092989414930344
# 876-)
# sentiment: True, probability: 0.9462121725082397
# 877-)
# sentiment: Fake, probability: 0.04909997060894966
# 878-)
# sentiment: True, probability: 0.9462121725082397
# 879-)
# sentiment: True, probability: 0.946212887763977
# 880-)
# sentiment: True, probability: 0.9462121725082397
# 881-)
# sentiment: Fake, probability: 0.04915684834122658
# 882-)
# sentiment: True, probability: 0.9462121725082397
# 883-)
# sentiment: True, probability: 0.9462121725082397
# 884-)
# sentiment: Fake, probability: 0.049094315618276596
# 885-)
# sentiment: True, probability: 0.9462121725082397
# 886-)
# sentiment: True, probability: 0.9462121725082397
# 887-)
# sentiment: True, probability: 0.9462124705314636
# 888-)
# sentiment: Fake, probability: 0.04918554052710533
# 889-)
# sentiment: Fake, probability: 0.049113739281892776
# 890-)
# sentiment: Fake, probability: 0.04909602925181389
# 891-)
# sentiment: Fake, probability: 0.04909007251262665
# 892-)
# sentiment: True, probability: 0.9462122917175293
# 893-)
# sentiment: True, probability: 0.9462122917175293
# 894-)
# sentiment: True, probability: 0.9462127089500427
# 895-)
# sentiment: Fake, probability: 0.04910752549767494
# 896-)
# sentiment: Fake, probability: 0.04910677298903465
# 897-)
# sentiment: Fake, probability: 0.049097783863544464
# 898-)
# sentiment: True, probability: 0.9462124705314636
# 899-)
# sentiment: True, probability: 0.9462121725082397
# 900-)
# sentiment: Fake, probability: 0.0505431666970253
# 901-)
# sentiment: Fake, probability: 0.049112625420093536
# 902-)
# sentiment: True, probability: 0.9462225437164307
# 903-)
# sentiment: True, probability: 0.9462121725082397
# 904-)
# sentiment: True, probability: 0.9462122917175293
# 905-)
# sentiment: True, probability: 0.9462133646011353
# 906-)
# sentiment: Fake, probability: 0.04915807396173477
# 907-)
# sentiment: True, probability: 0.9462122917175293
# 908-)
# sentiment: True, probability: 0.9462125897407532
# 909-)
# sentiment: True, probability: 0.9462127089500427
# 910-)
# sentiment: Fake, probability: 0.04909651726484299
# 911-)
# sentiment: Fake, probability: 0.04909900948405266
# 912-)
# sentiment: True, probability: 0.946212887763977
# 913-)
# sentiment: True, probability: 0.9462137818336487
# 914-)
# sentiment: True, probability: 0.946212887763977
# 915-)
# sentiment: True, probability: 0.9462122917175293
# 916-)
# sentiment: Fake, probability: 0.04913242533802986
# 917-)
# sentiment: Fake, probability: 0.04909048601984978
# 918-)
# sentiment: Fake, probability: 0.04909030720591545
# 919-)
# sentiment: Fake, probability: 0.0490923747420311
# 920-)
# sentiment: Fake, probability: 0.049094103276729584
# 921-)
# sentiment: True, probability: 0.9462121725082397
# 922-)
# sentiment: True, probability: 0.9462128281593323
# 923-)
# sentiment: Fake, probability: 0.049099601805210114
# 924-)
# sentiment: Fake, probability: 0.04909253120422363
# 925-)
# sentiment: Fake, probability: 0.04910021275281906
# 926-)
# sentiment: Fake, probability: 0.049092184752225876
# 927-)
# sentiment: Fake, probability: 0.049114473164081573
# 928-)
# sentiment: True, probability: 0.9462123513221741
# 929-)
# sentiment: True, probability: 0.9462140798568726
# 930-)
# sentiment: Fake, probability: 0.04910511150956154
# 931-)
# sentiment: True, probability: 0.9462123513221741
# 932-)
# sentiment: Fake, probability: 0.04910075664520264
# 933-)
# sentiment: True, probability: 0.9462122917175293
# 934-)
# sentiment: True, probability: 0.9462125897407532
# 935-)
# sentiment: Fake, probability: 0.049139734357595444
# 936-)
# sentiment: True, probability: 0.9462121725082397
# 937-)
# sentiment: Fake, probability: 0.04909524694085121
# 938-)
# sentiment: Fake, probability: 0.0490916445851326
# 939-)
# sentiment: True, probability: 0.9462122917175293
# 940-)
# sentiment: True, probability: 0.9462123513221741
# 941-)
# sentiment: True, probability: 0.9462121725082397
# 942-)
# sentiment: Fake, probability: 0.04908981919288635
# 943-)
# sentiment: Fake, probability: 0.04909215494990349
# 944-)
# sentiment: Fake, probability: 0.049092333763837814
# 945-)
# sentiment: True, probability: 0.9462122917175293
# 946-)
# sentiment: Fake, probability: 0.04908895120024681
# 947-)
# sentiment: True, probability: 0.9462122917175293
# 948-)
# sentiment: Fake, probability: 0.049090463668107986
# 949-)
# sentiment: Fake, probability: 0.04909168556332588
# 950-)
# sentiment: Fake, probability: 0.04909331351518631
# 951-)
# sentiment: True, probability: 0.9462121725082397
# 952-)
# sentiment: Fake, probability: 0.04908839240670204
# 953-)
# sentiment: True, probability: 0.9462121725082397
# 954-)
# sentiment: Fake, probability: 0.04909117519855499
# 955-)
# sentiment: Fake, probability: 0.04910750314593315
# 956-)
# sentiment: Fake, probability: 0.04909433797001839
# 957-)
# sentiment: Fake, probability: 0.04909312352538109
# 958-)
# sentiment: Fake, probability: 0.049093279987573624
# 959-)
# sentiment: Fake, probability: 0.0491417832672596
# 960-)
# sentiment: True, probability: 0.9462121725082397
# 961-)
# sentiment: True, probability: 0.9462121725082397
# 962-)
# sentiment: Fake, probability: 0.04909428954124451
# 963-)
# sentiment: Fake, probability: 0.049093689769506454
# 964-)
# sentiment: Fake, probability: 0.049194950610399246
# 965-)
# sentiment: Fake, probability: 0.04909133166074753
# 966-)
# sentiment: Fake, probability: 0.04914863407611847
# 967-)
# sentiment: True, probability: 0.9462139010429382
# 968-)
# sentiment: Fake, probability: 0.04910079389810562
# 969-)
# sentiment: True, probability: 0.9462122917175293
# 970-)
# sentiment: Fake, probability: 0.0492340512573719
# 971-)
# sentiment: True, probability: 0.9462125897407532
# 972-)
# sentiment: True, probability: 0.9462122917175293
# 973-)
# sentiment: Fake, probability: 0.049981195479631424
# 974-)
# sentiment: Fake, probability: 0.04910214990377426
# 975-)
# sentiment: True, probability: 0.9462122917175293
# 976-)
# sentiment: True, probability: 0.9462143182754517
# 977-)
# sentiment: True, probability: 0.9462123513221741
# 978-)
# sentiment: Fake, probability: 0.049088235944509506
# 979-)
# sentiment: Fake, probability: 0.04909577965736389
# 980-)
# sentiment: True, probability: 0.9462123513221741
# 981-)
# sentiment: True, probability: 0.9462121725082397
# 982-)
# sentiment: True, probability: 0.9462121725082397
# 983-)
# sentiment: Fake, probability: 0.04909542575478554
# 984-)
# sentiment: Fake, probability: 0.04909057170152664
# 985-)
# sentiment: Fake, probability: 0.05043249577283859
# 986-)
# sentiment: Fake, probability: 0.049132224172353745
# 987-)
# sentiment: True, probability: 0.9462125897407532
# 988-)
# sentiment: True, probability: 0.9462123513221741
# 989-)
# sentiment: Fake, probability: 0.04909126088023186
# 990-)
# sentiment: True, probability: 0.9462122917175293
# 991-)
# sentiment: True, probability: 0.9462122917175293
# 992-)
# sentiment: True, probability: 0.9462123513221741
# 993-)
# sentiment: Fake, probability: 0.04909871891140938
# 994-)
# sentiment: Fake, probability: 0.04909098520874977
# 995-)
# sentiment: True, probability: 0.9462128281593323
# 996-)
# sentiment: True, probability: 0.9462161064147949
# 997-)
# sentiment: Fake, probability: 0.049124229699373245
# 998-)
# sentiment: Fake, probability: 0.04910420998930931
# 999-)
# sentiment: True, probability: 0.9462122917175293
# 970

# %%
from sklearn.metrics import confusion_matrix

# %%
y_true=submission["Truth"].tolist()

# %%
conf_matrix=confusion_matrix(y_true, y_pred)
conf_matrix
# Out:
# array([[472,  20],
#        [ 10, 498]])

# %%
TP = conf_matrix[1][1]
TN = conf_matrix[0][0]
FP = conf_matrix[0][1]
FN = conf_matrix[1][0]
print('True Positives:', TP)
print('True Negatives:', TN)
print('False Positives:', FP)
print('False Negatives:', FN)
# Out:
# True Positives: 498
# True Negatives: 472
# False Positives: 20
# False Negatives: 10

# %%
conf_accuracy = (float (TP+TN) / float(TP + TN + FP + FN))

conf_error_rate = 1- conf_accuracy
    
conf_sensitivity = (TP / float(TP + FN)) #recall

conf_specificity = (TN / float(TN + FP))
    
conf_precision = (TN / float(TN + FP))

conf_f1 = 2 * ((conf_precision * conf_sensitivity) / (conf_precision + conf_sensitivity))
print('-'*50)
print(f'Accuracy: {round(conf_accuracy,2)}') 
print(f'Error_rate: {round(conf_error_rate,2)}') 
print(f'Sensitivity: {round(conf_sensitivity,2)}') 
print(f'Specificity: {round(conf_specificity,2)}') 
print(f'Precision: {round(conf_precision,2)}')
print(f'f_1 Score: {round(conf_f1,2)}')
# Out:
# --------------------------------------------------
# Accuracy: 0.97
# Error_rate: 0.03
# Sensitivity: 0.98
# Specificity: 0.96
# Precision: 0.96
# f_1 Score: 0.97
